# %% [markdown]
# ### Upload comunity Louvain

# %%
from cdlib import algorithms, readwrite
louv_coms = readwrite.read_community_csv( "louv_coms.csv", ",", str)

# %%
louv_clusters=louv_coms.communities 
louv_clusters
# Out:
# [['sharks',
#   'Soil',
#   'Outdoors',
#   'SpeculativeEvolution',
#   'bicycling',
#   'PlanetEarth',
#   'marinebiology',
#   'ocean',
#   'FuckNestle',
#   'whales',
#   'DiscoverEarth',
#   'srilanka',
#   'Elephants',
#   'elephantsbeingbros',
#   'Ytqaz2019',
#   'uscg',
#   'USMC',
#   'Stargate',
#   'MiscellaneousContent',
#   'McMansionHell',
#   'memphis',
#   'myfavoritemurder',
#   'tookyoulongenough',
#   'seasteading',
#   'BoogieMonster',
#   'TTAMF',
#   'Beebola',
#   'bootlickingnews',
#   'SwitzerlandIsFake',
#   'newsokuexp',
#   'autism',
#   'DanLeBatardShow',
#   'BoicoteANestle',
#   'weed',
#   'Iamactuallyverybadass',
#   'army',
#   'HelpMeFind',
#   'Sneakers',
#   'Dailyslant',
#   'SmallDeliMeats',
#   'Ternion',
#   'Belgium_kingdomOf',
#   'IASIP',
#   'Shitifind',
#   'hanguk',
#   'mostgilded',
#   'SportsQuestionMark',
#   'tesdcares',
#   'milwaukee',
#   'wholesome',
#   'YourMoneyIsYourVote',
#   'interesting',
#   'totallynotrobots',
#   'pittsburgh',
#   'vinyljerk',
#   'ToolBand',
#   'WhatWeDointheShadows',
#   'lukewarmsalmon',
#   'octopus',
#   'rickygervais',
#   'thalassophobia',
#   'SorayorimoTooiBasho',
#   'antarctica',
#   'blowit',
#   'Snorkblot',
#   'lastpodcastontheleft',
#   'theydidthemath',
#   'MediaSynthesis',
#   'trees',
#   'BlackMentalHealth',
#   'blackmen',
#   'nathanforyou',
#   'megafaunarewilding',
#   'MakeMeSmile',
#   'biology',
#   'IndianEnts',
#   'Wildfire',
#   'thanksihateit',
#   'HumansAreMetal',
#   'wolves',
#   'KarlPilkingtonFanClub',
#   'OkCupid',
#   'Silfy_Star',
#   'seinfeld',
#   'MyrtleBeach',
#   'NotAllHeroesWearCapes',
#   'Washington',
#   'Bigloads',
#   'unclebens',
#   'UIUC',
#   'Mushrooms',
#   'PsilocybinMushrooms',
#   'CarsCarbsCardsKabis',
#   'shutdownfullcast',
#   'DamnNatureYouScary',
#   'BirdsArentReal',
#   'bonnaroo',
#   'oddlyterrifying',
#   'Grimdank',
#   'shrooms',
#   'programminghorror',
#   'HilariaBaldwin',
#   'firefly',
#   'ArcherFX',
#   'microbiology',
#   'Mindalteringsituation',
#   'lost',
#   'LPOTL',
#   'AntarcticAnomalies',
#   'insects',
#   'Bossfight',
#   'espresso',
#   'discworld',
#   'Moisengoiser',
#   'LateStageCarnism',
#   'GasStationBathroom',
#   'BillBurr',
#   'timelapse',
#   'Reddit50k',
#   'beefanddairynetwork',
#   'ape',
#   'LandscapingTips',
#   'shittyaskscience',
#   'Hyperhidrosis',
#   'mildlyevangelion',
#   'DeliriumSC',
#   'aoe2',
#   'PUBG',
#   'Brunei',
#   'Lal_Salaam',
#   'AboutDirtbags',
#   'TopReposts',
#   'interstellar',
#   'destiny2',
#   'firewater',
#   'battlefield_4',
#   'wowfuckthewhat',
#   'oknotizie',
#   'TrillbillyPodcast',
#   'IndianDefense',
#   'forsen',
#   'PoliticoSubreddit',
#   'reptiles',
#   'squashmountainscouts',
#   'uktrees',
#   'AthleticoMince',
#   'NoMansSkyTheGame',
#   'iranian',
#   'GeorgiaOrGeorgia',
#   'norwayonreddit',
#   'LSD',
#   'yourlearningcurve',
#   'DeathPositive',
#   'asheville',
#   'holyshit',
#   'wokekids',
#   'shittydarksouls',
#   'Master0fwar',
#   'MBMBAM',
#   'WomenAreMetal',
#   'blackmirror',
#   'architecture',
#   'GoodBlackNews',
#   'ufl',
#   'sunlesssea',
#   'somecoolguys',
#   'gardening',
#   'Kanye',
#   'AntiLolitary',
#   'ATC',
#   'synthesizercirclejerk',
#   'kindafunny',
#   'Damnthatsinteresting',
#   'ALLTHEANIMALS',
#   'Jaguarland',
#   'AquaticAsFuck',
#   'megalophobia',
#   'Tierzoo',
#   'badassanimals',
#   'catsvstail',
#   'TheDepthsBelow',
#   'forbiddenboops',
#   'AIDKE',
#   'alligatorsarecute',
#   'Cetaphobia',
#   'orcas',
#   'SealifeGifs',
#   'forbiddensnacks',
#   'Currentlytripping',
#   'awwnverts',
#   'dontputyourdickinthat',
#   'RealLifePokemon',
#   'DeepRockGalactic',
#   'EDC',
#   'blackstonegriddle',
#   'Chefit',
#   'aesthetics13_saved',
#   'DeTrashed',
#   'banano',
#   'CreaturesOfTheHaunt',
#   'physicaltherapy',
#   'marijuanaenthusiasts',
#   'RawAndReal',
#   'bees',
#   'drawing',
#   'awesome',
#   'barstoolsports',
#   'ThePrepared',
#   'StardewValley',
#   'sunflowers',
#   'thingsforants',
#   'vancouver',
#   'marinelife',
#   'TheLewinsons',
#   'civilengineering',
#   'dune',
#   'NatureIsFuckingLit',
#   'Vermiculture',
#   'lotrmemes',
#   'ants',
#   'Pikmin',
#   'freefolk',
#   'cellbits',
#   'HunterXHunterMemes',
#   'nope',
#   'thatisdope',
#   'pikmin_irl',
#   'Breath_of_the_Wild',
#   'lordoftherings',
#   'makesitlookeasy',
#   'AccidentalWesAnderson',
#   'blender',
#   'ProperAnimalNames',
#   'dji',
#   'tampabayrays',
#   'SkyGame',
#   'TheBrownSound',
#   'forbiddenbed',
#   'stingrays',
#   'petesinterest',
#   'brandonsanderson',
#   'mayahiga',
#   '4g11',
#   'WhaleGifs',
#   'ShowTheKids',
#   'absoluteunit',
#   'Suomi',
#   'DivorcedBirds',
#   'RocketLeague',
#   'savedPostyStuff',
#   'birds',
#   'birdsonbirds',
#   'valheim',
#   'Yatzee',
#   'Monke',
#   'Satisfyingasfuck',
#   'RealmofDarkPsych',
#   'LeastWeAmuseOurselves',
#   'BILT',
#   'bigcats',
#   'beyondthebump',
#   'YogurtOwlsInLove',
#   'ShiniesIRL',
#   'TheAmazingNature',
#   'FuckYouImAShark',
#   'LilliaMains',
#   'photoshopbattles',
#   'raining',
#   'animalssmiling',
#   'ThingsWeeLike',
#   'DarkCrystal',
#   'DankCrystal',
#   'crazystairs',
#   'acrophobia',
#   'qcGottaSeeThis',
#   'AnimalsBeingPolite',
#   'turtles',
#   'whatsthisallabout',
#   'Nicehappystuff',
#   'trypophobia',
#   'Sneks',
#   'NatureIsFuckingTrippy',
#   'Frankthesnake',
#   'HighResolutionGifs',
#   'RhesusNegative',
#   'enissa',
#   'BravoAlex',
#   'theHunter',
#   'AccidentalSatanism',
#   'mildyinteresting',
#   '420PT',
#   'Eldenring',
#   'detsky',
#   'justelesmeilleurs',
#   'DeerAreFuckingStupid',
#   'rance',
#   'confusingperspective',
#   'Frozen',
#   'earthfractals',
#   'folkhorror',
#   'onsshareplekkie',
#   'CulturalLayer',
#   'Darkwood',
#   'TrueSTL',
#   'TheLastAirbender',
#   'UnexpectedAvatar',
#   'quatria',
#   'AltruisticHarmony',
#   'ancestors',
#   'titanfolk',
#   'Thatsactuallyverycool',
#   'MicroPorn',
#   'gonwild',
#   'nincirclejerk',
#   'fractals',
#   'GeometryIsNeat',
#   'trippy',
#   'salt',
#   'misleadingthumbnails',
#   'shittyskylines',
#   'Tombofannihilation',
#   'MemePiece',
#   'SavageGarden',
#   'AngelIsland',
#   'Bedtimememes',
#   'Zorubark',
#   'Castelbon',
#   'animalcrossingmeme',
#   'SaveAndSort',
#   'EveryoneBeingBros',
#   'savesofmine',
#   'fpv',
#   'drones',
#   'videography',
#   'DC_Cinematic',
#   'bioniclelego',
#   'toshowthekid',
#   'FPVFlow',
#   'Dronescapes',
#   'NeoCommunistArchive',
#   'tameimpalacirclejerk',
#   'MonarchButterfly',
#   'Monterrey',
#   'venturebros',
#   'Dust_of_Memes',
#   'ItemShop',
#   'finalfuckinglevel',
#   'farpeoplehate',
#   'ProjectBlueWorld',
#   'HumanForScale',
#   'NorwayPics',
#   'Norway',
#   'norge',
#   'NorthernNordics',
#   'Mypersub_Nature',
#   'fearsineverknewihad',
#   'WeatherGifs',
#   'woahdude',
#   'ChocolateMilkGuy',
#   'FreezingFuckingCold',
#   'Planegea',
#   'satisfying',
#   'mildlysatisfying',
#   '0ug',
#   'SILI',
#   'OddlyErotic',
#   'dionysus',
#   'sterling_random_stuff',
#   'MineralPorn',
#   'OddlyArousing',
#   'interestingasfuck',
#   'holdmyredbull',
#   'AdrenalinePorn',
#   'alpinism',
#   'oddlysatisfying',
#   'PraiseTheCameraMan',
#   'natureisfuckingmetal',
#   'DudeFuckThat',
#   'accidentalsurrealism',
#   'VideosthatgiveAnxiety',
#   'Earthmind',
#   'JuJutsuKaisen',
#   'ApexOutlands',
#   'NaturalPhenomena',
#   'Spore',
#   'MicroNatureIsMetal',
#   'microscopy',
#   'HardcoreNature',
#   'microscopicmetal',
#   'thrive',
#   'Biologyporn',
#   'chadsriseup',
#   'Lotekz',
#   'untitledgoosegame',
#   'NatureGifs',
#   'rainworld',
#   'interestingasduck',
#   'TheWonderfulWorld',
#   'wimagery',
#   'animalstakingover',
#   'otternews',
#   'geology',
#   'Gregfuckedarock',
#   'whatsthisrock',
#   'FortniteSavetheWorld',
#   'Minerals',
#   'commandandconquer',
#   'Crystals',
#   'ElderScrolls',
#   'greenday',
#   'ketamine',
#   'ror2',
#   'oddlyweird',
#   'forbiddenweed',
#   'forbiddennugs',
#   'oddlymesmerizing',
#   'battlefield_one',
#   'WildNature',
#   'tarantulas',
#   'Yltd',
#   'GlitchInTheMatrix',
#   'CLOUDS',
#   'JustCause',
#   'scanningEM',
#   'fangies',
#   'snakeswhoyell',
#   'SnakesYawning',
#   'pokemon',
#   'DnDnDPod',
#   'waterAliens',
#   'STFUitsadragon',
#   'IWouldDrawThat',
#   'BirdsAreNotReal',
#   'turtle',
#   'playalone',
#   'thelongdark',
#   'lynxes',
#   'EpicFlayn',
#   'isthisearth',
#   'Cephalopods',
#   'Carlosforscale',
#   'OctopusFuckery',
#   'Cephalopod',
#   'Weird',
#   'ClearAesthetic',
#   'earthaliens',
#   'creepy',
#   'WTMFN',
#   'Berserk',
#   'berserklejerk',
#   'CantBelieveThatsReal',
#   'NatureIsFuckingFab',
#   'Ibynst',
#   'DidntKnowThatExisted',
#   'TerrifyinglyTerrifyin',
#   'TheForest',
#   'mildlyterrifying',
#   'Natureiscursed',
#   'TILI',
#   'RareAnimals',
#   'ExpectantlyTerrifying',
#   'Mildlycthulhu',
#   'Wheresthebottom',
#   'nextfuckinglevel',
#   'HumansForScale',
#   'thalassaphobia',
#   'natureismental',
#   'AbsoluteUnits',
#   'mindMYcrack',
#   'mildlyvagina',
#   'Miniworlds',
#   'wildlypenis',
#   'mildlypenis',
#   'skulls',
#   'AquaticAnimals',
#   'midlyintersting',
#   'AbyssRium',
#   'EndlessOcean',
#   'mobydick',
#   'belugasbeingbros',
#   'KarmaConspiracy',
#   'FlyFishingCircleJerk',
#   'LeagueOfMemes',
#   'usfishfinder',
#   'LightbringerSeries',
#   'natureisending',
#   'HardcoreVegHentaiPorn',
#   'homegrownnationalpark',
#   'LiminalSpace',
#   'LiminalReality',
#   'surrealplaces',
#   'prancingponypod',
#   'UnexpectedMyst',
#   'druidism',
#   'lotr',
#   'yesbandcirclejerk',
#   'BooksThatFeelLikeThis',
#   'yeahbutreallyImaspeck',
#   'itsTooLate',
#   'Pareidolia',
#   'TheDarkTower',
#   'AccidentalArtGallery',
#   'nightvale',
#   'FairytaleasFuck',
#   'darktower',
#   'desirehole',
#   'stephenking',
#   'nancydrew',
#   'discordian',
#   'GetUpvote',
#   'dolphingifs',
#   'HauntingOfHillHouse',
#   'Sleepinganimals',
#   'Natureisfuckingtired',
#   'OlogiesPodcast',
#   'SatisfactoryGame',
#   'Bioshock',
#   'subnautica',
#   'WtfAreSnails',
#   'cremposting',
#   'Skyward',
#   'snails',
#   'stickyourdickinthat',
#   'PutYourDickInThat',
#   'saveOver1000',
#   'whalesdontexist',
#   'Natureisfuckingnope',
#   'cuttlefish',
#   'scuba',
#   'SCAcirclejerk',
#   'Cameras',
#   'edmprodcirclejerk',
#   'cellular_automata',
#   'DarkBlueOcean',
#   'Velkoz',
#   'MemeHunter',
#   'gravityrush',
#   'Subnautica_Below_Zero',
#   'ARK',
#   'EvolutionGoneWild',
#   'dumblookinganimals',
#   'CoolShots',
#   'bending',
#   'YuYuHakusho',
#   'mtg',
#   'ACValhalla',
#   'beautifultrees',
#   'ConfusedBoners',
#   'PokemonSwordAndShield',
#   'acnh',
#   'VaporwaveArt',
#   'AnimalsBeingPerfect',
#   'Funforkiddos',
#   'whatsthisbird',
#   'Mickstape',
#   'AnimalsDoingMath',
#   'PinkGang',
#   'NapkinPope',
#   'pics',
#   'ANormalDayInAlaska',
#   'Lizards',
#   'japanpics',
#   'whatsthisplant',
#   'AccidentalGreenhouses',
#   'MitchHedberg',
#   'WorldIsClosed',
#   'reclaimedbynature',
#   'sharedwithlove',
#   'MushroomPorn',
#   'goblincore',
#   'swampcore',
#   'PicsGalore',
#   'Influencersinthewild',
#   'RealLifeShinies',
#   'borbs',
#   'rarecompliments',
#   'rarelobsters',
#   'csgo',
#   'LSDTripLifeHacks',
#   'vigorgame',
#   'DrStone',
#   'NotAnotherDnDPodcast',
#   'Anprimistan',
#   'gojira',
#   'postapocalyptic',
#   'monkeys',
#   'classicwow',
#   '90dayfianceuncensored',
#   'Asmongold',
#   'MobileOverview',
#   'MischievousGibbons',
#   'Slackline',
#   'crashbandicoot',
#   'attackontitan',
#   '2007scape',
#   'modelbirbs',
#   'PicsOfUnusualBirds',
#   'Thorgasm',
#   'Bossfightarena',
#   'Lightning',
#   'forthebitz',
#   'phish',
#   'roads',
#   'AnimalbeingEngineers',
#   'AnimatedKidsFlick',
#   'botw',
#   'whatsthisbug',
#   'Entomology',
#   'spelunky',
#   'MagicCreatures',
#   'DiamondHandsRockets',
#   'Meetingofthemindz',
#   'shoebillsarentreal',
#   'mikeburnfire',
#   'OriAndTheBlindForest',
#   'Biigwes',
#   'BirdsBeingDicks',
#   'reddeadredemption2',
#   'RedDeadOnline',
#   'HannibalTV',
#   'skylanders',
#   'brakebills',
#   'mycology',
#   'watchplantsgrow',
#   'hillchillbillies',
#   'GearsOfWar',
#   'halo',
#   'EchoArena',
#   'physicsjokes',
#   'nightmarefuel',
#   'cadum',
#   'Crocodilia',
#   'hmmm',
#   'PlantsAreAmazing',
#   'primatology',
#   'CapyPlops',
#   'coolthingsformygirl',
#   'snakes',
#   'fakehistoryporn',
#   'popstuff',
#   'funnybooboo',
#   'Hunting',
#   'infp',
#   'aatombstonescute',
#   'Cosy',
#   'TransAesthetics',
#   'SaturatioNation',
#   'RelaxingGifs',
#   'ShittyAnimalFacts',
#   'eatingsoupwithfork',
#   'hermitcrabs',
#   'BirthofaCrab',
#   'BabyLedWeaning',
#   'scoopdewoop',
#   'KimbaMemes',
#   'KingdomDeath',
#   'FierceFlow',
#   'nationalgeographic',
#   'fawns',
#   'snek_irl',
#   'ClimbingCircleJerk',
#   'MetalGearSolidmemes',
#   'oddlysatisfyingnature',
#   'attractivereddit',
#   'natureporn',
#   'falloutnewvegas',
#   'DMT',
#   'ExcellentRepost',
#   'TunnelEntrances',
#   'deepseacreatures',
#   'AnimalCrossingNewHor',
#   'ac_newhorizons',
#   'clione',
#   'Flyers',
#   'Dimension20',
#   'pathoftitans',
#   'rollercoasterjerk',
#   'herpetawwlogy',
#   'PlantedTank',
#   'monsteraday',
#   'thassalaphobia',
#   'Snek',
#   'chaparral',
#   'gangasnaan',
#   'Yamaha_TW200',
#   'thecatchup',
#   'Vaporglow',
#   'Terraria',
#   'Mario',
#   'JurassicWorldAlive',
#   'ankmemes',
#   'suits',
#   'MartialMemes',
#   'NewParents',
#   'OneInTheHand',
#   'Witcher3',
#   'PlantGoths',
#   'madlad',
#   'upvotebecauseboy',
#   'theticket',
#   'FuturisticRaven',
#   'DayMemeing',
#   'whitewater',
#   'ftfy',
#   'BanTheRepublicanParty',
#   'navy',
#   'aesoprock',
#   'Cursed_Images',
#   'morbid_reality',
#   'big3podcast',
#   'Frisson',
#   'paris',
#   'guitars',
#   'hauntedattractions',
#   'NegarakuMalaysia',
#   'DinosaurKnight',
#   'happycryingdads',
#   'MadeMeCry',
#   'PoCDoingGoodThings',
#   'acecombat',
#   'SomeGoodNews',
#   'OakIsland',
#   'thestraightdopesub',
#   'randomactsofmusic',
#   'lingling40hrs',
#   'Construction',
#   'heavyequipment',
#   'ReferenceForAnimation',
#   'Gal_Shamen',
#   'ItHadToBeBrazil',
#   'LandRover',
#   'oblivionNPC',
#   'Davie504',
#   'BossfightUniverse',
#   'disability',
#   'kayotic123',
#   'vancouverwa',
#   'juggling',
#   'asianpeoplegifs',
#   'seenstit',
#   'snowboarding',
#   'HouseOfTheMemeMaker',
#   'SirSwag',
#   'Filmmakers',
#   'KidCudi',
#   'enlightenedbirdmen',
#   'expectedlyunexpected',
#   'fuckwasps',
#   'bee_irl',
#   'dxm',
#   'drums',
#   'DidntKnowIWantedThat',
#   'TurkeyJerky',
#   'PUBGConsole',
#   'juxtaposition',
#   'PraiseTheEditor',
#   'AccidentalRadiohead',
#   'CombatFootage',
#   'thisshitistight',
#   'skateboarding',
#   'Spiderman',
#   'redditiliked',
#   'kingcobrajfs',
#   'DISHPIT',
#   'morbidlybeautiful',
#   'projectzomboid',
#   'bestoftheinternet',
#   'NameThatSong',
#   'behindtheaction',
#   'toptalent',
#   'discgolf',
#   'MichaelJackson',
#   'Daniel',
#   'adfreefrontpage',
#   'RedDwarf',
#   'outside',
#   'mercedes_benz',
#   'DeathByMillennial',
#   'greysanatomy',
#   'CheapShow',
#   'pigs',
#   'youStupidBitch',
#   'HoldMyMetamucil',
#   'moon2mars',
#   'BookStew',
#   'Dance',
#   'Viral_repost',
#   'dresdenfiles',
#   'mallninjashit',
#   'neckbeardRPG',
#   'ghostoftsushima',
#   'fromsoftware',
#   'masterforgiveme',
#   'darksoulsmemes',
#   'PokemonTCG',
#   'kingdomcome',
#   'uncannyvalley',
#   'FirefighterPorn',
#   'wyomingdoesntexist',
#   'NationalPark',
#   'happy',
#   'IzuzuRodeo',
#   'nice',
#   'TheHOA',
#   'notstupidifitworks',
#   'techsupportmacgyver',
#   'agedlikewine',
#   'istp',
#   'fuckingmanly',
#   'CirclingBack',
#   'exfor',
#   'WeirdFlexButOK',
#   'geese',
#   'redrising',
#   'ScaryTechnology',
#   'eyeblech',
#   '3Dprinting',
#   'HelloInternet',
#   'unexpectedbrooklyn99',
#   'tloaHuman',
#   'thatHappened',
#   'doodiebutts',
#   'HumansBeingBros',
#   'HumansLovingWildlife',
#   'humanbeingsbeingmetal',
#   'Menaregood',
#   'juggalo',
#   'KindEngineering',
#   'AppleWatch',
#   'specializedtools',
#   'DadsBeingDads',
#   'StarKid',
#   'CoolNerd',
#   'BiomedicalEngineers',
#   'accidentalrockwell',
#   'WrongAnswersOnly',
#   'gifsthatkeepongiving',
#   'StopHunger',
#   'ThatsMyFuckingHero',
#   'onionfactory',
#   'BeforeNAfterAdoption',
#   'CannotWatchScottsTots',
#   'TabbyCats',
#   'btd6',
#   'SyntheticBiology',
#   'TheBrewery',
#   'StonerEngineering',
#   'BattlefieldV',
#   'formuladank',
#   'WildTimesPod',
#   'Flipping',
#   'fbhw',
#   'RedditAndChill',
#   'timecrisis',
#   'Warhammer40k',
#   'PearlStillSpammedYou',
#   'castiron',
#   'madmen',
#   'HowDogsWork',
#   'gaming',
#   'ActuallyInteresting',
#   'laebrkaes',
#   'totalwar',
#   'StardustCrusaders',
#   'ReefTank',
#   'Aquariums',
#   'panelshow',
#   'rootgame',
#   'crows',
#   'forgotthethe',
#   'wildgardens',
#   'roadtripnewengland',
#   'PhoenixPoint',
#   'SpecEvoJerking',
#   'Alonetv',
#   'WILTY',
#   'birdwatching',
#   'Videdia',
#   'ghana',
#   'ImageStabilization',
#   'vandwellers',
#   'Lowtechbrilliance',
#   'xbiking',
#   'amcirclejerk',
#   'KingdomHearts',
#   'ChrisChanSonichu',
#   'LoadingIcons',
#   'KSU',
#   'MechanicalKeyboards',
#   'hot_dog',
#   'fermentation',
#   'Dragonballsuper',
#   'OkieSHENANIGANS',
#   'TrashLove',
#   'savedbykru',
#   'succulents',
#   'RDR2',
#   'What',
#   'PerseveranceRover',
#   'thenetherlands',
#   'steak',
#   'fallenlondon',
#   'psychologystudents',
#   'mead',
#   '99percentinvisible',
#   'Purdue',
#   'NoDig',
#   'MadMudmen',
#   'OccupationalTherapy',
#   'zenify',
#   'flashlight',
#   'thestanleyschool',
#   'Wizard101',
#   'QueerWomenOfColor',
#   'SpidermanPS4',
#   'Stims',
#   'Stormlight_Archive',
#   '4BigTrees',
#   'Shadiversity',
#   'crochet',
#   'Bonsai',
#   'unexpectedcosmere',
#   'holofractal',
#   'ElectricUniverse',
#   'codyslab',
#   'triathlon',
#   'osr',
#   'RPIPDI',
#   'medizzy',
#   'Mewing',
#   'Futurelings',
#   'PERU',
#   'berlin',
#   'chemistry',
#   'Fractalverse',
#   'Farmers',
#   'SoBlessed',
#   'Dublin',
#   'frogpants',
#   'CollegeFootballRisk',
#   'rehabtherapy',
#   'HumanBeingBros',
#   'GoRVing',
#   'civ',
#   'labrats',
#   'evilbuildings',
#   'UznaliNas',
#   'shittyHDR',
#   'BirdsEyeViewVideos',
#   'friendlyarchitecture',
#   'Amsterdam',
#   'starcraft2',
#   'Sims4',
#   'ArchitecturePorn',
#   'Blue',
#   'mildlymonogatari',
#   'ShingekiNoKyojin',
#   'Battlefield',
#   'Romania',
#   'HisDarkMaterialsHBO',
#   'whoahdude',
#   'Founditsavedit',
#   'MeltMore',
#   'CohhCarnage',
#   'WorldOfWarships',
#   'nerdfighters',
#   'CivVI',
#   'manufacturing',
#   'ave',
#   'Morrowind',
#   'RandomStuffForBen',
#   'beltalowda',
#   'horizon',
#   'ToasterTalk',
#   'genewolfe',
#   'xkcd',
#   'Leathercraft',
#   'readyplayerone',
#   'ehlersdanlos',
#   'bkup',
#   'stevenuniverse',
#   'ScottishFootball',
#   'Earthchan',
#   'wholesome40k',
#   'MoeMorphism',
#   'Noearthsociety',
#   'simplypodlogical',
#   'abv',
#   'secretcompartments',
#   'hiddenrooms',
#   'GrifosMexico',
#   'StonerSpots',
#   'Gambiarra',
#   'DiWHY',
#   'redneckengineering',
#   'aircooled',
#   'Nittola',
#   'grilling',
#   'Owls',
#   'BirdButts',
#   ...],
#  ['nature',
#   'environment',
#   'EcoNewsNetwork',
#   'PublicLands',
#   'EndangeredSpecies',
#   'animalimpact',
#   'Animals',
#   'UpliftingNews',
#   'organizedhealing',
#   'Green_News',
#   'wildlifecorridors',
#   'WomenInNews',
#   'WomensRightsNews',
#   'prochoice',
#   'worldnews',
#   'europes',
#   'indepthstories',
#   'Midwives',
#   'ClimateCrisis',
#   'xxstem',
#   'anime_titties',
#   'cleanstreetbets',
#   'BigAgro',
#   'DoomsdayNow',
#   'DoomsdayBook',
#   'greeninvestor',
#   'energy',
#   'LockCarbon',
#   'Toadbook',
#   'SGU',
#   'Reterra',
#   'organic',
#   'patient_hackernews',
#   'CitizenPlanners',
#   'TaiwanChina',
#   'taiwan',
#   'TheEndOfHumanityShow',
#   'soundsaboutright',
#   'economy',
#   'Allopatria',
#   'Hozhor',
#   'sustainability',
#   'Ohio',
#   'climatejustice',
#   'RuralDemocrats',
#   'climateaction',
#   'climatepolicy',
#   'DemocracyNow',
#   'usa',
#   'ClimateChangeSolution',
#   'USNews2',
#   'USGovernment',
#   'usapolitics',
#   'world',
#   'europe',
#   'terrifyingstatistics',
#   'wheresthebeef',
#   'Energy_unbiased',
#   'NuclearPower',
#   'airlines',
#   'DemocratsforDiversity',
#   'EarthEnthusiasts',
#   'ClimateAndEnvironment',
#   'planet',
#   'ClimateActivism',
#   'netzero',
#   'CleanEnergy',
#   'north_america',
#   'EmissionsTax',
#   'carboncapture',
#   'northamerica',
#   'Hawaii',
#   'goodnews',
#   'hawaiinews',
#   'oceans',
#   'CoralRestoration',
#   'Positivity',
#   'environmentaljustice',
#   'ClimateActionPlan',
#   'Futurology',
#   'solarpower',
#   'gmc',
#   'midwest',
#   'Renewable',
#   'usanews',
#   'solarpowerplants',
#   'windpower',
#   '2030',
#   'climateskeptics',
#   'ClimateNews',
#   'smartcities',
#   'SouthAsia',
#   'indianews',
#   'Cities',
#   'Sustainable',
#   'RenewableEnergy',
#   'AppleInvestors',
#   'SunriseMovement',
#   'ideasforgovt',
#   'PhysicalGeography',
#   'Environmentalism',
#   'Green',
#   'PeopleDoGood',
#   'GetIt2Gether',
#   'collapse',
#   'vego',
#   'AmazoNope',
#   'HC_Capitalism',
#   'actualconspiracies',
#   'workthatreconnects',
#   'Permanence',
#   'MachineThatMakesMoney',
#   'TechOfTheFuture',
#   'water',
#   'StopFossilFuels',
#   'China_irl',
#   'bioscience',
#   'climate',
#   'ForestHealth',
#   'SearchScene',
#   'doomists',
#   'brasil',
#   'Cleveland',
#   'GreatLakesPrepping',
#   'Environmental_Policy',
#   '2020',
#   'OhioGovernment',
#   'Cetacea',
#   'Positive_News',
#   'CarbonFootprint',
#   'GreenNewDeal',
#   'GreenNewIdeas',
#   'decarbonize',
#   'coal',
#   'FossilFuels',
#   '2035',
#   'COVID19RippleEffects',
#   'theworldnews',
#   'environmentallaw',
#   'EnvironmentProtectors',
#   'libclimateactivism',
#   'neoliberal',
#   'BigEnergy',
#   'climatescience',
#   'DavidDistributed',
#   'darkfacts',
#   'supplychain',
#   'Waste',
#   'kellogg',
#   'ZeroWaste',
#   'enviroaction',
#   'ProEarth',
#   'Greenspo',
#   'Urbanism',
#   'yimby',
#   'NUMTOT',
#   'environmental_science',
#   'WatchdogJournalism',
#   'YangForPresidentHQ',
#   'RetailNews',
#   'newyorkcity',
#   'EmergingRisks',
#   'Euromaidan2014',
#   'ExposingRussia',
#   'humanrights',
#   'WatchRedditDie',
#   'PerpetualPixelNews',
#   'TriCitiesWA',
#   'exchristian',
#   'WhatsonNow',
#   'women',
#   'Buffalo',
#   'neoconNWO',
#   'PositiveNewsCovid19',
#   'FourCorners',
#   'upbeatnews',
#   'PrepperIntel',
#   'NoShitSherlock',
#   'BigTech',
#   'Anticonsumption',
#   'conservatives',
#   'ireland',
#   'Kappa',
#   'rorius',
#   'StallmanWasRight',
#   'freesoftware',
#   'nyc',
#   'MorbidReality',
#   'MARCIANOTECH',
#   'Cyberpunk',
#   'GoodIdeasForAustralia',
#   'GlobalNews',
#   'AutisticPride',
#   'MensRights',
#   'EndMassIncarceration',
#   'NewMexicoPolitics',
#   'SouthJersey',
#   'maryland',
#   'okc',
#   'LasCruces',
#   'MarshallBrain',
#   'downliftingnews',
#   'BrasildoB',
#   'gammasecretkings',
#   'PersonOfInterest',
#   'technews',
#   'PivotPodcast',
#   'Philippines',
#   'CoronavirusUS',
#   'democracy',
#   'AlexeiNavalny',
#   'CoronavirusFL',
#   'CoronavirusGA',
#   'SpaceXLounge',
#   'Piracy',
#   'AXELNetwork',
#   'TechDystopia',
#   'diabetes_t1',
#   'healthcare',
#   'arizona',
#   'SurprisingNoOne',
#   'technology',
#   'brasilivre',
#   'saudiarabia',
#   'KingdomofSaudiArabia',
#   'basicincomejapan',
#   'NormMacdonald',
#   'BidenCoalition',
#   'Chinatown_irl',
#   'AdamCarolla',
#   'Buddhism',
#   'ABA',
#   'armenia',
#   'SecondGreatDepression',
#   'Egalitarianism',
#   'Turkey',
#   'Kazakhstan',
#   'fucktheccp',
#   'applesucks',
#   'EcoFriendly',
#   'fuckamazon',
#   'AIandRobotics',
#   'AntiAmazon',
#   '2ndIntelligentSpecies',
#   'CoV2Canada',
#   'MuskMarsColony',
#   'avoidchineseproducts',
#   'islam',
#   'FreeTheUyghurs',
#   'MuslimLounge',
#   'BoycottChina',
#   'AntiFANG',
#   'CorpFree',
#   'CoronavirusCA',
#   'Anthropology',
#   'SzechuanSauceSeekers',
#   'China_War',
#   'TaiwanNumberOne',
#   'Spacers',
#   'TechNewsToday',
#   'netneutrality',
#   'exmormon',
#   'WeHaveConcerns',
#   'TIL_Uncensored',
#   'test',
#   'ChinaSucks',
#   'NoMoreBigChina',
#   'hempflowers',
#   'Bellingham',
#   'Yatirim',
#   'publichealth',
#   'KillFacebook',
#   'oculus',
#   'The_Coronavirus',
#   'StormComing',
#   'NATOrussianconflict',
#   'taiwanindependence',
#   'techable',
#   'HerpesCureResearch',
#   'clinicalresearch',
#   'svihs',
#   'scandinavia',
#   'FactoryFarming',
#   'BanFactoryFarming',
#   'paradoxpolitics',
#   'breakingnews',
#   'solarenergy',
#   'Humannews',
#   'objectiveEconomics',
#   'italy',
#   'ABoringUtopia',
#   'chonglangTV',
#   'WorldNewsHeadlines',
#   'CANNABISfuturus',
#   'UkrainevRussia',
#   'SonsofOrpheus',
#   'shroomstocks',
#   'shroomers',
#   'MindMedInvestorsClub',
#   'PsychedelicStudies',
#   'microdosing',
#   'Psychedelics',
#   'ScienceFacts',
#   'Delivery',
#   'doordash',
#   'coronavirusflorida',
#   'EuropeanNews',
#   'International',
#   'WorldNews_Serious',
#   'NewsHub',
#   'R4RcovidNYC',
#   'COVIDGoodNews',
#   'EmergingTherapies',
#   'CoronavirusRecession',
#   'finance_news',
#   '2020electioncrisis',
#   '2020Election',
#   'DeclineIntoCensorship',
#   'teslamotors',
#   'FillsYourNiche',
#   'Ornithology',
#   'Drugs',
#   'Sunriseredding',
#   'venusforming',
#   'germany',
#   'climatesolutions',
#   'uninsurable',
#   'gayfarmer',
#   'RedMeatPolitics',
#   'ClimateOffensive',
#   'socialscience',
#   'Renewable_Energy_News',
#   'EcoActivism',
#   'SDGbyBOSAGORA',
#   'FridaysForFuture',
#   'ExtinctionRebellion',
#   'EarthStrike',
#   'newbrunswickcanada',
#   'ClimateChangeWar',
#   'goodnewseveryone',
#   'goodnewsstation',
#   'NJPolitics',
#   'cannabisreform',
#   'MarijuanaNewsOnline',
#   'peoplejustdonothing',
#   'Hempire',
#   'Jamaica',
#   'nycpolitics',
#   'Alternative_Energy',
#   'Ethiopia',
#   'Tigray',
#   'AntiVegan',
#   'RedMeatScience',
#   'collapze',
#   'SiliconValleyHBO',
#   'hungary',
#   'softwaregore',
#   'ukraine',
#   'LiberalsWhoHateTheCCP',
#   'March2018',
#   'Indonesias',
#   'adultsnew',
#   'russia',
#   'winniepoohpresident',
#   'Capitalism',
#   'ParadoxExtra',
#   'amazonemployees',
#   'redcroatia',
#   'rawpetfood',
#   'Sakartvelo',
#   'Russophobic',
#   'Feminism',
#   'Bundesliga',
#   'qatar',
#   'arabs',
#   'doha',
#   'MiddleEast',
#   'Baloldal',
#   'PRChina',
#   'Holokauston',
#   'mrballen',
#   'Zino',
#   'AntiCCP',
#   'AlternatitveReality',
#   'CoronavirusRelief',
#   'DailyNewsPosts',
#   'ph_politics',
#   'Globalactivism',
#   'shitpostemblem',
#   'UkrainianConflict',
#   'RetardsTalkAboutSaudi',
#   'CHERUB',
#   'NewColdWar',
#   'overpopulation',
#   'UngiveBirthToMe',
#   'unexpectedtaylorswift',
#   'BasicFood',
#   'idiocracy',
#   '12Monkeys',
#   'ClimateCrazies',
#   'ecogenics',
#   'ThanksSherlock',
#   'sweden',
#   'Tampere',
#   'H5N8Avian',
#   'NonCredibleDefense',
#   'neocentrism',
#   'AmericanPoverty',
#   'BunchaBS',
#   'Slovakia',
#   'BasicIncome',
#   'bigaussieprepper',
#   'climatedisalarm',
#   'okinawa',
#   'UraniumSqueeze',
#   'GlobalSouth',
#   'korea',
#   'Ecosocialism',
#   'Geedis',
#   'Ryan',
#   'kirillwashere',
#   'loveliveserve',
#   'WorldSuccess',
#   'humandesign',
#   'WilliamGibson',
#   'KingstonOntario',
#   'ChinaRemoves',
#   'newsbeat',
#   'AsianAmericanIssues',
#   'olympia',
#   'universityofauckland',
#   'ToriesAreBad',
#   'takeDownRindiA',
#   'LiberalCatholics',
#   'UAE',
#   'perestroika_pw_org',
#   'China_Debate',
#   'ADVChina',
#   'toriesdeathtoll',
#   'liberta',
#   'TinyViolins',
#   'Harmontown',
#   'China',
#   'craftofintelligence',
#   'CCP_virus',
#   'PrisonStrike',
#   'ChunghwaMinkuo',
#   'chinesepolitics',
#   'justchinathings',
#   'EnoughWumaoSpam',
#   'HallOfFake',
#   'abudhabi',
#   'lithuania',
#   'CivPolitics',
#   'AbsoluteLithuanian',
#   'worldevents',
#   'espionage',
#   'magnitsky',
#   'emoluments',
#   'UnitedNations',
#   'Eritrea',
#   'Oromia',
#   'RPCV4PeaceTigray',
#   'coffee_roasters',
#   'RoyalMarines',
#   'commonwealth',
#   'Royalcore',
#   'Gaspard',
#   'TastingHistory',
#   'streeteats',
#   'benfordslaw',
#   'Southwest_VA_Living',
#   'shanghai',
#   'xijinping',
#   'AntiComAction',
#   'badgovnofreedom',
#   'AnalSwabs4All',
#   'Nepal',
#   'king_of_the_south',
#   'AntiFacebook',
#   'ProtectOurForests',
#   'Theregoesthefuture',
#   'ecology',
#   'pikachuatemyface',
#   'Abhigyan',
#   'JoeBiden',
#   'Jewish',
#   'diccwilliams',
#   'Forum_Democratie',
#   'CoronavirusWA',
#   'Coronavirus_KY',
#   'MiddleEastNews',
#   'switchgreen',
#   'investimentos',
#   'Gold',
#   'armchaireconomics',
#   'ksatv',
#   'LeonardodaVinci',
#   'progressive_islam',
#   'FuckTheChineseGov',
#   'Uyghur',
#   'Bad_Bing_No_Rice',
#   'DiscoElysium',
#   'EUnews',
#   'indonesia',
#   'sean',
#   'PoliticalScience',
#   'ArtHistory',
#   'DataHoarder',
#   'KetoNews',
#   'cincinnati',
#   'timepoverty',
#   'Taoesm',
#   'Nurse',
#   'respiratorytherapy',
#   'Covid19FreeNews',
#   'canadian',
#   'TDSInfestedIdiots',
#   'SinophobiaWatch',
#   'greenwizards',
#   'computerscience',
#   'ConservativeKiwi',
#   'asucottage',
#   'vancouvercanada',
#   'GeoNews24',
#   'TheChinaNerd',
#   'malaysia',
#   'Ecosia',
#   'HunnyFunny',
#   'Khatrimaza',
#   'CoronaUpliftingNews',
#   'cleverclogs',
#   'Coronaworldwide',
#   'CdnVeganClimateAction',
#   'Breaking_News',
#   'theAlgorithmHasSpoken',
#   'spinalcordinjuries',
#   'RobotChurch',
#   'Newsoku_L',
#   'Knoxville',
#   'GoodCorona',
#   'CoronaUK',
#   'xrmed',
#   'HongKong',
#   'chineselogic',
#   'ChinaExposed',
#   'TurkicPeople',
#   'Humans_suck',
#   'ChinaWatchNZ',
#   'internationalpolitics',
#   'foreignpolicy',
#   'cvnews',
#   'ModernWarzone',
#   'China_News',
#   'southeastasia',
#   'vipkid',
#   'Covid2019',
#   'crossposters',
#   'smem',
#   'KiAChatroom',
#   'republicans',
#   'WuhanVirus',
#   'nCoronaVirus',
#   'Disinfo',
#   'CCP_Virus_Censorship',
#   'ChinaHumanRights',
#   'BoycottTI9',
#   'Tunisia',
#   'RimWorld',
#   'rationalpakistan',
#   'Linky_links',
#   'lastweektonight',
#   'Judaism',
#   'Humanpersecution',
#   'supporthongkong',
#   'HongKongProtest',
#   'Yourmomgay69',
#   'Shittiergovernments',
#   'CoronaVirusInfo',
#   'FuckHKPopo',
#   'Asean',
#   'Milk_Tea_Alliance',
#   'singing',
#   'ccp',
#   'Sciencology',
#   'AntimatterDimensions',
#   'wsu',
#   'eliteexplorers',
#   'Gunnm',
#   'TerraformingMarsGame',
#   'Gizzverse',
#   'fightboredom',
#   'IHateCoronaVirus',
#   'TrumpCoronaVirus',
#   'CorruptionOnAPlatter',
#   'ActualidadMundial',
#   'CredibleDefense',
#   'CoronavirusFOS',
#   'republitrash',
#   'saraba0th',
#   'exAdventist',
#   'ogman',
#   'Yazidis',
#   'ReligiousFreedom',
#   'human_rights',
#   'scandalousrabbithole',
#   'Seaspiracy',
#   'plastichell',
#   'Hacking_Tutorials',
#   'cybersecurity',
#   'AskBalkans',
#   'theericzaneshow',
#   'NoMoreChina',
#   'AsABlackMan',
#   'FinanceShed',
#   'LoveForTaiwan',
#   'XiIsFinished',
#   'Sameproblems',
#   'AdamCurtis',
#   'TheyTrustMe',
#   'socialmedianews',
#   'chinareddits',
#   'propublica',
#   'tibet',
#   'Wholesomeawardhell',
#   'globalhealth',
#   'Newanimalspecies',
#   'indiadefense',
#   'foreignpolicyanalysis',
#   'NeoliberalButNoFash',
#   'Global_Geopolitics',
#   'CanadaConservatives',
#   'geopolitics',
#   'roddit',
#   'darknetdiaries',
#   'MilitaryProcurement',
#   'worldnews2',
#   'censorship',
#   'atheismindia',
#   'nationofeurope',
#   'BritishNationalism',
#   'Honduras',
#   'centralamerica',
#   'LatinAmerica',
#   'WasteFest',
#   'bookmarkStream',
#   'AnimalIndustry',
#   'tories',
#   'Antofu',
#   'ender',
#   'Monk',
#   'belarus',
#   'Biodegradable',
#   'HotterTopics',
#   'TrashyCompany',
#   'longform',
#   'FuturologyPolitics',
#   'substance',
#   'TechNewsTomorrow',
#   'GlobalTribeInitiative',
#   'research',
#   'PlanPlantPlanet',
#   'vastarinta',
#   'SocConstructOfReality',
#   'CoronaDidNothingWrong',
#   'mantis',
#   'ScienceAlliance',
#   'DieOff',
#   'COVID19Resistance',
#   'HumanProgress',
#   'USA_StratCom',
#   'programming',
#   'Ayahuasca',
#   'WhoreMagic',
#   'IHateOhio',
#   'HumanityForward',
#   'YangGang',
#   'universalincome',
#   'business',
#   'FemaleLevelUpStrategy',
#   'Presidents',
#   'upliftingnewsforwomen',
#   'electionReformNews',
#   'Leader',
#   'electionreform',
#   'elections',
#   'MiddleEastern',
#   'UberDeutschland',
#   'caucasus',
#   'KarabakhConflict',
#   'Africa',
#   'TheWayIMakeMeThink',
#   'ReForested',
#   'bonsaicommunity',
#   'Pandemic',
#   'internationalbusiness',
#   'SouthKoreanPolitics',
#   'teslainvestorsclub',
#   'Nio',
#   'FreeAsInFreedom',
#   'fastvoted',
#   'libgen',
#   'scihub',
#   'Open_Science',
#   'HealthTechnology',
#   'HealthTech',
#   'VaccineResearch',
#   'WorldHealthOrg',
#   'Vaccine',
#   'VACCINES',
#   'cyber',
#   'loicense',
#   'westabootales',
#   'AnarchyintheUK',
#   'electricvehicles',
#   'farming',
#   'VaccinesMeds',
#   'LeftWingNonFeminist',
#   'kansascity',
#   'mississippi',
#   'cordcutters',
#   'theta_network',
#   'direito',
#   'MontanaPolitics',
#   'Infrastructurist',
#   'ForUnitedStates',
#   'AlaskaPolitics',
#   'TheCrescent',
#   'FloridaPolitics',
#   'NortheastUS',
#   'Brooklyn',
#   'GAPolitics',
#   'internationallaw',
#   'notesandnews',
#   'westlinn',
#   'RooseveltRepublicans',
#   'baltimore',
#   'shitneoliberalismsays',
#   'IsTheMicStillOn',
#   'VoteByMail',
#   'SPACs',
#   'WHHR2',
#   'newsokur',
#   'krulife',
#   'toxicology',
#   'Longreads',
#   'YACUHQ',
#   'NEET',
#   'Rights',
#   'aaronswartz',
#   'Democrat',
#   'Election2020',
#   'DuggarsSnark',
#   'alaska',
#   'BidenHarrisForAmerica',
#   'CaliforniaForYang',
#   'newyork',
#   'nycCoronavirus',
#   'CoronavirusNewYork',
#   'OhioConservatives',
#   '350',
#   'GeorgiaUS',
#   'AtlantaPolitics',
#   'USElectionPrediction',
#   'vote',
#   'VotingRights',
#   'youthvote',
#   '2016Elections',
#   '2016_elections',
#   'WhiteHouse2020',
#   'LosAngelesStonks',
#   'ohiopolitics',
#   'californiapolitics',
#   'bipartisanSolutions',
#   'dementia',
#   'KeepOurNetFree',
#   'BipartisanNews',
#   'democratic_socialists',
#   'capitolhill',
#   'confederateflags',
#   'bipartisanship',
#   'DemocracyNeedsFixing',
#   'HowHumanBeingsWork',
#   'VotingReform',
#   'votingtheory',
#   'facebook',
#   'hemp',
#   'GorillaReddit',
#   'Rwanda',
#   'flavortown',
#   'coloradoteens',
#   'Cello',
#   'Bowling',
#   'diabetes',
#   'RedditTimeCapsule',
#   'books',
#   'cork',
#   'Library',
#   'LGBTCatholic',
#   'exIglesiaNiCristo',
#   'Popefacts',
#   'warriors',
#   'Cyberdelinaut',
#   'inventors',
#   'Interesting_Shit',
#   'GoodNewsNews',
#   'SomePositiveInYourDay',
#   'Americans',
#   'HealMovement',
#   'rewilding',
#   'biodiversity',
#   'ScotlandPorn',
#   'over60reddit',
#   'bee',
#   'YourPestLife',
#   'oilandgas',
#   'oil',
#   'GlobalPolitics',
#   'worldnews247',
#   'europeans',
#   'amarillo',
#   'Pets',
#   'TeenMomOGandTeenMom2',
#   'CountryTimes',
#   'Essay_Tips_Tricks',
#   'ClimateTakeBack',
#   'Cowwapse',
#   'octopusagiletariff',
#   'singularity',
#   'regenerate',
#   'optometry',
#   'fantasyfootball',
#   'MURICANEWS',
#   'flowers',
#   'tech',
#   'conservation',
#   'landconservation',
#   'WaterTreatment',
#   'BottleNeck',
#   'FacebookReplacement',
#   'GreenBayPackers',
#   'VisitBrazil',
#   'oneanddone',
#   'Butterflies',
#   'weather',
#   'portugal',
#   'TraditionalShamanism',
#   'SeaShepherd',
#   'AnimalIntelligence',
#   'poland',
#   'Armadillo',
#   'Cheetahs',
#   'AnarquismoBrasil',
#   'northernireland',
#   'CCPwatch',
#   'UmbrellaAcademy',
#   'Real_Sikhi',
#   'revolutionaryculture',
#   'AskAChristian',
#   'ExPentecostal',
#   'pharmacy',
#   'Twitter',
#   'TenMinutePodcast',
#   'YouWillSurviveIt',
#   'albania',
#   'peace',
#   'anchorage',
#   'WPI',
#   'PerfectSystem',
#   'millenials',
#   'GroceryStores',
#   'CoronavirusOC',
#   'USF',
#   'NYCbike',
#   'Colts',
#   'UnexpectedCommunity',
#   'greece',
#   '2MiddleEast4you',
#   'urbanplanning',
#   'Rochester',
#   'upstate_new_york',
#   'casualEurope',
#   'the1975',
#   'lastimages',
#   'RepublicadeChile',
#   'Reno',
#   'recycling',
#   'Scottsdale',
#   'capetown',
#   'lasers',
#   'NewYorkCityResidents',
#   'KansasPolitics',
#   'Columbus',
#   'LIHKG',
#   'Taiwancirclejerk',
#   'maritime',
#   'nycrail',
#   'kurdistan',
#   'Positive',
#   'JacksFilms',
#   'tangentiallyspeaking',
#   'YoureWrongAbout',
#   'techdetects',
#   'ASTSpaceMobile',
#   'AnywhereButAmazon',
#   'Animatronics',
#   'FoodDeliveryRobots',
#   'bharat',
#   'aws',
#   'Ghost_in_the_Shell',
#   'bestarticles',
#   'ItalyInformatica',
#   'pancakeswap',
#   'apdm',
#   'LaCarcaza',
#   'clubhouse',
#   'whatsapp',
#   'android_devs',
#   'michigantraders',
#   'GlobalTribe',
#   'revragnarok',
#   'ForwardThinkingJasper',
#   'solarstocks',
#   'srilankacomputing',
#   'workfromhome',
#   'Nextlevelbabysitting',
#   'IOPsychology',
#   'StupidFatAmericansSay',
#   'tdi',
#   'nanocurrency',
#   'ukcrypto',
#   'notArgentina',
#   'TechnicalMind',
#   'noip',
#   'DevsJunky',
#   'DoughProbe',
#   'billgates',
#   'ATT',
#   'Oligopolies',
#   'homeland',
#   'TikToksucks',
#   'CysticFibrosis',
#   'Benzofamily',
#   'GarbageHeap',
#   'ExroTechnologies',
#   'EnvironmentalScience',
#   'renewableenergystocks',
#   'IGN',
#   'borderlands3',
#   'WeAreTheMusicMakers',
#   'acousticecology',
#   'privacytoolsIO',
#   'PaidPhotography',
#   'hagerstown',
#   'OculusQuest',
#   'PublicEthics',
#   'HorrorsOfBigTech',
#   'the_bad_place',
#   'TikTokVoices',
#   'HaShoah',
#   'thehatedone',
#   'quefaitlapolice',
#   'TaiwanNews',
#   'treeplanting',
#   'watch_dogs',
#   'Wordpress',
#   'mac',
#   'skipthedishes',
#   'uber',
#   'UBreddit',
#   'XRP',
#   'Particl',
#   'TheAdventuresofTB',
#   'ReformJews',
#   'whiteHatSr',
#   'GoNuclearNow',
#   'cyberlaws',
#   'degoogle',
#   'ubi',
#   'businessnews',
#   'fcc',
#   'kansas',
#   'AutonomousNews',
#   'newyorknews',
#   'fuckatt',
#   'GoNetspeed',
#   'sherwinwilliams',
#   'mega64',
#   'Namibia',
#   'Amberfossil',
#   'humor',
#   'RKG',
#   'CurrentGeek',
#   'scouting_electric',
#   'fusionnews',
#   'cricut',
#   'CricutButCrass',
#   'discdyeing',
#   'privacy',
#   'linux',
#   ...],
#  ['DarkViperAU',
#   'ems',
#   'Veryfuckingstupid',
#   'KGBTR',
#   'OGoogleReaders',
#   'NoEvidenceNoCrime',
#   'TIHI',
#   'mildlyinfuriating',
#   'Idiotswithguns',
#   'Mujico',
#   'InternetCommentEtiq',
#   'h3h3productions',
#   'Honkyandthebadger',
#   'AbruptChaos',
#   'yourmomshousepodcast',
#   'doordash_drivers',
#   'copoverde',
#   'IdiotsFightingThings',
#   'nonononoyes',
#   'TheLeagueOfMorons',
#   'WHATYOUFUCKINGDESERVE',
#   'Seenthatcoming',
#   'jakeandamir',
#   'IThinkYouShouldLeave',
#   'Scrubs',
#   'comedybangbang',
#   'golf',
#   'poker',
#   'ukgaybros',
#   'HeavyMetalAndOrgies',
#   'Romania_B',
#   '321',
#   'OneyPlays',
#   'DangelsHub',
#   'Dominos',
#   'wineandcrimepodcast',
#   'KumoDesu',
#   'couriersofreddit',
#   'KitchenConfidential',
#   'starbucks',
#   'AirForce',
#   'CartoonMoment',
#   'HyphonixRS',
#   'incrediblyinfuriating',
#   'Professors',
#   'surfing',
#   'quin69',
#   'Frostpunk',
#   'MrRobot',
#   'Kenya',
#   'SuddenlyGay',
#   'nursing',
#   'Frenemies',
#   'UnexpectedlyWholesome',
#   'WeEatBees',
#   'AdmiralBulldog',
#   'leptongirisim',
#   'teenagersnew',
#   'NewLondonCounty',
#   'CasualUK',
#   'okmatewanker',
#   'CountDankula',
#   'premed',
#   'publix',
#   'LegalEagle',
#   'noyoucantwatch',
#   'americandad',
#   'FargoTV',
#   '13or30',
#   'cannabisconisuier',
#   'aretheNTsokay',
#   'Accounting',
#   'Bozeman',
#   'UnexpectedMulaney',
#   'OnCinemaAtTheCinema',
#   'TheBoys',
#   'CultureShipNames',
#   'FUCKYOUINPARTICULAR',
#   'Debate',
#   'TfwYouLiveInMexico',
#   'premiuminternet',
#   'Chadtopia',
#   'drugscirclejerk',
#   'LunaNegra',
#   'gay_irl',
#   'immafuckthisdolphin',
#   'Neverbrokeabone',
#   'AwfulNature',
#   'dannygroen',
#   'Fleabag',
#   'SweatyPalms',
#   'Pikabu',
#   'Nuthinbuttrouble',
#   'therewasanattempt',
#   'LooneyTunesLogic',
#   'MyPeopleNeedMe',
#   'BakaNewsJP',
#   'funnyvideos',
#   'shooting_stars',
#   'Mizkif',
#   'ItsRainingMemes',
#   'AAAAAAAAAAAAAAAAA',
#   'Merdeumane',
#   'donthelpjustfilm',
#   'ReptiloidsLeague',
#   'blockchainio',
#   'TheLonelyStoner',
#   'metal_me_irl',
#   'AvatarMemes',
#   'nevertellmetheodds',
#   'yesyesyesyesno',
#   'VideosPraVerChapado',
#   'noisygifs',
#   'whatcouldgoright',
#   'ANormalDayInRussia',
#   'crosovinisti',
#   'AltitudeSickness',
#   'popping',
#   'CapuSEEno',
#   'MakeMeSuffer',
#   'JustThinkAbout',
#   'riskofrain',
#   'DunderMifflin',
#   'HolUp',
#   'Shittyaskflying',
#   'freeflight',
#   'TrashTaste',
#   'burgers_and_sushi',
#   'Colombia',
#   'lebowski',
#   'dontlookdown',
#   'MichaelReeves',
#   'FreeKarma4U',
#   'stabbot',
#   'Target',
#   'Mommit',
#   'watchthingsfly',
#   'HVAC',
#   'OnlyFans',
#   'dumaflache',
#   'tiltshift',
#   'NNUCS',
#   'zblinks',
#   'AZCardinals',
#   'killthecameraman',
#   'FortniteCompetitive',
#   'magictavern',
#   'Epicentr',
#   'TarkovMemes',
#   'Sekiro',
#   'MxRMods',
#   'killitwithfire',
#   'hmm',
#   'PavelQualityMemes',
#   'cyberpunkgame',
#   'AccidentalSlapStick',
#   'WatchAnimalsDieInside',
#   'CloakFolk',
#   'forza',
#   'TrackMania',
#   'BeamNG',
#   'maybemaybemaybemaybe',
#   'yesyesyesno',
#   'IrrationalMadness',
#   'abruptbears',
#   'dolphinconspiracy',
#   'motorcycles',
#   'Amry',
#   'BicyclingCirclejerk',
#   'Instantregret',
#   'wildlyinfuriating',
#   'videosthatendtoosoon',
#   'DownloadVideo',
#   'Whatcouldgowrong',
#   'FakeRemakes',
#   'instantkarma',
#   'holdmybraincells',
#   'OneLessDirtbag',
#   'instantbarbarians',
#   'WatchPeopleKillInside',
#   'holdmyfries',
#   'FirstNameBasis',
#   'MXRplays',
#   'lunzen',
#   'PeopleYeetingAnimals',
#   'watchpeoplealmostdie',
#   'killedthecameraman',
#   'RussNews',
#   'ThatLookedExpensive',
#   'IdiotsOnBikes',
#   'holdmycosmo',
#   'UpvoteBecauseButt',
#   'suddenlycaralho',
#   'FullShrimp',
#   'WhyWereTheyFilming',
#   'watchpeoplesurvive',
#   'GTAorRussia',
#   'Hirnschiss',
#   'GradualChaos',
#   'gtaonline',
#   'Idiots',
#   'akagas',
#   'NewJerseyFreakshow',
#   'ryryandtay',
#   'StopResisting',
#   'sandiego',
#   'blackpeoplegifs',
#   'KidsAreFuckingEvil',
#   'holdmyjuicebox',
#   'gifsthatendtoosoon',
#   'Bestbuy',
#   'suddenlysexoffender',
#   'shockwaveporn',
#   'ShitPile',
#   'peopledyinginside',
#   'blackfathers',
#   'JustGuysBeingDudes',
#   'DynamicBanter',
#   'ummumm',
#   'AccidentalTerrorism',
#   'WhyWomenLiveLonger',
#   'dumbasseswithlighters',
#   'MakeMyCoffin',
#   'HeheMoment',
#   'RussaorGTA',
#   'russianorgta',
#   'IdiotsInBoats',
#   'mesodumb',
#   'robberiesgonewrong',
#   'apolloapp',
#   'StrangeAndFunny',
#   'tookjustenough',
#   'fut',
#   'AdultsAreFuckinStupid',
#   'tooktoomuch',
#   'ExpensiveAccidents',
#   'holdmyfuckingteeth',
#   'CrazyFuckingVideos',
#   'ZeroFucksWereGiven',
#   'DenseGifs',
#   'StoicMemes',
#   'arkamahalle',
#   'gta_irl',
#   'humansarespaceorcs',
#   'natesshitposthub',
#   'moreofmytrash',
#   'thelauras',
#   'Crainn',
#   'perfectlycutscreams',
#   'claustrophobia',
#   'WalmartCelebrities',
#   'ContagiousLaughter',
#   'CinnamonToastKen',
#   'TikTokCringe',
#   'TikTokHumor',
#   'justforsocialmedia',
#   'GifsYouCanHear',
#   'Oof',
#   'HIMYM',
#   'PlayItAgainSam',
#   'xTheGermanReich_II',
#   'AccidentalShoeLoss',
#   'retardsinaction',
#   'Ulta',
#   'upvotebecausebear',
#   'holdmyfeedingtube',
#   'titleporn',
#   'IdiotsOnMotorcycles',
#   'CrazyHuman',
#   'KidsAreCondomAds',
#   'videoswithsubtitles',
#   'AllGasNoBrakes',
#   'constantchaos',
#   'Fireworksgonewrong',
#   'NotTimAndEric',
#   'skiing',
#   'AbruptComposure',
#   'STJFH',
#   'mostrepostedposts',
#   'ProperPublicFreakout',
#   'AllFantasyEverything',
#   'black_humor',
#   'bangladesh',
#   'DailyLiveThread',
#   'Killadrix',
#   'KarmaForBrats',
#   'idiotsoutofcars',
#   'TFABAARBI',
#   'whatisthiscar',
#   'FuckeryUniveristy',
#   'lossofalovedone',
#   'PaymoneyWubby',
#   'GTAorRealLife',
#   'GTAorJapan',
#   'CoronavirusMemes',
#   'JustLearnedTheFWord',
#   'sdohni_blyat',
#   'donttrythisinreallife',
#   'AssholesInCars',
#   'WalgreensStores',
#   'consulting',
#   'ericandre',
#   'DunningKruger',
#   'KnotTwoBrite',
#   'LaschesTeilen',
#   'perfectlycutyeets',
#   'DadReflexes',
#   'wrestling',
#   'waitforit',
#   'KingOfTheHill',
#   'FuckGavyn',
#   'Imacasual',
#   'facingtheirparenting',
#   'Wrasslin',
#   'FunnyAnaesthesia',
#   'ScriptedCaucasianGIFs',
#   'cestlarigolade',
#   '911FOX',
#   'TerminallyStupid',
#   'karensincars',
#   'stupidpeople',
#   'Justfuckmyshitup',
#   'WholesomeMetalheads',
#   'darkmast3r',
#   'coltonsmemes',
#   'mmamemes',
#   'fuckyouimatoddler',
#   'literally',
#   'bonkedthefuckout',
#   'VideosMP4',
#   'ParentsAreFuckingDumb',
#   'normaldayinrussia',
#   'WatchDogsDieInside',
#   'WatchDogsWoofInside',
#   'humour',
#   'upvotebecauseboobs',
#   'gifsyoucanfeel',
#   'tall',
#   'teamsteil',
#   'FunnyandSad',
#   'BitchImATrain',
#   'Multicopter',
#   'funnysigns',
#   'thatescalatedquickly',
#   'misc',
#   'AnyAll',
#   'tuglife',
#   'saintmartin',
#   'theyknew',
#   'MoronsInAction',
#   'untrustworthypoptarts',
#   'BerenBierBrigade',
#   'idiotinfluencers',
#   'livesound',
#   'EDM',
#   'aves',
#   'Carola',
#   'Trainwreckstv',
#   'Spoopychatmemes',
#   'aikido',
#   'Horsetrash',
#   'FuckingWithNature',
#   'BossFights',
#   'HypixelSkyblock',
#   'metalgearsolid',
#   'unexpecteddarksouls',
#   'dogswithweapons',
#   'Naruto',
#   'Tendies',
#   'HoldMyBreedingTube',
#   'iiiiiiitttttttttttt',
#   'donttellmetheodds',
#   'scody15',
#   'ANormalDayInIndia',
#   'AlienVsVigilante',
#   'FunnyASF',
#   'DustyLookatThis',
#   'oopsotherhand',
#   'cursedcomments',
#   'theseMenAreNihilists',
#   'HomeDepot',
#   'CVS',
#   'Serverlife',
#   'Satan',
#   '2mad4madlads',
#   'chaoticneutral',
#   'voidpunk',
#   'THUITFHNGL',
#   'loveafterlockup',
#   'Sysadminhumor',
#   'DarwinAwards',
#   'OopsDidntMeanTo',
#   'TrollXFunny',
#   'drugmemes',
#   'BobsBurgers',
#   'HydroKittys',
#   'suddenlytractor',
#   'gank',
#   'fakedisordercringe',
#   'noita',
#   'unexpectedoffice',
#   'SpittinChicletsPod',
#   'Frugal_Jerk',
#   'xqcow',
#   'sousvide',
#   'onlyinrussia',
#   'funny_and_useful',
#   'nightmareonfilmstreet',
#   'Solus_International',
#   'ShittyLifeProTips',
#   'Assholesome',
#   'SmalltownBignews',
#   'greatestgen',
#   'Waterisfuckingstupid',
#   'PissDawgs',
#   'MoldyMemes',
#   'DrinkingProblems',
#   'SuddenlyTrans',
#   'ibs',
#   'LinusTechTips',
#   'Hadusinthefirsthalf',
#   'RandomCrap4teens',
#   'uselessredcircle',
#   'WuerfelAufEins',
#   'NLSSCircleJerk',
#   'EDanonymemes',
#   'FuckCilantro',
#   'ShittyGifRecipes',
#   'StupidFood',
#   'rgbroachgang',
#   'AccidentalRacism',
#   'FuckCaillou',
#   'FUCKINGINFURIATING',
#   'gusjohnson',
#   'UlcerativeColitis',
#   'smoking',
#   'polyamory',
#   'AlanPartridge',
#   'Tiresaretheenemy',
#   'MarriedAtFirstSight',
#   'Bullshido',
#   'MaladaptiveDreaming',
#   'WetlanderHumor',
#   'TheDickShow',
#   'BPDmemes',
#   'Yogscast',
#   'poopisland',
#   'loopdaddy',
#   'poopshitters',
#   'dailyspam',
#   'ShitCrusaderKingsSay',
#   'Cruise',
#   'RhodeIsland',
#   'bih',
#   'cursedfoods',
#   'TheDuccCult',
#   'DucksOvertaking',
#   'CraftBeer',
#   'GeburtstagsPenis',
#   'BUENZLI',
#   'workingmoms',
#   'LowSodiumCyberpunk',
#   'GhostRecon',
#   'Stillgame',
#   'Unexpected',
#   'Yointerneto',
#   'Caliebre',
#   'thabeast721',
#   'BBQ',
#   'RubeGoldbergFails',
#   'vivihyun',
#   'suddenlybi',
#   'Expected',
#   'cobrakai',
#   'YeetingKids',
#   'WarOwl',
#   'DanishEnts',
#   'AbruptCalm',
#   'ArsenalFC',
#   'Asparagoose',
#   'Hatfilms',
#   'NeonGenesisEvangelion',
#   'directorsondrugs',
#   'EnjoyableReposts',
#   'Funnystuffiwanttosabe',
#   'Funesto',
#   'tamperstew',
#   'imodernleaf',
#   'NANIKPosting',
#   'VredditDownloader',
#   'UnexpectedLetterkenny',
#   '4x4',
#   'ATV',
#   'Crossout',
#   'nopeswings',
#   'GirlsOnRopeSwings',
#   'ropeswingfails',
#   'Adguessr',
#   'EverythingsAnAd',
#   'perfectlycutgags',
#   'HuntersRUS',
#   'FishingHunting',
#   'HuntingFishingCamping',
#   'fountainpens',
#   'pens',
#   'Unexpectedkittens',
#   'short',
#   'shortguytallgirl',
#   'Im15AndThisIsYeet',
#   'dailydoseofinternet',
#   'unexpecteddopamine',
#   'thepbgb',
#   'Peopleareactuallygood',
#   'Storageformereeeee',
#   'VideosWithSound',
#   'CasualJamming',
#   'akalimains',
#   'Squirkyly',
#   'michaelbaygifs',
#   'combinedgifs',
#   'unexpectedjihad',
#   'PietSmiet',
#   'narutomemes',
#   'MarkRober',
#   'ThingsThatBlowUp',
#   'ExtremeCarCrashes',
#   'stalker',
#   'bitchimabus',
#   'forkliftmemes',
#   'HitboxPornIRL',
#   'nextlevel',
#   'forklift',
#   'PerfectlyCutBooms',
#   'ButterTeeth',
#   'wandbrot',
#   'leveledupidiots',
#   'Dubsmb',
#   'skilledidiotsincars',
#   'NormalDayInIndia',
#   'scriptedasiangifs',
#   'PlotTwist',
#   'Baxov',
#   'fixedbytheduet',
#   'HomeCams',
#   'CatsareFake',
#   'unexpectedhogwarts',
#   'electricians',
#   'Stepdadreflexes',
#   'ChildrenFallingOver',
#   'magicthecirclejerking',
#   'BadDesigns',
#   'onejob',
#   'programminghumor',
#   'squarehole',
#   'ozzonepazzopazzopazzo',
#   'DSL_Shitposting',
#   'techienonsense',
#   'ShuumatsuNoValkyrie',
#   'PepegaSquad',
#   'GenerationZeroGame',
#   'jovemnerd',
#   'birthofasupervillain',
#   'Custodians',
#   'SCPSecretLab',
#   'Holthefuckup',
#   'ThatWasFuckingEpic',
#   'Felps',
#   'TISP',
#   'vidheheos',
#   'TheBrightSide',
#   'BetterMUA',
#   'Potterless',
#   'TheBeardedCollection',
#   'womenmoment',
#   'allFunnies',
#   'DaFuckIJustWatched',
#   'doggoslife',
#   'zvedatori',
#   'YikikSoccer',
#   'AAAAAAAAA',
#   'judo',
#   'DopamineDonations',
#   'Egg',
#   'meth',
#   'Akkaiverso',
#   'Orochisegundo',
#   'datamoshing',
#   'Gittertiere',
#   'mountainbiking',
#   'petthedamnshark',
#   'Slazo',
#   'TimberAndMetals',
#   'TimingWasPerfect',
#   'Buttpucker',
#   'SlipperyPickles',
#   'StupidActsOfGenius',
#   'stupidbutimpressive',
#   'SAoG',
#   'Ankit_bhai_ko_sub',
#   'OneTrip',
#   'dad',
#   'DaddyDawsonsDungeon',
#   'WholesomeCatfish',
#   'IncreasinglyWeird',
#   'Apexrollouts',
#   'nononoyesno',
#   'Noyesnoyesnono',
#   'OEOI',
#   'BulienJam',
#   'yesnoyesno',
#   'TheZiomBgamerGulag',
#   'Kidsarefuckingbrutal',
#   'DanceDanceRevolution',
#   'skateboardcirclejerk',
#   'surprisespiderman',
#   'AccidentalSlap',
#   'Spectrum',
#   'ShittyThumbsUp',
#   'An_Axe_For_The_Weary',
#   'Valhala',
#   'Seattle2k',
#   'FireFriends',
#   'suddenlyonfire',
#   'shuffle',
#   'YEET',
#   'BikiniBottomTwitter',
#   'Warzone',
#   'ItsButtercup',
#   'yesyesnoyes',
#   'cursedvideos',
#   'geckos',
#   'DungeonsAndDaddies',
#   'ties',
#   'ShamelessCaptures',
#   'ChratosGameplay',
#   'japads',
#   'accidentalwrestling',
#   'PlayerTwo',
#   'unexpecteddoggo',
#   'AnimalSlapstick',
#   'Getdownmrpresident',
#   'FactsAboutWasps',
#   'yesyesyesnoyes',
#   'ChampagneFails',
#   'HumansGettingLucky',
#   'idiotswithchampagne',
#   'justa',
#   'upvote',
#   'GooglyEyes',
#   'ticmemes',
#   'CanadaHunting',
#   'BottleDisService',
#   'perfectlycutwhaa',
#   'perfectlycutwaas',
#   'Lowes',
#   'farts',
#   'SuchaDadThing',
#   'Leonhart',
#   'whattypeofcheese',
#   'CaptainTsubasaDT',
#   'footballmemes',
#   'Rojankhzxr',
#   'HoopMe',
#   'Antimassesteihalter',
#   'accidentalmadmax',
#   'PlayingWithFire',
#   'BurningAsFuck',
#   'highsupply',
#   '9999999999999999999',
#   'suspectthecameraman',
#   'RaidShadowLegends',
#   'SustainedChaos',
#   'level20',
#   'HoldMyCoolCompress',
#   'holdmybeer',
#   'GodHatesYou',
#   'BrosPanicking',
#   'FuckingIdiot',
#   'qcBoneHeads',
#   'duckydeesubmissions',
#   'Niiiice',
#   'BadChoicesWithOscar',
#   'FakeMartialArts',
#   'degeneradosnozap',
#   'DankAndrastianMemes',
#   'Serotonin_',
#   'kidsfallingdown',
#   'Helmet',
#   'ridiculousness',
# ...
#   'MuslimMarriage',
#   'DesiTwoX',
#   'SouthAsianMasculinity',
#   'Kerala',
#   'IndiaDivine',
#   'chinesefood',
#   'Vegan_Food',
#   'ARLAW',
#   'BollyBlindsNGossip',
#   'AgainstHinduphobia',
#   'india',
#   'TamilNadu',
#   'shitbjpdoes',
#   'mangalore',
#   'CoronavirusIndia',
#   'IndiaUnchained',
#   'COVID_19India',
#   'shitbjpsays',
#   'anarchyindia',
#   'eww',
#   'PassportPorn',
#   'indianhistoryporn',
#   'DHSavagery',
#   'MarathiAsmita',
#   'MarathiMemes',
#   'shahanpana',
#   'MarathiMantra',
#   'MarathiMeme',
#   'MemesMarathi',
#   'IndianNewsBias',
#   'TheSubcontinent',
#   'AnimalRightsAdvocates',
#   'TheNewActivist',
#   'Yucatan',
#   'Krodh',
#   'Samaj',
#   'bollywood',
#   'hindu',
#   'unexpecteddiscworld',
#   'EAjobs',
#   'shaivism',
#   'TeaPictures',
#   'IndianFoodPhotos',
#   'VeganFoodPorn',
#   'TeaPorn',
#   'budgetfood',
#   'TopSecretRecipes',
#   'veganart',
#   'cmmreddit',
#   'AskAnAntinatalist',
#   'areweinhell',
#   'insaneparents',
#   'conflictresolution',
#   'AskVegans',
#   'VeganDiscussion',
#   'CornStalk',
#   'yrwnova',
#   'veganuk',
#   'VegRecipes',
#   'Nicecream',
#   'herbs',
#   'vegancheesemaking',
#   'vegancheese',
#   'drunkvegans',
#   'DrunkVegan',
#   'omadvegan',
#   'VeganWeightGain',
#   'Cheesitarian',
#   'vegetarianrecipes',
#   'vegetarianfoodporn',
#   'evopsych',
#   'SecularHumanism',
#   'urdupoetry',
#   'Showerthoughts',
#   'Workstress',
#   'Soulism101',
#   'HindutvaRises',
#   'BirthandDeathEthics',
#   'asianfood',
#   'Chandigarh',
#   'worldpoliticalhumour',
#   'CFB',
#   'sterilization',
#   'Anarcho_Antinatalism',
#   'IntersectionalAntiCap',
#   'YourVeganFallacyIs',
#   'VeganUSA',
#   'Recipe_Redux',
#   'u_AnyCalligrapher9430',
#   'IndiaInfrastructure',
#   'Chennai',
#   'Bhagwa_Feminism',
#   'FascistIndianLeft',
#   'AnandaBanga',
#   'IndianMeyMeys',
#   'TheSouthAsia',
#   'Virathindumemes',
#   'indiapolicy',
#   'dankinindia',
#   'politicalhinduism',
#   'WesternHinduphobia',
#   'indianpeoplequora',
#   'IndiaPoliticalBridges',
#   'RightWingIndia',
#   'wildfires',
#   'oldindia',
#   'BharatasyaItihaas',
#   'whycobraliveslonger',
#   'unitedstatesofindia',
#   'NewDelhi',
#   'JammuandKashmir',
#   'jammu',
#   'JammuKashmir',
#   'kolkata',
#   'Vyabhichari',
#   'Rayta',
#   'MaulanaGobhi',
#   'banFascistBJP',
#   'MudiRejine',
#   'BobsBurgersCreations',
#   'irishfood',
#   'Bacon',
#   'burgers',
#   'Parkinggonewild',
#   'KeralaSpeaks',
#   'Pizza',
#   'eatsandwiches',
#   'MozzarellaPorn',
#   'u_strillointhebox',
#   'VeganFood',
#   'RecipeCollection',
#   'dairyfreerecipes',
#   'Vegan__Sensei',
#   'xenofeminism',
#   'Pessimism',
#   'kreisvegs',
#   'Lendinghand',
#   'karnataka',
#   'canconfirmiamindian',
#   'IndiansRead',
#   'chineserecipes',
#   'MealPics',
#   'RateMyPlate',
#   'TastyFood',
#   'AmateurFoodPorn',
#   'tonightsdinner',
#   'Cheap_Meals',
#   'mexicanfood',
#   'Swatantra',
#   'VeganFashion',
#   'CellularAgriculture',
#   'Veganity',
#   'VeganVideos',
#   'watchingcongress',
#   'VeganAnarchistPOC',
#   'cozumel',
#   'QuintanaRoo',
#   'mauritius',
#   'WouldYouRather',
#   'Frugallearning',
#   'Mayan',
#   'tacos',
#   'chichenitza',
#   'tncovid19',
#   'BonkersBusiness',
#   'tamil',
#   'chennaicity',
#   'ramen',
#   'FarmBill',
#   'independentmusic',
#   'youdontmattergiveup',
#   'nihilistmemes',
#   'fuckHOA',
#   'running',
#   'VeganBeauty',
#   'DebateAVegan',
#   'Veganforbeginners',
#   'HealthyEatingnow',
#   '15minutefood',
#   'Vegetarianism',
#   'ISKCON',
#   'TheRamayana',
#   'RamaBhajans',
#   'HinduTemplesRock',
#   'HinduArt',
#   'JaiShreeRam',
#   'bhajan',
#   'ShivaBhajans',
#   'HinduDiscussion',
#   'placesofworship',
#   'IndianArtAndThinking',
#   'BollywoodFashion',
#   'EatLessMeat',
#   'ElvenFood',
#   'budgetcooking',
#   'PutAnEggOnIt',
#   'bachelorchef',
#   'TemplesHindu',
#   'SHIVA',
#   'Uttarakhand',
#   'ChinmayaMission',
#   'Sadhguru',
#   'icm',
#   'KrishnaConsciousness',
#   'animalwelfarescience',
#   'NonHumanCommunication',
#   'veganJews',
#   'VeganInCanada',
#   'veganhatecirclejerk',
#   'VeganChat',
#   'VegansOfFaith',
#   'UKvegan',
#   'ARActivism',
#   'AntiVirals',
#   'HerbalMedicine',
#   'FoodIsMedicine',
#   'planetbaseddiet',
#   'u_meghnadasodissi',
#   'DailyHistoryIndia'],
#  ['HydroHomies',
#   'AntiHateCommunities',
#   'nestledidnothingwrong',
#   'pakistan',
#   'trailerparkboys',
#   'indianmuslims',
#   'Muslim',
#   'TheUnitedUmmah',
#   'waterbros',
#   'thepaknarrative',
#   'subvertising',
#   'Ummah',
#   'PanIslamistPosting',
#   'CaliphateRestoration',
#   'chutyapa',
#   'DeathtoIsraHell',
#   'noscrapleftbehind',
#   'goldhoard',
#   'wherecanibuythis',
#   'MadMax',
#   'catscantdrink',
#   'elkaybattlestations',
#   'clamswithjobs',
#   'GifRecipes',
#   'vegangifrecipes',
#   'ketodrunk',
#   'intermittentfasting',
#   'fasting',
#   'Izlam',
#   'kitchentalk',
#   'CheeseburgerClub',
#   'woocancook',
#   'HealthyGifRecipes',
#   'GFRecipeGifs',
#   'BGRecipes',
#   'MexicanFoodGore',
#   'glutenfreerecipes',
#   '0000zxcv',
#   'BasicallyHomeless',
#   'ketotrees',
#   'pallascatfans',
#   'ketobeginners',
#   'MorgansCookbook',
#   'AnimeFood',
#   'ShokugekiNoSoma',
#   'ratelrecipes',
#   'MuffinEats',
#   'sanjiskitchen',
#   'SushiAbomination',
#   'highvegans',
#   'badatfocusing',
#   'onionhate',
#   'KarlsRecipeSub',
#   'AcquiredTastes',
#   'anneandreese',
#   'AbsentAgony',
#   'ketorecipes',
#   'irl_error',
#   'moneymonkies',
#   'osmlkdengoso',
#   'MekkanikLearns',
#   'WastelandRecipeBook',
#   'Bento',
#   'NicksRecipes',
#   'YushisoRecipes',
#   'recipegifs',
#   'shitwithcheese',
#   'SuccessionTV',
#   'Sourdough',
#   'smoothbrain',
#   'habie',
#   'AIP_Recipes',
#   'cowboybebop',
#   'dbz',
#   'onepotmeals',
#   'StopOnlineAntisemitsm',
#   'Archaeology',
#   'shia',
#   'uncharted',
#   'muslimculture',
#   'ProductPorn',
#   'psg',
#   'fulbo',
#   'Bolehland',
#   'oakland',
#   'HydroHomiesBeingBros',
#   'bassnectar',
#   'IF_Petites',
#   'hisdarkmaterials',
#   'PoliticalMompassCemes',
#   'CICO',
#   'gravityfalls',
#   'Syracuse',
#   'altcoinforum',
#   'Gunners',
#   'LICENSEPLATES',
#   'deletespain',
#   'metaldetecting',
#   'lcfc',
#   'MobKitchen',
#   'WholeFoodsPlantBased',
#   'cadernodereceitas',
#   'FatMoms',
#   'AlternateDayFasting',
#   'raspberry_pi',
#   'ArduinoProjects',
#   'ScamHomeWarranty',
#   'memesofthedank',
#   'AskOuija',
#   'fullwordlicenseplates',
#   'Water_Fasting',
#   'FajrCompanion',
#   'Halal_Competitions',
#   'converts',
#   'pakistanimemes',
#   'NUFC',
#   'PSA',
#   'ConspiracyProgramming',
#   'CARiverPlate',
#   'QuranFirstIslam',
#   'ussoccer',
#   'pirates',
#   'Kasheer',
#   'Kashmiri',
#   'AgainstHateSubreddits',
#   'soccer',
#   'tipofmytongue',
#   'LiverpoolFC',
#   'future_fight',
#   'LegendsOfTomorrow',
#   'pureasoiaf',
#   'civbattleroyale',
#   'Dipcifica',
#   'rant',
#   'rbny',
#   'ShitRedditSays',
#   'BeautyGuruChatter',
#   'talkingheads',
#   'Xyyz',
#   'CatInTheHatMemes',
#   'NYCFC',
#   'offmychest',
#   'ismailis',
#   'AgainstAHSubreddits',
#   'cavetown',
#   'Overseas_Pakistani',
#   'saboyz',
#   'transgenderteens',
#   'ryangosling',
#   'transtimelines',
#   'cyberpunk_stories',
#   'coys',
#   'reddevils',
#   'SportingCP',
#   'LeedsUnited',
#   'Hammers',
#   'ACMilan',
#   'exreddevil',
#   'coybig',
#   'ccfc',
#   'coincidence',
#   'BocaJuniors',
#   'FantasyPL',
#   'avfc',
#   'SeleccionArgentina',
#   'football',
#   'TopRightMessi',
#   'SCJerk',
#   'mainz05',
#   'MLS',
#   'Morganeisenberg',
#   'AllDeliciousRecipes',
#   'GifRecipesKeto',
#   'cookingvideos',
#   'gifrecipeshealthy',
#   'Against_Genocide',
#   'MuslumanTurk',
#   'wholesomechina',
#   'bluepillorredpill',
#   'ChinaIsAssHoe',
#   'islamichistory',
#   'MateriaIslamica',
#   'muslims',
#   'Quran',
#   'Recitation',
#   'Tiele',
#   'Natsikap',
#   'PakGamers',
#   'TrueAntiHateCommunity',
#   'NestleLove',
#   'AntiHateEverything',
#   'AntiSemitismInReddit',
#   'AntiIsraelBigotry',
#   'StanKelly',
#   'traandwagon',
#   'history',
#   'EflPalestine',
#   'subredditcancer',
#   'adbusters',
#   'Cooking',
#   'CandyMakers',
#   'story',
#   'ketoaustralia',
#   'South_Asia_Geopolitik',
#   'u_WooCanCook',
#   'OaklandFood',
#   'RobinHood',
#   'slowcooking',
#   'Siapproved',
#   'ketodieting',
#   'Keto_Diet',
#   'lowcarb',
#   'KetoMeals',
#   'Ketodietbeginners',
#   'keto_food_log',
#   'EasyKetoMeal',
#   'ketogenicdiet',
#   'ketosis',
#   'KetoSnacks',
#   'KetoFoodPorn',
#   'ketoporn',
#   'Keto_Maintenance',
#   'ketogenic',
#   'u_rightcoastguy',
#   'LearnQuranOnline',
#   'SPEAKtruth',
#   'CrusadesMemes',
#   'KitsForFootball',
#   'eastbay',
#   'SalafisUnveiled',
#   'PakistaniTech',
#   'PremierLeague',
#   'Jay_Talg',
#   'MilenaCiciottiSnark2',
#   'SashaShectman',
#   'SportingKC',
#   'EsotericIslam',
#   'exatheist',
#   'AntiAHS',
#   'averageredditor'],
#  ['fosscad',
#   'SurreyBC',
#   'yorku',
#   'CCW',
#   'CarletonU',
#   'AcadiaU',
#   'Glocks',
#   'ak47',
#   'CursedGuns',
#   'czscorpion',
#   'DIYGuns',
#   'GunnitRust',
#   'NFA',
#   'McMaster',
#   'USPSA',
#   'longrange',
#   'AR10',
#   'gunsmithing',
#   'Shooting',
#   'ISSF',
#   'gun',
#   '1911',
#   '3dprintguns',
#   'PrintYour2A',
#   'SigSauer',
#   'PlebeianAR',
#   'MosinNagant',
#   'FirearmsHallOfShame',
#   'TheMoreYouLook',
#   'blackpowder',
#   'CompetitionShooting',
#   'ShootOptics',
#   'NOWTTYG',
#   '1022',
#   'SmithAndWesson',
#   'ruger',
#   'SpringfieldArmory',
#   'SmallGroups',
#   'mossberg',
#   'MP5',
#   'Shotguns',
#   'HecklerKoch',
#   '300BLK',
#   'CZFirearms',
#   '458socom',
#   'GlockMod',
#   'Revolvers',
#   'milsurp',
#   'Bren2',
#   'VEPR12',
#   'thetrueandthemighty',
#   'RedditStateGunNetwork',
#   'BT_APC',
#   'b_t',
#   'Stribog',
#   'P320',
#   'Tec9',
#   'ps90',
#   '68SPC',
#   'Mini14',
#   'Colt',
#   'Beretta',
#   'Tavor',
#   'USPmasterrace',
#   'SasquatchAttacks',
#   'rimfire',
#   'SW22VICTORY',
#   'GunGutsPorn',
#   '50AE',
#   'BerettaARX',
#   '22lr',
#   '57x28mm',
#   'suppressors',
#   'OlympicTrapShooting',
#   'AK74',
#   '10mm',
#   'canadaguns',
#   'NAIT',
#   'UFV',
#   'UCalgary',
#   'BCIT',
#   'usask',
#   'queensuniversity',
#   'OCADU',
#   'brocku',
#   'SMUHalifax',
#   'University_Of_Regina',
#   'UQAM',
#   'stfx',
#   'uwinnipeg',
#   'UWindsor',
#   'lakeheadu',
#   'uvic',
#   'nipissingu',
#   'etsmtl',
#   'UWSportShooting',
#   'wlu',
#   'TWU',
#   'Dalhousie',
#   'uleth',
#   'UdeM',
#   'MRU',
#   'CapU',
#   'simonfraser',
#   'unb',
#   'umanitoba'],
#  ['aznidentity',
#   'RacismAgainstAsians',
#   'ViolenceAgainstAsians',
#   'CrimesAgainstAsianity',
#   'bayarea',
#   'AsiaReport',
#   'gratefuldead',
#   'asianamerican',
#   'GigEconomy',
#   'Queens',
#   'psychadelics',
#   'terencemckenna',
#   'SinoDaily',
#   'Psychedelic',
#   'ActualHippies',
#   'RealMerryPranksters',
#   'sanfrancisco',
#   'nyu',
#   'MurderedByDionLim',
#   'queensgambit',
#   'Jazz',
#   'Kamloops',
#   'StopAsianHate',
#   'Noypi',
#   'DrugArt',
#   'BayRap',
#   'vacaville',
#   'Cowsonhills',
#   'LSDmusic',
#   'AsianAmericanAthletes',
#   'nonwhite',
#   'sexpat',
#   'MedikaLife',
#   'AskHistorians',
#   'MiddleEastHistory',
#   'AsianReddit',
#   'dragonutopia',
#   'deadandcompany',
#   'grateful_dead',
#   'GratefulDeadFamily',
#   'AcidHouse',
#   'EnamelPins',
#   'Pinz',
#   'deadheadcirclejerk',
#   'John_Frusciante',
#   'psychedelicrock',
#   'Erowidistan',
#   'jambands',
#   'altcountry',
#   'isthisheady',
#   'IndieFolk',
#   'bobacommie',
#   'TurboChangs',
#   'u_poochunks',
#   'sociology',
#   'HatPins',
#   'Pins',
#   'fanart',
#   'u_Viv_iannart',
#   'characterdesigns',
#   'Portraiture',
#   'DigitalArtGallery',
#   'portraits',
#   'Portraitart',
#   'ARTIST',
#   'thequeensgambit_tv',
#   'AnyaTaylorJoy',
#   'digitalarts',
#   'Anya_TaylorJoy',
#   'Artists',
#   'AnyaTaylor_Joy',
#   'ArtBuddy'],
#  ['furry_irl',
#   'surrealtraa',
#   'linux_gaming',
#   'Undertale',
#   'FurriesUncaged',
#   'BubsyTheodoreBobcat',
#   'the_Bubsy',
#   'FurryBlep',
#   'LinuxYiff',
#   'linuxmasterrace',
#   'LinuxFurries',
#   'linuxmemes',
#   'gex',
#   'OkBuddyCatgirl',
#   'foreverbox',
#   'overlyspecificEDmemes',
#   'digimon',
#   'Rayman',
#   'retrogaming',
#   'furry',
#   'Furry_Comics',
#   'snes',
#   'bubsy3d',
#   'casualnintendo',
#   'felixthecat',
#   'discordservers',
#   'CharaOffenseSquad',
#   'starterpack',
#   'undyneundertale',
#   'imsorrysans',
#   'UndyneSimps',
#   'okbuddylinux',
#   'OSTechNix',
#   'MovieDetails',
#   'ADHD_Programmers',
#   'ISS',
#   'thinkpad',
#   'Amd',
#   'starfox',
#   'videogames',
#   'retrogamingmagazines',
#   'Charadefensesquad',
#   'Chasriel_Squad',
#   'FriskUndertale',
#   'Friskriel',
#   'Deltarune',
#   'breakawayminyan',
#   'tallyhall',
#   'Pundertale',
#   'realAMD'],
#  ['bigfoot',
#   'creepypasta',
#   'Scary',
#   'AusMemes',
#   'unnerving',
#   'Cryptozoology',
#   'wanttobelieve',
#   'truecreepy',
#   'terrifying',
#   'GypsyRoad',
#   'UnexplainedPhenomena7',
#   'BigfootEncounters',
#   'theunexplained',
#   'SirSpooks',
#   'squatchersonly',
#   'UrbanLegends',
#   'cryptids',
#   'UrbanMyths',
#   'ParanormalReddit',
#   'MysteryMedia',
#   'Haunted',
#   'mysteriesoftheworld',
#   'veryspookyvideos',
#   'Unexplained',
#   'welcometohell',
#   'scaryasfuck',
#   'Paranormalsss',
#   'hauntedhouses',
#   'ghostsightings',
#   'Mandela_Effect',
#   'MetaMandela',
#   'MandelaEffectBenefits',
#   'mandelaeffects',
#   'ParallelUniverse',
#   'ShittyFanTheories',
#   'multiverse',
#   'matrixmemes',
#   'MatrixReality',
#   'Lets_Be_Friends'],
#  ['Marvel',
#   'BeatemupsYTCommunity',
#   'KeanuReeves',
#   'Falcom',
#   'residentevil',
#   'Daredevil',
#   'Defenders',
#   'capcom',
#   'StreetsofRage',
#   'NintendoSwitch',
#   'SwitchUpdates',
#   'midwestshitfest',
#   'ComicArtSociety',
#   'ImaginaryDC',
#   'WonderWoman',
#   'GhostRider',
#   'ImaginaryDemons',
#   'hulk',
#   'ComicsCentral',
#   'Inhumans',
#   'JessicaJones',
#   'thepunisher',
#   'new_comics_this_week',
#   'ImaginaryMarvel',
#   'drdoom',
#   'ImaginaryImmortals',
#   'comicbookcollecting',
#   'ImaginaryCarnage',
#   'comicbookart',
#   'u_sophie_valentine',
#   'SEGA',
#   'nintendo',
#   'SmartGamingDeals',
#   'BrzrkrByKeanu',
#   'comicbookshelves',
#   'indiecomics'],
#  ['religiousfruitcake',
#   'LeftySomalia',
#   'XSomalian',
#   'fucktrump',
#   'ParlerTrick',
#   'MAGAMeltdown',
#   'MeWeTrolling',
#   'ParlerCringe',
#   'ParlerTrolling',
#   'ParlerTricks',
#   'Heathen_Shieldwall',
#   'NorsePaganism',
#   'rage',
#   'ExEgypt',
#   'XSudanese',
#   'ex2x2',
#   'ExIsmailis',
#   'Somalia',
#   'tarantinocirclejerk'],
#  ['murderers',
#   'truecrimememes',
#   'forensics',
#   'mysterynibbles',
#   'crime',
#   'BeyondHorrors',
#   'DiscoveryID',
#   'murders',
#   'TrueCrimeLink',
#   'CrimePlus',
#   'CriminalProfiling',
#   'CrimeMugshots',
#   'ForensicPsych',
#   'serial_killers',
#   'UnsolvedCrime',
#   'MissingPersons',
#   'crime_documentaries'],
#  ['AmazonFBAOnlineRetail',
#   'u_Alseid',
#   'FacebookAds',
#   'startdropshipping',
#   'ecommentrepreneurs',
#   'AmazonSellerAbuse',
#   'amazondropshipping',
#   'DropshippingBiz',
#   'AmazonTools',
#   'PodcastSharing',
#   'AmazonFBATips',
#   'FBAadvanced',
#   'AmazonFBASellerTools',
#   'BetaTestersNeeded',
#   'u_Slowrolljoe',
#   'Dropshipping_France'],
#  ['Porsche',
#   'Autos',
#   'lamborghini',
#   'Cadillac',
#   'exoticautos',
#   'retrocars',
#   'Ferrari',
#   'XYONetwork',
#   'Bugatti',
#   'superexotics',
#   'SupercarsAlliance',
#   'supercars',
#   'u_Acceptable_Ad_6952',
#   'DubaiExoticsAuction',
#   'whatcarshouldIbuy'],
#  ['ChinaScamPatrol',
#   'WorkAbroadFraud',
#   'tefljobs',
#   'ChinaTeachers',
#   'ChinaTeacherAlliance',
#   'ChinaCheaters',
#   'TheFraudSquad',
#   'TEFL_TIPS_TRAPS_SCAMS',
#   'TEFLScams',
#   'TeflReviews',
#   'CFTU',
#   'ChinaScamCentral',
#   'expatrights',
#   'CyberScams'],
#  ['goodanimememes',
#   'guro',
#   'Weebdom',
#   'weeb',
#   'UnitedWeebFront',
#   'GoodAnimeme',
#   'GreatestAnimeMemes',
#   'MemesOfAnime',
#   'LandoftheWeebs',
#   'animeanarchist',
#   'Animememesforgods',
#   'guromemes'],
#  ['Koreanfilm',
#   '80s',
#   'TrulyBadCinema',
#   'AbsurdMovies',
#   'HKMovies',
#   'badMovies',
#   'ForeignMovies',
#   'Goremovies',
#   'kungfucinema',
#   'AsianMoviePulse',
#   'AsianFilmFans'],
#  ['BOLIVIA',
#   'GamingVPNs',
#   'Games',
#   'patchnotes',
#   'FranceInsoumise',
#   'melenchon',
#   'u_the_wildsheepnews',
#   'News_Feed',
#   'Fighters',
#   'meltyblood'],
#  ['SnekGang',
#   'OneTrueMiia',
#   'TongueTwisterGirls',
#   'Lamia',
#   'SFWmonstergirls',
#   'MonsterMusume',
#   'Miia',
#   'MonsterMusume_NSFW'],
#  ['Westonsupermare', 'bristol', 'Bath', 'Somerset', 'taunton', 'Yeovil'],
#  ['Vonnegut',
#   'DonDeLillo',
#   'robertobolano',
#   'davidfosterwallace',
#   'Gaddis',
#   'InfiniteDiscussion'],
#  ['Overkillers',
#   'DOPEorNOPEsubmissions',
#   'syphus',
#   'underkillers',
#   'Hi5StudiosYT'],
#  ['accelworld', 'awwnime', 'longhairedwaifus', 'ChurchofBelly'],
#  ['offlineTV', 'kimunity', 'justfriendshome', 'Angels_Kimi'],
#  ['JuicyNewsNetwork',
#   'ClashRoyale',
#   'ClashRoyaleCirclejerk',
#   'ClashRoyaleSerious'],
#  ['rakdos', 'mtgcombos', 'BadMtgCombos', 'Magicdeckbuilding'],
#  ['CellsAtWork', 'nojibrilnolife', 'NoGameNoLife'],
#  ['nebraskajobs', 'TrueOmaha']]

# %% [markdown]
# ### Upload comunity Leiden

# %%
leiden_coms = readwrite.read_community_csv( "leiden_coms.csv", ",", str)
leiden_clusters=leiden_coms.communities 
leiden_clusters
# Out:
# [['sharks',
#   'Outdoors',
#   'SpeculativeEvolution',
#   'newjersey',
#   'PlanetEarth',
#   'marinebiology',
#   'ocean',
#   'whales',
#   'HillbillyNerdTalk',
#   'DiscoverEarth',
#   'srilanka',
#   'Elephants',
#   'elephantsbeingbros',
#   'Ytqaz2019',
#   'uscg',
#   'USMC',
#   'Stargate',
#   'MiscellaneousContent',
#   'McMansionHell',
#   'myfavoritemurder',
#   'tookyoulongenough',
#   'SubGenius',
#   'BoogieMonster',
#   'TTAMF',
#   'Beebola',
#   'bootlickingnews',
#   'SwitzerlandIsFake',
#   'newsokuexp',
#   'OGoogleReaders',
#   'NoEvidenceNoCrime',
#   'Cyberpunk',
#   'TIHI',
#   'autism',
#   'DanLeBatardShow',
#   'weed',
#   'Iamactuallyverybadass',
#   'HelpMeFind',
#   'Sneakers',
#   'GeoVideos',
#   'SmallDeliMeats',
#   'Ternion',
#   'Belgium_kingdomOf',
#   'IASIP',
#   'TheDollop',
#   'Shitifind',
#   'basicincomejapan',
#   'hanguk',
#   'tesdcares',
#   'milwaukee',
#   'wholesome',
#   'interesting',
#   'totallynotrobots',
#   'vinyljerk',
#   'ToolBand',
#   'WhatWeDointheShadows',
#   'lukewarmsalmon',
#   'octopus',
#   'ResidentAlienTVshow',
#   'rickygervais',
#   'thalassophobia',
#   'SorayorimoTooiBasho',
#   'blowit',
#   'Snorkblot',
#   'lastpodcastontheleft',
#   'theydidthemath',
#   'MediaSynthesis',
#   'trees',
#   'jakeandamir',
#   'IThinkYouShouldLeave',
#   'Scrubs',
#   'comedybangbang',
#   'nathanforyou',
#   'golf',
#   'gamegrumps',
#   'Consoom',
#   'IndianEnts',
#   'Wildfire',
#   'thanksihateit',
#   'HumansAreMetal',
#   'KarlPilkingtonFanClub',
#   'Silfy_Star',
#   'seinfeld',
#   'MyrtleBeach',
#   'NotAllHeroesWearCapes',
#   'Bigloads',
#   'unclebens',
#   'UIUC',
#   'Dominos',
#   'Mushrooms',
#   'Psychedelics',
#   'CarsCarbsCardsKabis',
#   'shutdownfullcast',
#   'DamnNatureYouScary',
#   'bonnaroo',
#   'oddlyterrifying',
#   'Grimdank',
#   'shrooms',
#   'Holokauston',
#   'mrballen',
#   'ArcherFX',
#   'microbiology',
#   'Mindalteringsituation',
#   'surfing',
#   'lost',
#   'LPOTL',
#   'AntarcticAnomalies',
#   'insects',
#   'Bossfight',
#   'Harmontown',
#   'espresso',
#   'discworld',
#   'DiscoElysium',
#   'indonesia',
#   'Moisengoiser',
#   'LateStageCarnism',
#   'GasStationBathroom',
#   'timelapse',
#   'Reddit50k',
#   'malaysia',
#   'ape',
#   'shittyaskscience',
#   'Hyperhidrosis',
#   'mildlyevangelion',
#   'DeliriumSC',
#   'AdmiralBulldog',
#   'aoe2',
#   'PUBG',
#   'vipkid',
#   'RimWorld',
#   'singing',
#   'interstellar',
#   'destiny2',
#   'battlefield_4',
#   'wowfuckthewhat',
#   'plastichell',
#   'oknotizie',
#   'ww2',
#   'forsen',
#   'reptiles',
#   'squashmountainscouts',
#   'uktrees',
#   'AthleticoMince',
#   'NoMansSkyTheGame',
#   'GeorgiaOrGeorgia',
#   'norwayonreddit',
#   'LSD',
#   'yourlearningcurve',
#   'DeathPositive',
#   'asheville',
#   'holyshit',
#   'shittydarksouls',
#   'Master0fwar',
#   'MBMBAM',
#   'WomenAreMetal',
#   'blackmirror',
#   'architecture',
#   'GoodBlackNews',
#   'ufl',
#   'newsokur',
#   'sunlesssea',
#   'gardening',
#   'Kanye',
#   '1998TeenMovie',
#   'synthesizercirclejerk',
#   'SaltLakeCity',
#   'whatintarnation',
#   'kindafunny',
#   'Damnthatsinteresting',
#   'ALLTHEANIMALS',
#   'AquaticAsFuck',
#   'megalophobia',
#   'Tierzoo',
#   'badassanimals',
#   'catsvstail',
#   'SoundsLikeMusic',
#   'TheDepthsBelow',
#   'forbiddenboops',
#   'AIDKE',
#   'alligatorsarecute',
#   'Cetaphobia',
#   'orcas',
#   'SealifeGifs',
#   'forbiddensnacks',
#   'Currentlytripping',
#   'awwnverts',
#   'dontputyourdickinthat',
#   'RealLifePokemon',
#   'DeepRockGalactic',
#   'EDC',
#   'blackstonegriddle',
#   'Chefit',
#   'aesthetics13_saved',
#   'DeTrashed',
#   'Bowling',
#   'banano',
#   'CreaturesOfTheHaunt',
#   'physicaltherapy',
#   'HealMovement',
#   'marijuanaenthusiasts',
#   'bees',
#   'drawing',
#   'awesome',
#   'barstoolsports',
#   'ThePrepared',
#   'optometry',
#   'StardewValley',
#   'thingsforants',
#   'marinelife',
#   'TheLewinsons',
#   'civilengineering',
#   'dune',
#   'NatureIsFuckingLit',
#   'Vermiculture',
#   'lotrmemes',
#   'ants',
#   'Pikmin',
#   'freefolk',
#   'HunterXHunterMemes',
#   'nope',
#   'thatisdope',
#   'pikmin_irl',
#   'Breath_of_the_Wild',
#   'lordoftherings',
#   'makesitlookeasy',
#   'AccidentalWesAnderson',
#   'blender',
#   'ProperAnimalNames',
#   'dji',
#   'tampabayrays',
#   'SkyGame',
#   'TheBrownSound',
#   'forbiddenbed',
#   'stingrays',
#   'petesinterest',
#   'brandonsanderson',
#   'mayahiga',
#   '4g11',
#   'SweatyPalms',
#   'WhaleGifs',
#   'ShowTheKids',
#   'absoluteunit',
#   'Suomi',
#   'RocketLeague',
#   'savedPostyStuff',
#   'birds',
#   'valheim',
#   'Yatzee',
#   'NatureIsFuckingCute',
#   'Satisfyingasfuck',
#   'HappyAndRelaxing',
#   'LeastWeAmuseOurselves',
#   'BILT',
#   'bigcats',
#   'beyondthebump',
#   'Mizkif',
#   'YogurtOwlsInLove',
#   'ShiniesIRL',
#   'TheAmazingNature',
#   'FuckYouImAShark',
#   'Deer_IRL',
#   'LilliaMains',
#   'photoshopbattles',
#   'raining',
#   'animalssmiling',
#   'ThingsWeeLike',
#   'DarkCrystal',
#   'DankCrystal',
#   'dyspraxia',
#   'crazystairs',
#   'acrophobia',
#   'qcGottaSeeThis',
#   'AnimalsBeingPolite',
#   'turtles',
#   'whatsthisallabout',
#   'Nicehappystuff',
#   'ReptiloidsLeague',
#   'trypophobia',
#   'Sneks',
#   'NatureIsFuckingTrippy',
#   'Frankthesnake',
#   'HighResolutionGifs',
#   'RhesusNegative',
#   'enissa',
#   'BravoAlex',
#   'Giraffesdontexist',
#   'theHunter',
#   'AccidentalSatanism',
#   'mildyinteresting',
#   '420PT',
#   'Eldenring',
#   'detsky',
#   'justelesmeilleurs',
#   'DeerAreFuckingStupid',
#   'rance',
#   'confusingperspective',
#   'Frozen',
#   'earthfractals',
#   'folkhorror',
#   'CulturalLayer',
#   'Darkwood',
#   'TrueSTL',
#   'ATLA',
#   'TheLastAirbender',
#   'UnexpectedAvatar',
#   'quatria',
#   'AltruisticHarmony',
#   'ancestors',
#   'titanfolk',
#   'Thatsactuallyverycool',
#   'MicroPorn',
#   'gonwild',
#   'nincirclejerk',
#   'fractals',
#   'GeometryIsNeat',
#   'trippy',
#   'salt',
#   'misleadingthumbnails',
#   'shittyskylines',
#   'Tombofannihilation',
#   'MemePiece',
#   'SavageGarden',
#   'AngelIsland',
#   'Bedtimememes',
#   'Zorubark',
#   'Castelbon',
#   'animalcrossingmeme',
#   'SaveAndSort',
#   'EveryoneBeingBros',
#   'fpv',
#   'drones',
#   'videography',
#   'DC_Cinematic',
#   'bioniclelego',
#   'toshowthekid',
#   'FPVFlow',
#   'Dronescapes',
#   'NeoCommunistArchive',
#   'tameimpalacirclejerk',
#   'MonarchButterfly',
#   'venturebros',
#   'Dust_of_Memes',
#   'ItemShop',
#   'finalfuckinglevel',
#   'farpeoplehate',
#   'ProjectBlueWorld',
#   'HumanForScale',
#   'NorwayPics',
#   'Norway',
#   'norge',
#   'NorthernNordics',
#   'Mypersub_Nature',
#   'gratefuldead',
#   'fearsineverknewihad',
#   'WeatherGifs',
#   'noisygifs',
#   'woahdude',
#   'ChocolateMilkGuy',
#   'FreezingFuckingCold',
#   'Planegea',
#   'satisfying',
#   'mildlysatisfying',
#   '0ug',
#   'SILI',
#   'OddlyErotic',
#   'dionysus',
#   'sterling_random_stuff',
#   'MineralPorn',
#   'OddlyArousing',
#   'interestingasfuck',
#   'whatcouldgoright',
#   'holdmyredbull',
#   'AdrenalinePorn',
#   'alpinism',
#   'oddlysatisfying',
#   'PraiseTheCameraMan',
#   'natureisfuckingmetal',
#   'DudeFuckThat',
#   'accidentalsurrealism',
#   'AltitudeSickness',
#   'VideosthatgiveAnxiety',
#   'Earthmind',
#   'JuJutsuKaisen',
#   'ApexOutlands',
#   'NaturalPhenomena',
#   'Spore',
#   'MicroNatureIsMetal',
#   'microscopy',
#   'HardcoreNature',
#   'microscopicmetal',
#   'thrive',
#   'Biologyporn',
#   'chadsriseup',
#   'untitledgoosegame',
#   'NatureGifs',
#   'rainworld',
#   'interestingasduck',
#   'Mushishi',
#   'TheWonderfulWorld',
#   'wimagery',
#   'animalstakingover',
#   'otternews',
#   'geology',
#   'Gregfuckedarock',
#   'whatsthisrock',
#   'FortniteSavetheWorld',
#   'Minerals',
#   'commandandconquer',
#   'riskofrain',
#   'Crystals',
#   'ElderScrolls',
#   'greenday',
#   'ketamine',
#   'ror2',
#   'oddlyweird',
#   'forbiddenweed',
#   'forbiddennugs',
#   'oddlymesmerizing',
#   'battlefield_one',
#   'DunderMifflin',
#   'WildNature',
#   'tarantulas',
#   'Yltd',
#   'GlitchInTheMatrix',
#   'CLOUDS',
#   'JustCause',
#   'scanningEM',
#   'fangies',
#   'snakeswhoyell',
#   'SnakesYawning',
#   'pokemon',
#   'DnDnDPod',
#   'waterAliens',
#   'STFUitsadragon',
#   'IWouldDrawThat',
#   'HollywoodHandbook',
#   'BirdsAreNotReal',
#   'turtle',
#   'playalone',
#   'thelongdark',
#   'lynxes',
#   'EpicFlayn',
#   'isthisearth',
#   'Cephalopods',
#   'Carlosforscale',
#   'OctopusFuckery',
#   'Cephalopod',
#   'Weird',
#   'ClearAesthetic',
#   'HumanTippyTaps',
#   'earthaliens',
#   'creepy',
#   'WTMFN',
#   'Berserk',
#   'berserklejerk',
#   'CantBelieveThatsReal',
#   'NatureIsFuckingFab',
#   'Ibynst',
#   'DidntKnowThatExisted',
#   'TerrifyinglyTerrifyin',
#   'TheForest',
#   'mildlyterrifying',
#   'Natureiscursed',
#   'TILI',
#   'RareAnimals',
#   'ExpectantlyTerrifying',
#   'Mildlycthulhu',
#   'Wheresthebottom',
#   'nextfuckinglevel',
#   'HumansForScale',
#   'thalassaphobia',
#   'natureismental',
#   'AbsoluteUnits',
#   'mindMYcrack',
#   'mildlyvagina',
#   'Miniworlds',
#   'wildlypenis',
#   'mildlypenis',
#   'skulls',
#   'AquaticAnimals',
#   'midlyintersting',
#   'AbyssRium',
#   'EndlessOcean',
#   'mobydick',
#   'belugasbeingbros',
#   'KarmaConspiracy',
#   'FlyFishingCircleJerk',
#   'LeagueOfMemes',
#   'usfishfinder',
#   'LightbringerSeries',
#   'lebowski',
#   'natureisending',
#   'HardcoreVegHentaiPorn',
#   'homegrownnationalpark',
#   'LiminalSpace',
#   'LiminalReality',
#   'surrealplaces',
#   'prancingponypod',
#   'UnexpectedMyst',
#   'druidism',
#   'lotr',
#   'dontlookdown',
#   'yesbandcirclejerk',
#   'BooksThatFeelLikeThis',
#   'yeahbutreallyImaspeck',
#   'itsTooLate',
#   'Pareidolia',
#   'TheDarkTower',
#   'AccidentalArtGallery',
#   'nightvale',
#   'FairytaleasFuck',
#   'darktower',
#   'desirehole',
#   'stephenking',
#   'nancydrew',
#   'discordian',
#   'GetUpvote',
#   'dolphingifs',
#   'HauntingOfHillHouse',
#   'Sleepinganimals',
#   'Natureisfuckingtired',
#   'CozyPlaces',
#   'OlogiesPodcast',
#   'SatisfactoryGame',
#   'Bioshock',
#   'subnautica',
#   'WtfAreSnails',
#   'cremposting',
#   'Skyward',
#   'snails',
#   'stickyourdickinthat',
#   'PutYourDickInThat',
#   'saveOver1000',
#   'whalesdontexist',
#   'Natureisfuckingnope',
#   'cuttlefish',
#   'scuba',
#   'SCAcirclejerk',
#   'Cameras',
#   'edmprodcirclejerk',
#   'cellular_automata',
#   'DarkBlueOcean',
#   'Velkoz',
#   'MemeHunter',
#   'gravityrush',
#   'Subnautica_Below_Zero',
#   'ARK',
#   'EvolutionGoneWild',
#   'dumblookinganimals',
#   'CoolShots',
#   'bending',
#   'YuYuHakusho',
#   'mtg',
#   'ACValhalla',
#   'beautifultrees',
#   'ConfusedBoners',
#   'PokemonSwordAndShield',
#   'acnh',
#   'VaporwaveArt',
#   'AnimalsBeingPerfect',
#   'Funforkiddos',
#   'whatsthisbird',
#   'Mickstape',
#   'PinkGang',
#   'NapkinPope',
#   'pics',
#   'ANormalDayInAlaska',
#   'Lizards',
#   'japanpics',
#   'whatsthisplant',
#   'AccidentalGreenhouses',
#   'MitchHedberg',
#   'WorldIsClosed',
#   'reclaimedbynature',
#   'MushroomPorn',
#   'goblincore',
#   'swampcore',
#   'PicsGalore',
#   'Influencersinthewild',
#   'RealLifeShinies',
#   'borbs',
#   'rarecompliments',
#   'rarelobsters',
#   'csgo',
#   'LSDTripLifeHacks',
#   'vigorgame',
#   'DrStone',
#   'NotAnotherDnDPodcast',
#   'Anprimistan',
#   'gojira',
#   'postapocalyptic',
#   'monkeys',
#   'classicwow',
#   '90dayfianceuncensored',
#   'Asmongold',
#   'MobileOverview',
#   'MischievousGibbons',
#   'Slackline',
#   'crashbandicoot',
#   'attackontitan',
#   'SwiggitySwootyGifs',
#   '2007scape',
#   'AZCardinals',
#   'modelbirbs',
#   'PicsOfUnusualBirds',
#   'Thorgasm',
#   'Bossfightarena',
#   'Lightning',
#   'forthebitz',
#   'phish',
#   'roads',
#   'magictavern',
#   'AnimalbeingEngineers',
#   'AnimatedKidsFlick',
#   'botw',
#   'whatsthisbug',
#   'Entomology',
#   'spelunky',
#   'MagicCreatures',
#   'DiamondHandsRockets',
#   'Meetingofthemindz',
#   'shoebillsarentreal',
#   'mikeburnfire',
#   'OriAndTheBlindForest',
#   'Biigwes',
#   'TarkovMemes',
#   'Sekiro',
#   'reddeadredemption2',
#   'RedDeadOnline',
#   'deer',
#   'skylanders',
#   'brakebills',
#   'Adorifying',
#   'mycology',
#   'watchplantsgrow',
#   'hillchillbillies',
#   'GearsOfWar',
#   'halo',
#   'EchoArena',
#   'physicsjokes',
#   'nightmarefuel',
#   'hmm',
#   'Crocodilia',
#   'hmmm',
#   'PlantsAreAmazing',
#   'primatology',
#   'CapyPlops',
#   'coolthingsformygirl',
#   'snakes',
#   'fakehistoryporn',
#   'popstuff',
#   'funnybooboo',
#   'Hunting',
#   'infp',
#   'aatombstonescute',
#   'Cosy',
#   'TransAesthetics',
#   'SaturatioNation',
#   'RelaxingGifs',
#   'ShittyAnimalFacts',
#   'eatingsoupwithfork',
#   'hermitcrabs',
#   'BirthofaCrab',
#   'BabyLedWeaning',
#   'scoopdewoop',
#   'KimbaMemes',
#   'KingdomDeath',
#   'FierceFlow',
#   'nationalgeographic',
#   'fawns',
#   'snek_irl',
#   'ClimbingCircleJerk',
#   'MetalGearSolidmemes',
#   'oddlysatisfyingnature',
#   'attractivereddit',
#   'natureporn',
#   'TibblesandRosie',
#   'falloutnewvegas',
#   'DMT',
#   'Utah',
#   'ExcellentRepost',
#   'TunnelEntrances',
#   'deepseacreatures',
#   'AnimalCrossingNewHor',
#   'ac_newhorizons',
#   'StarWars',
#   'clione',
#   'Flyers',
#   'pathoftitans',
#   'rollercoasterjerk',
#   'herpetawwlogy',
#   'PlantedTank',
#   'monsteraday',
#   'thassalaphobia',
#   'Snek',
#   'chaparral',
#   'gangasnaan',
#   'Yamaha_TW200',
#   'thecatchup',
#   'Vaporglow',
#   'Terraria',
#   'Mario',
#   'JurassicWorldAlive',
#   'ankmemes',
#   'suits',
#   'MartialMemes',
#   'DesirePath',
#   'NewParents',
#   'OneInTheHand',
#   'Witcher3',
#   'PlantGoths',
#   'madlad',
#   'theticket',
#   'FuturisticRaven',
#   'DayMemeing',
#   'whitewater',
#   'ftfy',
#   'BanTheRepublicanParty',
#   'navy',
#   'aesoprock',
#   'NegarakuMalaysia',
#   'DinosaurKnight',
#   'MadeMeCry',
#   'PoCDoingGoodThings',
#   'acecombat',
#   'OakIsland',
#   'thestraightdopesub',
#   'humansarespaceorcs',
#   'lingling40hrs',
#   'psych',
#   'Construction',
#   'heavyequipment',
#   'moviescirclejerk',
#   'LandRover',
#   'HIMYM',
#   'disability',
#   'PardonMyTake',
#   'kayotic123',
#   'juggling',
#   'seenstit',
#   'snowboarding',
#   'HouseOfTheMemeMaker',
#   'ColorBlind',
#   'Filmmakers',
#   'KidCudi',
#   'AllFantasyEverything',
#   'bangladesh',
#   'fuckwasps',
#   'bee_irl',
#   'dxm',
#   'karmawhoresrus',
#   'drums',
#   'DidntKnowIWantedThat',
#   'TurkeyJerky',
#   'juxtaposition',
#   'PraiseTheEditor',
#   'lastimages',
#   'CombatFootage',
#   'thisshitistight',
#   'skateboarding',
#   'Spiderman',
#   'LaschesTeilen',
#   'KingOfTheHill',
#   'Cigarettes',
#   'recycling',
#   'morbidlybeautiful',
#   'coltonsmemes',
#   'bestoftheinternet',
#   'NameThatSong',
#   'toptalent',
#   'discgolf',
#   'mercedes_benz',
#   'Multicopter',
#   'saintmartin',
#   'greysanatomy',
#   'moon2mars',
#   'Dance',
#   'Viral_repost',
#   'dresdenfiles',
#   'BossFights',
#   'mallninjashit',
#   'ghostoftsushima',
#   'fromsoftware',
#   'darksoulsmemes',
#   'PokemonTCG',
#   'kingdomcome',
#   'Naruto',
#   'uncannyvalley',
#   'FirefighterPorn',
#   'NationalPark',
#   'happy',
#   'IzuzuRodeo',
#   'nice',
#   'notstupidifitworks',
#   'donttellmetheodds',
#   'techsupportmacgyver',
#   'agedlikewine',
#   'istp',
#   'fuckingmanly',
#   'CirclingBack',
#   'WeirdFlexButOK',
#   'geese',
#   'redrising',
#   'ScaryTechnology',
#   'eyeblech',
#   '3Dprinting',
#   'HelloInternet',
#   'TwoBestFriendsPlay',
#   'tloaHuman',
#   'doodiebutts',
#   'BobsBurgers',
#   'Menaregood',
#   'KindEngineering',
#   'specializedtools',
#   'StarKid',
#   'CoolNerd',
#   'BiomedicalEngineers',
#   'WrongAnswersOnly',
#   'gifsthatkeepongiving',
#   'btd6',
#   'shield',
#   'thething',
#   'DnD',
#   'TheBrewery',
#   'StonerEngineering',
#   'noita',
#   'formuladank',
#   'worldjerking',
#   'WildTimesPod',
#   'Flipping',
#   'fbhw',
#   'RedditAndChill',
#   'timecrisis',
#   'Warhammer40k',
#   'PearlStillSpammedYou',
#   'sousvide',
#   'castiron',
#   'WorldWar2',
#   'Achievement_Hunter',
#   'Defunctland',
#   'HowDogsWork',
#   'gaming',
#   'ActuallyInteresting',
#   'laebrkaes',
#   'dancegavindance',
#   'totalwar',
#   '1MostImportantStuff',
#   'elephacts',
#   'StardustCrusaders',
#   'ReefTank',
#   'Aquariums',
#   'TheOwlHouse',
#   'crows',
#   'crowbro',
#   'forgotthethe',
#   'PhoenixPoint',
#   'SpecEvoJerking',
#   'Alonetv',
#   'birdwatching',
#   'BSA',
#   'greatestgen',
#   'Videdia',
#   'ImageStabilization',
#   'vandwellers',
#   'Lowtechbrilliance',
#   'xbiking',
#   'DevilMayCry',
#   'amcirclejerk',
#   'KingdomHearts',
#   'LinusTechTips',
#   'LoadingIcons',
#   'MechanicalKeyboards',
#   'NLSSCircleJerk',
#   'ShittyGifRecipes',
#   'StupidFood',
#   'hot_dog',
#   'OkieSHENANIGANS',
#   'TrashLove',
#   'savedbykru',
#   'houseplants',
#   'succulents',
#   'RDR2',
#   'What',
#   'psychadelics',
#   'PerseveranceRover',
#   'thenetherlands',
#   'fallenlondon',
#   'mead',
#   '99percentinvisible',
#   'mainetrees',
#   'NoDig',
#   'OccupationalTherapy',
#   'zenify',
#   'flashlight',
#   'thestanleyschool',
#   'KJFQATest',
#   'SpidermanPS4',
#   'Stormlight_Archive',
#   'crochet',
#   'Bonsai',
#   'WetlanderHumor',
#   'unexpectedcosmere',
#   'holofractal',
#   'ElectricUniverse',
#   'osr',
#   'medizzy',
#   'belgium',
#   'Mewing',
#   'Futurelings',
#   'chemistry',
#   'Fractalverse',
#   'SoBlessed',
#   'Dublin',
#   'rehabtherapy',
#   'GoRVing',
#   'civ',
#   'labrats',
#   'evilbuildings',
#   'UznaliNas',
#   'shittyHDR',
#   'BirdsEyeViewVideos',
#   'friendlyarchitecture',
#   'starcraft2',
#   'FatEqualsFlavor',
#   'cursedfoods',
#   'FoodPorn',
#   'Sims4',
#   'ArchitecturePorn',
#   'Blue',
#   'DucksOvertaking',
#   'GermanyPics',
#   'ShingekiNoKyojin',
#   'HisDarkMaterialsHBO',
#   'aerospace',
#   'whoahdude',
#   'Founditsavedit',
#   'BUENZLI',
#   'MeltMore',
#   'CohhCarnage',
#   'WorldOfWarships',
#   'ebikes',
#   'nerdfighters',
#   'CivVI',
#   'manufacturing',
#   'ave',
#   'Morrowind',
#   'Gundam',
#   'beltalowda',
#   'horizon',
#   'ToasterTalk',
#   'xkcd',
#   'MrFruit',
#   'Leathercraft',
#   'readyplayerone',
#   'FuturisticRealism',
#   'WeLiveInTheFuture',
#   'ehlersdanlos',
#   'bkup',
#   'stevenuniverse',
#   'ScottishFootball',
#   'Earthchan',
#   'wholesome40k',
#   'MoeMorphism',
#   'Noearthsociety',
#   'abv',
#   'secretcompartments',
#   'hiddenrooms',
#   'GrifosMexico',
#   'StonerSpots',
#   'Yointerneto',
#   'Gambiarra',
#   'DiWHY',
#   'redneckengineering',
#   'Nittola',
#   'Owls',
#   'shittyrobots',
#   'TheDesignIsVeryHuman',
#   'KillerRobotAttack',
#   'neatbutwhy',
#   'aviation',
#   '9_8',
#   'PenmanshipPorn',
#   'motiongraphics',
#   'Dungeons_and_Dragons',
#   'TheWeeknd',
#   'Odablock',
#   'Otamurai',
#   'stalker',
#   'nextlevel',
#   'jibungatari',
#   'mykindahumour',
#   'magicthecirclejerking',
#   'TheNinthHouse',
#   'harrypotter',
#   'Volkswagen',
#   'Egg',
#   'Salvia',
#   'Genshin_Memepact',
#   'ChrisRamsay52',
#   'TheDamnSharkRepost',
#   'wavegifs',
#   ...],
#  ['nature',
#   'environment',
#   'EcoNewsNetwork',
#   'PublicLands',
#   'EndangeredSpecies',
#   'animalimpact',
#   'Animals',
#   'UpliftingNews',
#   'organizedhealing',
#   'Green_News',
#   'wildlifecorridors',
#   'WomenInNews',
#   'WomensRightsNews',
#   'prochoice',
#   'worldnews',
#   'europes',
#   'indepthstories',
#   'Midwives',
#   'ClimateCrisis',
#   'xxstem',
#   'anime_titties',
#   'cleanstreetbets',
#   'BigAgro',
#   'DoomsdayNow',
#   'DoomsdayBook',
#   'greeninvestor',
#   'energy',
#   'LockCarbon',
#   'Toadbook',
#   'SGU',
#   'Reterra',
#   'organic',
#   'EnoughMuskSpam',
#   'patient_hackernews',
#   'CitizenPlanners',
#   'TaiwanChina',
#   'taiwan',
#   'TheEndOfHumanityShow',
#   'soundsaboutright',
#   'economy',
#   'Allopatria',
#   'Hozhor',
#   'PlantBased4ThePlanet',
#   'sustainability',
#   'Ohio',
#   'climatejustice',
#   'RuralDemocrats',
#   'climateaction',
#   'climatepolicy',
#   'DemocracyNow',
#   'usa',
#   'ClimateChangeSolution',
#   'USNews2',
#   'USGovernment',
#   'usapolitics',
#   'world',
#   'europe',
#   'terrifyingstatistics',
#   'wheresthebeef',
#   'GreenConsumersUnion',
#   'Energy_unbiased',
#   'NuclearPower',
#   'airlines',
#   'DemocratsforDiversity',
#   'EarthEnthusiasts',
#   'ClimateAndEnvironment',
#   'planet',
#   'ClimateActivism',
#   'netzero',
#   'CleanEnergy',
#   'north_america',
#   'EmissionsTax',
#   'carboncapture',
#   'northamerica',
#   'Hawaii',
#   'goodnews',
#   'hawaiinews',
#   'oceans',
#   'CoralRestoration',
#   'Positivity',
#   'environmentaljustice',
#   'ClimateActionPlan',
#   'Futurology',
#   'solarpower',
#   'gmc',
#   'midwest',
#   'Renewable',
#   'usanews',
#   'solarpowerplants',
#   'windpower',
#   '2030',
#   'climateskeptics',
#   'ClimateNews',
#   'smartcities',
#   'SouthAsia',
#   'IndiaSpeaks',
#   'airpollution',
#   'Cities',
#   'Sustainable',
#   'RenewableEnergy',
#   'AppleInvestors',
#   'SunriseMovement',
#   'ideasforgovt',
#   'PhysicalGeography',
#   'veganscience',
#   'Environmentalism',
#   'Green',
#   'PeopleDoGood',
#   'GetIt2Gether',
#   'collapse',
#   'vego',
#   'HC_Capitalism',
#   'actualconspiracies',
#   'workthatreconnects',
#   'Permanence',
#   'MachineThatMakesMoney',
#   'TechOfTheFuture',
#   'water',
#   'China_irl',
#   'bioscience',
#   'climate',
#   'ForestHealth',
#   'SearchScene',
#   'doomists',
#   'brasil',
#   'Cleveland',
#   'GreatLakesPrepping',
#   'Environmental_Policy',
#   '2020',
#   'OhioGovernment',
#   'Cetacea',
#   'Positive_News',
#   'CarbonFootprint',
#   'GreenNewDeal',
#   'GreenNewIdeas',
#   'decarbonize',
#   'coal',
#   'FossilFuels',
#   '2035',
#   'COVID19RippleEffects',
#   'theworldnews',
#   'environmentallaw',
#   'EnvironmentProtectors',
#   'greed',
#   'libclimateactivism',
#   'neoliberal',
#   'MeidasTouch',
#   'BigEnergy',
#   'climatescience',
#   'DavidDistributed',
#   'darkfacts',
#   'supplychain',
#   'Waste',
#   'kellogg',
#   'ZeroWaste',
#   'enviroaction',
#   'ProEarth',
#   'UpstateUrban',
#   'Greenspo',
#   'Urbanism',
#   'yimby',
#   'NUMTOT',
#   'environmental_science',
#   'PuertoRico',
#   'WatchdogJournalism',
#   'YangForPresidentHQ',
#   'RetailNews',
#   'newyorkcity',
#   'EmergingRisks',
#   'Euromaidan2014',
#   'ExposingRussia',
#   'humanrights',
#   'PerpetualPixelNews',
#   'TriCitiesWA',
#   'Tacoma',
#   'WhatsonNow',
#   'women',
#   'Buffalo',
#   'britishmilitary',
#   'neoconNWO',
#   'PositiveNewsCovid19',
#   'FourCorners',
#   'CoronavirusMa',
#   'upbeatnews',
#   'PrepperIntel',
#   'NoShitSherlock',
#   'BigTech',
#   'seasteading',
#   'Anticonsumption',
#   'conservatives',
#   'TheBellmanStillRings',
#   'ireland',
#   'Kappa',
#   'Calgary',
#   'StallmanWasRight',
#   'freesoftware',
#   'uptiltingnews',
#   'nyc',
#   'MorbidReality',
#   'MARCIANOTECH',
#   'GoodIdeasForAustralia',
#   'protest',
#   'GlobalNews',
#   '2404',
#   'AutisticPride',
#   'MensRights',
#   'EndMassIncarceration',
#   'NewMexicoPolitics',
#   'SouthJersey',
#   'maryland',
#   'LasCruces',
#   'portugueses',
#   'MarshallBrain',
#   'downliftingnews',
#   'BrasildoB',
#   'PersonOfInterest',
#   'technews',
#   'PivotPodcast',
#   'Philippines',
#   'CoronavirusUS',
#   'democracy',
#   'AlexeiNavalny',
#   'Mildlyinterestingas',
#   'CoronavirusFL',
#   'CoronavirusGA',
#   'Dailyslant',
#   'Edmonton',
#   'latinos',
#   'SpaceXLounge',
#   'Piracy',
#   'AXELNetwork',
#   'TechDystopia',
#   'ArcanaPost',
#   'samharris',
#   'healthcare',
#   'arizona',
#   'SurprisingNoOne',
#   'technology',
#   'brasilivre',
#   'saudiarabia',
#   'KingdomofSaudiArabia',
#   'BidenCoalition',
#   'Chinatown_irl',
#   'AdamCarolla',
#   'Buddhism',
#   'HumanResponse',
#   'massachusetts',
#   'armenia',
#   'SecondGreatDepression',
#   'Egalitarianism',
#   'Turkey',
#   'Kazakhstan',
#   'fucktheccp',
#   'BoycottChinaRussiaUSA',
#   'YourMoneyIsYourVote',
#   'EcoFriendly',
#   'fuckamazon',
#   'AIandRobotics',
#   'excitingdystopia',
#   '2ndIntelligentSpecies',
#   'CoV2Canada',
#   'Vitards',
#   'MuskMarsColony',
#   'avoidchineseproducts',
#   'islam',
#   'FreeTheUyghurs',
#   'MuslimLounge',
#   'BoycottChina',
#   'AntiFANG',
#   'CorpFree',
#   'CoronavirusCA',
#   'Anthropology',
#   'SzechuanSauceSeekers',
#   'China_War',
#   'TaiwanNumberOne',
#   'Spacers',
#   'TechNewsToday',
#   'netneutrality',
#   'exmormon',
#   'WeHaveConcerns',
#   'TIL_Uncensored',
#   'Birthstrike',
#   'ChinaSucks',
#   'NoMoreBigChina',
#   'hempflowers',
#   'Bellingham',
#   'Yatirim',
#   'publichealth',
#   'KillFacebook',
#   'oculus',
#   'The_Coronavirus',
#   'StormComing',
#   'megafaunarewilding',
#   'NATOrussianconflict',
#   'vouched',
#   'taiwanindependence',
#   'techable',
#   'HerpesCureResearch',
#   'clinicalresearch',
#   'scandinavia',
#   'RepublicofNE',
#   'biology',
#   'FactoryFarming',
#   'paradoxpolitics',
#   'childrenofdemocracy',
#   'BDS',
#   'AutoMechanics',
#   'mejico',
#   'breakingnews',
#   'Maine',
#   'solarenergy',
#   'Humannews',
#   'objectiveEconomics',
#   'italy',
#   'croatia',
#   'exjw',
#   'NOCRISISJUSTCHANGE',
#   'ABoringUtopia',
#   'chonglangTV',
#   'Lahore',
#   'WorldNewsHeadlines',
#   'UkrainevRussia',
#   'SonsofOrpheus',
#   'shroomstocks',
#   'shroomers',
#   'MindMedInvestorsClub',
#   'PsychedelicStudies',
#   'microdosing',
#   'ScienceFacts',
#   'AmericanHistory',
#   'Delivery',
#   'coronavirusflorida',
#   'EuropeanNews',
#   'International',
#   'WorldNews_Serious',
#   'NewsHub',
#   'R4RcovidNYC',
#   'COVIDGoodNews',
#   'EmergingTherapies',
#   'CoronavirusRecession',
#   'finance_news',
#   '2020electioncrisis',
#   '2020Election',
#   'france',
#   'teslamotors',
#   'FillsYourNiche',
#   'veg',
#   'Ornithology',
#   'Drugs',
#   'Sunriseredding',
#   'venusforming',
#   'germany',
#   'climatesolutions',
#   'uninsurable',
#   'gayfarmer',
#   'RedMeatPolitics',
#   'ClimateOffensive',
#   'socialscience',
#   'Renewable_Energy_News',
#   'EcoActivism',
#   'SDGbyBOSAGORA',
#   'FridaysForFuture',
#   'ExtinctionRebellion',
#   'EarthStrike',
#   'methanecrisis',
#   'newbrunswickcanada',
#   'ClimateChangeWar',
#   'goodnewseveryone',
#   'goodnewsstation',
#   'NJPolitics',
#   'cannabisreform',
#   'MarijuanaNewsOnline',
#   'Jamaica',
#   'nycpolitics',
#   'Alternative_Energy',
#   'Ethiopia',
#   'misanthropy',
#   'Tigray',
#   'AntiVegan',
#   'RedMeatScience',
#   'collapze',
#   'mexico',
#   'SiliconValleyHBO',
#   'hungary',
#   'softwaregore',
#   'ukraine',
#   'LiberalsWhoHateTheCCP',
#   'March2018',
#   'Indonesias',
#   'adultsnew',
#   'russia',
#   'winniepoohpresident',
#   'programminghorror',
#   'Capitalism',
#   'LoveForAmazon',
#   'ParadoxExtra',
#   'spain',
#   'amazonemployees',
#   'rawpetfood',
#   'Sakartvelo',
#   'Russophobic',
#   'Feminism',
#   'Bundesliga',
#   'qatar',
#   'arabs',
#   'doha',
#   'MiddleEast',
#   'Baloldal',
#   'PRChina',
#   'Zino',
#   'AntiCCP',
#   'KarmaFarming4Pros',
#   'AlternatitveReality',
#   'firefly',
#   'CoronavirusRelief',
#   'DailyNewsPosts',
#   'ph_politics',
#   'Globalactivism',
#   'shitpostemblem',
#   'UkrainianConflict',
#   'RetardsTalkAboutSaudi',
#   'CHERUB',
#   'NewColdWar',
#   'overpopulation',
#   'UngiveBirthToMe',
#   'unexpectedtaylorswift',
#   'BasicFood',
#   'idiocracy',
#   '12Monkeys',
#   'ClimateCrazies',
#   'ecogenics',
#   'ThanksSherlock',
#   'sweden',
#   'Tampere',
#   'H5N8Avian',
#   'NonCredibleDefense',
#   'neocentrism',
#   'quin69',
#   'AmericanPoverty',
#   'BunchaBS',
#   'Slovakia',
#   'BasicIncome',
#   'bigaussieprepper',
#   'climatedisalarm',
#   'okinawa',
#   'UraniumSqueeze',
#   'GlobalSouth',
#   'korea',
#   'solarpunk',
#   'Ecosocialism',
#   'Geedis',
#   'Ryan',
#   'kirillwashere',
#   'loveliveserve',
#   'WorldSuccess',
#   'humandesign',
#   'WilliamGibson',
#   'The_Watch_Towers',
#   'KingstonOntario',
#   'Quebec',
#   'metamtl',
#   'ChinaRemoves',
#   'newsbeat',
#   'AsianAmericanIssues',
#   'olympia',
#   'emojipresident',
#   'universityofauckland',
#   'ToriesAreBad',
#   'takeDownRindiA',
#   'LiberalCatholics',
#   'UAE',
#   'perestroika_pw_org',
#   'China_Debate',
#   'ADVChina',
#   'toriesdeathtoll',
#   'ActiveMeasures',
#   'liberta',
#   'TinyViolins',
#   'China',
#   'craftofintelligence',
#   'CCP_virus',
#   'PrisonStrike',
#   'ChunghwaMinkuo',
#   'chinesepolitics',
#   'justchinathings',
#   'EnoughWumaoSpam',
#   'HallOfFake',
#   'abudhabi',
#   'lithuania',
#   'BalticStates',
#   'CivPolitics',
#   'worldevents',
#   'espionage',
#   'magnitsky',
#   'unchainedpolitics',
#   'emoluments',
#   'UnitedNations',
#   'Eritrea',
#   'Oromia',
#   'RPCV4PeaceTigray',
#   'coffee_roasters',
#   'RoyalMarines',
#   'commonwealth',
#   'Royalcore',
#   'TastingHistory',
#   'streeteats',
#   'MrRobot',
#   'benfordslaw',
#   'Southwest_VA_Living',
#   'shanghai',
#   'xijinping',
#   'AntiComAction',
#   'badgovnofreedom',
#   'AnalSwabs4All',
#   'Nepal',
#   'king_of_the_south',
#   'AntiFacebook',
#   'ProtectOurForests',
#   'Theregoesthefuture',
#   'ecology',
#   'Abhigyan',
#   'JoeBiden',
#   'Jewish',
#   'diccwilliams',
#   'Forum_Democratie',
#   'Coronavirus_KY',
#   'MiddleEastNews',
#   'switchgreen',
#   'investimentos',
#   'Gold',
#   'armchaireconomics',
#   'ksatv',
#   'LeonardodaVinci',
#   'progressive_islam',
#   'CANZUK',
#   'FuckTheChineseGov',
#   'Uyghur',
#   'Bad_Bing_No_Rice',
#   'EUnews',
#   'sean',
#   'mongolia',
#   'PoliticalScience',
#   'ArtHistory',
#   'DataHoarder',
#   'KetoNews',
#   'cincinnati',
#   'timepoverty',
#   'Taoesm',
#   'nursing',
#   'Nurse',
#   'respiratorytherapy',
#   'Covid19FreeNews',
#   'canadian',
#   'TDSInfestedIdiots',
#   'SinophobiaWatch',
#   'greenwizards',
#   'computerscience',
#   'SexWorkers',
#   'beefanddairynetwork',
#   'ConservativeKiwi',
#   'portugal2',
#   'asucottage',
#   'GeoNews24',
#   'TheChinaNerd',
#   'Ecosia',
#   'HunnyFunny',
#   'LandscapingTips',
#   'Khatrimaza',
#   'CoronaUpliftingNews',
#   'cleverclogs',
#   'Coronaworldwide',
#   'CdnVeganClimateAction',
#   'Breaking_News',
#   'theAlgorithmHasSpoken',
#   'spinalcordinjuries',
#   'RobotChurch',
#   'fullysaved',
#   'Newsoku_L',
#   'Knoxville',
#   'GoodCorona',
#   'HongKong',
#   'chineselogic',
#   'ChinaExposed',
#   'TurkicPeople',
#   'Humans_suck',
#   'Luxembourg',
#   'ChinaWatchNZ',
#   'internationalpolitics',
#   'foreignpolicy',
#   'cvnews',
#   'ModernWarzone',
#   'China_News',
#   'southeastasia',
#   'CoronavirusJapan',
#   'Covid2019',
#   'crossposters',
#   'smem',
#   'KiAChatroom',
#   'republicans',
#   'WuhanVirus',
#   'nCoronaVirus',
#   'Disinfo',
#   'ChinaHumanRights',
#   'BoycottTI9',
#   'Brunei',
#   'rationalpakistan',
#   'Linky_links',
#   'lastweektonight',
#   'Humanpersecution',
#   'supporthongkong',
#   'ID_News',
#   'Lal_Salaam',
#   'HongKongProtest',
#   'Yourmomgay69',
#   'Shittiergovernments',
#   'AboutDirtbags',
#   'CoronaVirusInfo',
#   'FuckHKPopo',
#   'Asean',
#   'Milk_Tea_Alliance',
#   'ccp',
#   'Sciencology',
#   'AntimatterDimensions',
#   'wsu',
#   'eliteexplorers',
#   'Gunnm',
#   'TerraformingMarsGame',
#   'Gizzverse',
#   'MaunaKea',
#   'fightboredom',
#   'firewater',
#   'IHateCoronaVirus',
#   'TrumpCoronaVirus',
#   'CorruptionOnAPlatter',
#   'ActualidadMundial',
#   'CredibleDefense',
#   'CoronavirusFOS',
#   'republitrash',
#   'Snowflake_Meltdown',
#   'saraba0th',
#   'ogman',
#   'Yazidis',
#   'ReligiousFreedom',
#   'human_rights',
#   'scandalousrabbithole',
#   'Seaspiracy',
#   'Hacking_Tutorials',
#   'cybersecurity',
#   'AskBalkans',
#   'theericzaneshow',
#   'armenian',
#   'NoMoreChina',
#   'SAVEBRENDAN',
#   'AsABlackMan',
#   'FinanceShed',
#   'LoveForTaiwan',
#   'XiIsFinished',
#   'IndianDefense',
#   'Eesti',
#   'Sameproblems',
#   'AdamCurtis',
#   'dubai',
#   'TheyTrustMe',
#   'socialmedianews',
#   'chinareddits',
#   'PoliticoSubreddit',
#   'tibet',
#   'Wholesomeawardhell',
#   'globalhealth',
#   'Newanimalspecies',
#   'indiadefense',
#   'foreignpolicyanalysis',
#   'NeoliberalButNoFash',
#   'Global_Geopolitics',
#   'CanadaConservatives',
#   'geopolitics',
#   'roddit',
#   'darknetdiaries',
#   'CECIA',
#   'MilitaryProcurement',
#   'worldnews2',
#   'censorship',
#   'nationofeurope',
#   'BritishNationalism',
#   'Honduras',
#   'centralamerica',
#   'LatinAmerica',
#   'WasteFest',
#   'bookmarkStream',
#   'AnimalIndustry',
#   'tories',
#   'Antofu',
#   'myanmar',
#   'ender',
#   'Monk',
#   'belarus',
#   'Biodegradable',
#   'HotterTopics',
#   'TrashyCompany',
#   'longform',
#   'FuturologyPolitics',
#   'substance',
#   'TechNewsTomorrow',
#   'GlobalTribeInitiative',
#   'research',
#   'PlanPlantPlanet',
#   'uruguay',
#   'vastarinta',
#   'SocConstructOfReality',
#   'alberta',
#   'CoronaDidNothingWrong',
#   'mantis',
#   'ScienceAlliance',
#   'DieOff',
#   'COVID19Resistance',
#   'HumanProgress',
#   '2021',
#   'USA_StratCom',
#   'programming',
#   'Ayahuasca',
#   'tijuana',
#   'WhoreMagic',
#   'HumanityForward',
#   'YangGang',
#   'universalincome',
#   'business',
#   'iranian',
#   'FemaleLevelUpStrategy',
#   'Presidents',
#   'upliftingnewsforwomen',
#   'electionReformNews',
#   'Leader',
#   'electionreform',
#   'elections',
#   'MiddleEastern',
#   'UberDeutschland',
#   'caucasus',
#   'KarabakhConflict',
#   'Africa',
#   'TheWayIMakeMeThink',
#   'ReForested',
#   'bonsaicommunity',
#   'Pandemic',
#   'internationalbusiness',
#   'SouthKoreanPolitics',
#   'CanadianInvestor',
#   'teslainvestorsclub',
#   'Nio',
#   'FreeAsInFreedom',
#   'fastvoted',
#   'libgen',
#   'scihub',
#   'Open_Science',
#   'HealthTechnology',
#   'HealthTech',
#   'VaccineResearch',
#   'WorldHealthOrg',
#   'Vaccine',
#   'VACCINES',
#   'cyber',
#   'westabootales',
#   'AnarchyintheUK',
#   'electricvehicles',
#   'farming',
#   'vzla',
#   'VaccinesMeds',
#   'coronabr',
#   'LeftWingNonFeminist',
#   'kansascity',
#   'LGBTnews',
#   'Derfla_bookmarks',
#   'wichita',
#   'cordcutters',
#   'direito',
#   'USCensus2020',
#   'greenland',
#   'MontanaPolitics',
#   'Infrastructurist',
#   'ForUnitedStates',
#   'AlaskaPolitics',
#   'TheCrescent',
#   'FloridaPolitics',
#   'NortheastUS',
#   'FloridaCoronavirus',
#   'GAPolitics',
#   'internationallaw',
#   'Intactivism',
#   'notesandnews',
#   'AgainstPolarization',
#   'westlinn',
#   'RinoDinoPorcupino',
#   'RooseveltRepublicans',
#   'IsTheMicStillOn',
#   'WHHR2',
#   'Montana',
#   'Myanmar2021',
#   'toxicology',
#   'FeMRADebates',
#   'Longreads',
#   'YACUHQ',
#   'NEET',
#   'Rights',
#   'Liberal_Conservatives',
#   'aaronswartz',
#   'Democrat',
#   'Election2020',
#   'DuggarsSnark',
#   'alaska',
#   'BidenHarrisForAmerica',
#   'activism',
#   'CaliforniaForYang',
#   'newyork',
#   'nycCoronavirus',
#   'CoronavirusNewYork',
#   'OhioConservatives',
#   '350',
#   'GeorgiaUS',
#   'AtlantaPolitics',
#   'Hispanic',
#   'USElectionPrediction',
#   'Latino',
#   'vote',
#   'VotingRights',
#   '2016Elections',
#   '2016_elections',
#   'WhiteHouse2020',
#   'ohiopolitics',
#   'californiapolitics',
#   'bipartisanSolutions',
#   'dementia',
#   'KeepOurNetFree',
#   'BipartisanNews',
#   'democratic_socialists',
#   'capitolhill',
#   'confederateflags',
#   'bipartisanship',
#   'DemocracyNeedsFixing',
#   'HowHumanBeingsWork',
#   'VotingReform',
#   'votingtheory',
#   'facebook',
#   'hemp',
#   'mapasdemexico',
#   'MapPorn',
#   'Jaguarland',
#   'Rwanda',
#   'flavortown',
#   'coloradoteens',
#   'Cello',
#   'RedditTimeCapsule',
#   'books',
#   'cork',
#   'LGBTCatholic',
#   'exIglesiaNiCristo',
#   'Popefacts',
#   'warriors',
#   'Cyberdelinaut',
#   'inventors',
#   'Interesting_Shit',
#   'GoodNewsNews',
#   'SomePositiveInYourDay',
#   'Americans',
#   'lowcar',
#   'rewilding',
#   'biodiversity',
#   'ScotlandPorn',
#   'over60reddit',
#   'bee',
#   'YourPestLife',
#   'oilandgas',
#   'oil',
#   'GlobalPolitics',
#   'worldnews247',
#   'europeans',
#   'amarillo',
#   'Pets',
#   'TeenMomOGandTeenMom2',
#   'CountryTimes',
#   'Essay_Tips_Tricks',
#   'ClimateTakeBack',
#   'Cowwapse',
#   'octopusagiletariff',
#   'singularity',
#   'regenerate',
#   'fantasyfootball',
#   'sunflowers',
#   'MURICANEWS',
#   'flowers',
#   'tech',
#   'conservation',
#   'landconservation',
#   'WaterTreatment',
#   'BottleNeck',
#   'chile',
#   'PlantBasedDiet',
#   'VisitBrazil',
#   'oneanddone',
#   'Borderporn',
#   'Microorganisms',
#   'weather',
#   'portugal',
#   'finlandConspiracy',
#   'TraditionalShamanism',
#   'SeaShepherd',
#   'AnimalIntelligence',
#   'poland',
#   'Armadillo',
#   'IncredibleIndia',
#   'NewEnglandSocialism',
#   'AnarquismoBrasil',
#   'northernireland',
#   'CCPwatch',
#   'Real_Sikhi',
#   'revolutionaryculture',
#   'pharmacy',
#   'monarchism',
#   'Twitter',
#   'albania',
#   'anchorage',
#   'mediterranea',
#   'PerfectSystem',
#   'millenials',
#   'GroceryStores',
#   'CoronavirusOC',
#   'USF',
#   'greece',
#   '2MiddleEast4you',
#   'urbanplanning',
#   'Rochester',
#   'upstate_new_york',
#   '2balkan4you',
#   'OrenoNetachou',
#   'casualEurope',
#   'Polska',
#   'MusicIndia',
#   'MTU',
#   'NewYorkCityResidents',
#   'KansasPolitics',
#   'LIHKG',
#   'Taiwancirclejerk',
#   'maritime',
#   'wyomingdoesntexist',
#   'nycrail',
#   'kurdistan',
#   'Positive',
#   'notjustbikes',
#   'tangentiallyspeaking',
#   'newzealand',
#   'IDontCareBeMad',
#   'umass',
#   'techdetects',
#   'AnywhereButAmazon',
#   'Animatronics',
#   'FoodDeliveryRobots',
#   'genlock',
#   'bharat',
#   'aws',
#   'Ghost_in_the_Shell',
#   'bestarticles',
#   'ItalyInformatica',
#   'pancakeswap',
#   'apdm',
#   'LaCarcaza',
#   'clubhouse',
#   'whatsapp',
#   'android_devs',
#   'michigantraders',
#   'GlobalTribe',
#   'revragnarok',
#   'ForwardThinkingJasper',
#   'solarstocks',
#   'srilankacomputing',
#   'workfromhome',
#   'UPSers',
#   'Nextlevelbabysitting',
#   'IOPsychology',
#   'StupidFatAmericansSay',
#   'tdi',
#   'nanocurrency',
#   'ukcrypto',
#   'notArgentina',
#   'TechnicalMind',
#   'noip',
#   'DevsJunky',
#   'DoughProbe',
#   'billgates',
#   'ATT',
#   'Oligopolies',
#   'homeland',
#   'CysticFibrosis',
#   'Benzofamily',
#   'GarbageHeap',
#   'ExroTechnologies',
#   'EnvironmentalScience',
#   'renewableenergystocks',
#   'linux_gaming',
#   'IGN',
#   'borderlands3',
#   'IntoThePitOfLife',
#   'acousticecology',
#   ...],
#  ['furry_irl',
#   'theFutureLiberalsWant',
#   'exchristian',
#   'jschlatt',
#   'ems',
#   'ThatsHowThingsWork',
#   'neurodiversity',
#   'PBWorld',
#   'codyko',
#   'mostgilded',
#   'ksi',
#   'chaoticgood',
#   'BrandNewSentence',
#   'LettuceGang',
#   'Lolitary',
#   'JustUnsubbed',
#   'theydidthemonstermath',
#   'TopofAllTime',
#   'thegrandtour',
#   'badwomensanatomy',
#   'CrustofReason',
#   'OkCupid',
#   'BroProduction',
#   'DonutMedia',
#   'oddlyspecific',
#   'Embracemonkey',
#   'unanticipatedstartrek',
#   'DangelsHub',
#   'ainbow',
#   'lgbt',
#   'ClimateMemes',
#   'environmemes',
#   'gay',
#   'trans',
#   'ThanksForTheHelp',
#   'genekeys',
#   'unexpecteddestiny',
#   'SuddenlyGay',
#   'BanVideoGames',
#   'SomeOrdinaryGmrs',
#   'Tunisia',
#   'Judaism',
#   'exmuslim',
#   'cirkeltrek',
#   'ww3memes',
#   'exAdventist',
#   'AtheisticTeens',
#   'timesuck',
#   'teenagersnew',
#   'Antitheism',
#   'TheBigWasteland',
#   'spacefrogs',
#   'bisexual',
#   'soccercirclejerk',
#   'okmatewanker',
#   'fuckcars',
#   'SatanGetTheDelorian',
#   'ftm',
#   'OutcastingMedia',
#   'noyoucantwatch',
#   'Accounting',
#   'SimDemocracy',
#   'UnexpectedMulaney',
#   'raimimemes',
#   'FridayNightFunkin',
#   'PoliticalCompassMemes',
#   'LudwigAhgren',
#   'boburnham',
#   'TfwYouLiveInMexico',
#   'Birates',
#   'dustin',
#   'menwritingwomen',
#   'excatholic',
#   'GayChristians',
#   'OpenChristian',
#   'RawAndReal',
#   'Neverbrokeabone',
#   'adhdmeme',
#   'LostBoysMemeGold',
#   'Fleabag',
#   'Monke',
#   'bigfloppa',
#   'TheLonelyStoner',
#   'SatanicTemple_Reddit',
#   'GusAndEddy',
#   'qvackson',
#   'Monterrey',
#   'aspiememes',
#   'CapuSEEno',
#   'marvelmemes',
#   'CloneWarsMemes',
#   'HolUp',
#   'TrashTaste',
#   'ShutupBelugaWhaleMan9',
#   'PrequelMemes',
#   'mydadwroteaporno',
#   'technicallythetruth',
#   'Hololive',
#   'FalcoCult',
#   'sharedwithlove',
#   'me_irl',
#   'INTJmemes',
#   'HannibalTV',
#   'themummymemes',
#   'cadum',
#   'lostpause',
#   'Punny',
#   'notinteresting',
#   'Dimension20',
#   'EmKay',
#   'HUEstation',
#   'NoRules',
#   'pyrocynical',
#   'UnexpectedJoJo',
#   'redditoryt',
#   'FreeKarma4You',
#   'MemesBrasil',
#   'DaniDev',
#   'akagas',
#   'Cursed_Images',
#   'anarchy',
#   'QuackityHQ',
#   'meme',
#   'shitposting',
#   'suddenlysexoffender',
#   'SpongebobMemes',
#   'holdup',
#   'stanpegasus',
#   'AnarchyChess',
#   'arkamahalle',
#   '3B9349145EA67F53',
#   'imveryedgy',
#   'bottomgear',
#   'aviationmemes',
#   'Davie504',
#   'deadmeatjames',
#   'OurFinalSolution',
#   'RADAL',
#   'LifeofBoris',
#   'PunPatrol',
#   'bulgaria',
#   'Reddit100k',
#   'NuxTakuSubmissions',
#   'michealreeves',
#   'KrazyRabb1t',
#   'LWIAY',
#   'AreTheCisOk',
#   'GrahamStephan',
#   'suicidebywords',
#   'KamikazeByWords',
#   'kingcobrajfs',
#   'CumTownChat',
#   'Atheist_Teens',
#   'exchristianmemes',
#   'Exvangelical',
#   'Joshua',
#   'dankvideos',
#   'oompasubs',
#   'A_EomionisVow',
#   'iDiedLookingAtThis',
#   'RedDwarf',
#   'FunnyandSad',
#   'theyknew',
#   'MurderedByWords',
#   'OverSimplified',
#   'Offensivejokes',
#   'Spoopychatmemes',
#   'starwarsmemes',
#   'metalgearsolid',
#   'Suicide4Fun',
#   'DelusionsOfAdequacy',
#   'simpsonsshitposting',
#   'tf2shitposterclub',
#   'TVTooHigh',
#   '2meirl4meirl',
#   'MansTooLit',
#   'AlienVsVigilante',
#   'characterarcs',
#   'DoctorMike',
#   'DustyLookatThis',
#   'MShumor',
#   'depression_memes',
#   'meirl',
#   'Hornyjail',
#   'biologymemes',
#   'Error418',
#   'HumanPeopleTwitter',
#   'INTP',
#   'cursedcomments',
#   'SixtySecondsInAfrica',
#   'Tautology',
#   'peachykeenocean',
#   '2meirl42meirl4meirl',
#   'clevercomebacks',
#   'AmericaBad',
#   'DrewGooden',
#   'ThatsWhatSheSaid',
#   'RoleReversal',
#   'gatesopencomeonin',
#   'demisexuality',
#   'aromantic',
#   'aaaaaaacccccccce',
#   'NonPoliticalTwitter',
#   'me_irlgbt',
#   'Satan',
#   '2mad4madlads',
#   'traaaaaaannnnnnnnnns',
#   'ADHDmemes',
#   'adhdwomen',
#   'areTheAllosOK',
#   'agender',
#   'ennnnnnnnnnnnbbbbbby',
#   'NonBinary',
#   'suspiciouslyspecific',
#   'getsomehelpbro',
#   'enby',
#   'GodDesigns',
#   'THUITFHNGL',
#   'countablepixels',
#   'southpark',
#   'drugmemes',
#   'intj',
#   'Culusclava',
#   'personalfinancememes',
#   'CPTSDmemes',
#   'waterniggees',
#   'waterhomies',
#   'CalPolyPomona',
#   'thanksimcured',
#   'Campey45',
#   'Joinen',
#   'DeepSpaceNine',
#   'Asexual',
#   'asexuality',
#   'ShittyLifeProTips',
#   'scottthewoz',
#   'naturebros',
#   'QuotesAurJokes',
#   'OneTopicAtATime',
#   'MadMax',
#   'MoldyMemes',
#   'GameOfThronesMemes',
#   'Slum_Police',
#   'UnexpectedBangtan',
#   '3meirl',
#   'ZeducationSubmissions',
#   'IncreasinglyVerbose',
#   'TheMemeNation',
#   'Limenade',
#   'wadzee',
#   'jedi',
#   'furrymemes',
#   'NFKRZ',
#   'FunnySupernatural',
#   'memenade',
#   'atheistmemes',
#   'boysarequirky',
#   'pointlesslygendered',
#   'ratatouillememes',
#   'absolutelynotme_irl',
#   'l3daisy',
#   'Funnymemes',
#   'ceciarmy',
#   'dannydevitomemes',
#   'spidermanmemes',
#   'Undertale',
#   'NessMains',
#   'asexualteens',
#   'Memes_Of_The_Dank',
#   'Randomawesomeness',
#   'SuddenlyTrans',
#   'KnowYourMeme',
#   'theodd1sout',
#   'marchingband',
#   'INTPmemes',
#   'JabyKoayFamily',
#   'OzMedia',
#   'Fibromyalgia',
#   'narcissisticparents',
#   'trans_irl',
#   'APStudents',
#   'ScienceHumour',
#   'enfj',
#   'corejerk',
#   'Dark_Hole',
#   'TheCutieClub',
#   'noyesyesyesno',
#   'otomegames',
#   'ChrisChanSonichu',
#   'Hadusinthefirsthalf',
#   'tumblr',
#   'ComedyBuddhism',
#   'richwcampbell',
#   'okbuddycraft',
#   'Fugglechumps',
#   'WoWComics',
#   'RandomCrap4teens',
#   'introvertmemes',
#   'penultimatepanel',
#   'VivaLaDirtLeague',
#   'DamienLee',
#   'KSU',
#   'uselessredcircle',
#   'Shoe0nHead',
#   'WitchMemes',
#   'starterpacks',
#   'examplepacks',
#   'criticaldesign',
#   'hingeapp',
#   'SmolBeanSnark',
#   'offtoxic',
#   'stopperpacks',
#   'TrustTheDog',
#   'absolutelynotmeirl',
#   'carnivorediet',
#   'suddenlytrap',
#   'Recursion',
#   'DrosteEffect',
#   'meta',
#   'DerClubMemes',
#   'AgainstKarmaWhores',
#   'cityplanning',
#   'startrekmemes',
#   'oakpark',
#   'NoFap',
#   'qwijibo',
#   'rgbroachgang',
#   'rgbroachgangwarroom',
#   'FBIOpenTheFuckUp',
#   'RoachSociety',
#   'beatMeatToIt',
#   'AccidentalRacism',
#   'FuckCaillou',
#   'thanosdidnothingwrong',
#   'Why',
#   'memeswithoutmods',
#   'HornyPolice',
#   'unexpectedfactorial',
#   'NuxTaku',
#   'antihomosexual',
#   'Memeulous',
#   'IndieDev',
#   'FurriesUncaged',
#   'hentaimemes',
#   'BubsyTheodoreBobcat',
#   'the_Bubsy',
#   'FurryBlep',
#   'LinuxYiff',
#   'linuxmasterrace',
#   'LinuxFurries',
#   'linuxmemes',
#   'gex',
#   'GaySoundsShitposts',
#   'OkBuddyCatgirl',
#   'foreverbox',
#   'ChronicIllness',
#   'Star_Trek',
#   'MadMudmen',
#   'Treknobabble',
#   'introvert',
#   'entp',
#   'PinkFloydCircleJerk',
#   'heartbreak',
#   'Marriage',
#   'Aphantasia',
#   'simpleliving',
#   'Agoraphobia',
#   'SapphoAndHerFriend',
#   'actuallesbians',
#   'AncientCivilizations',
#   'MandalorianMemes',
#   'IBO',
#   'bipolar_irl',
#   'BPDmemes',
#   'cfs',
#   'rareinsults',
#   'birthofasub',
#   'isfj',
#   'poopisland',
#   'ShittyTodayILearned',
#   'poopshitters',
#   'ShitCrusaderKingsSay',
#   'UniversityOfHouston',
#   'studentsph',
#   'covidlonghaulers',
#   'CapitalistClub',
#   'lupus',
#   'im14andthisisamogus',
#   'malta',
#   'Nordichistorymemes',
#   'unket',
#   'ShittyMapPorn',
#   'girlfriendreviews',
#   'KayseriGayBar',
#   'bookporn',
#   'wet_ognions',
#   'atrioc',
#   'UnitarianUniversalist',
#   'nihilism',
#   'Persona5',
#   'ITcrowd',
#   'threebodyproblem',
#   'Healthygamergg',
#   'GenZ',
#   'Zapatabanda',
#   'gatekeeping',
#   'AmongUsMemes',
#   'simplypodlogical',
#   'antimeme',
#   'wilbursoot',
#   'SwimmingMemes',
#   'walkr',
#   'BenedictCumberbatch',
#   'ImAllexx',
#   'suddenlybi',
#   'birdswithbutts',
#   'Charmx',
#   'physicsmemes',
#   'vicio',
#   'monures',
#   'Funesto',
#   'elitaGOH',
#   'Chadposting',
#   'AreTheOmnisOkay',
#   'ateismo_br',
#   'Mtf_irl',
#   'Im15AndThisIsYeet',
#   'dankruto',
#   'rubius',
#   'carmemes',
#   'Dank',
#   'CrappyDesign2',
#   'DitxizsenpaiUwU',
#   'AlexG_S',
#   'HistoryMemes',
#   'BollywoodRealism',
#   'HarryPotterMemes',
#   'Potterless',
#   '2truthand1lie',
#   'maxlukastim',
#   'DylanteroYT',
#   'MoaiGreddit',
#   'SlipperyPickles',
#   'For_Dreams',
#   'darussianbadger',
#   'cursedmemes',
#   'lfdownvotes',
#   'MemesThatMakeMeLaugh',
#   'sEND_MEmes',
#   'Brawlstars',
#   'VICIOOMT',
#   'Conor_Edwars',
#   'Antimassesteihalter',
#   'ketchuphate',
#   'kurtisconner',
#   'AreTheStraightsOkay',
#   'IvanhoeGrammarSchool',
#   'mallmilitiashit',
#   'holesome',
#   'ApexLegendsMemes',
#   'PhilosophyMemes',
#   'RickRollArmy',
#   'rickroll',
#   'RickRolled',
#   'SimonWhistler',
#   'tf_irl',
#   'cksz',
#   'SpaceCannibalism',
#   'unexpectedsabaton',
#   'ClassicalMemes',
#   'mathmemes',
#   'TheBirdCage',
#   'shittylifehacks',
#   'unexpectedcommunism',
#   'pigeon',
#   'SuddenlyCommunism',
#   'PewdiepieSubmissions',
#   'SpecialHumor',
#   'TopMemesUsers',
#   'technicallytrue',
#   'Idubbbz',
#   'nonbinarymemes',
#   'USDL',
#   'justgamedevthings',
#   'NewVegasMemes',
#   'FUTMobile',
#   'siRz_oWnlY',
#   'Webadas',
#   'ourSub',
#   'Relatable',
#   'pansexual',
#   'theboys_FREAKS',
#   'Khun_redagnes_sania',
#   'TheMandalorianTV',
#   'memesITA',
#   'VZC',
#   'engrish',
#   'craftivists',
#   'thethickofit',
#   'TakeDownNestle',
#   'DrewDurnil',
#   'DSPDiscussion',
#   'Shitty_Superpowers',
#   'overlyspecificEDmemes',
#   'StevenHe',
#   'siginak',
#   'HikaruNakamura',
#   'agadmatorOfficial',
#   'crosspost',
#   'mauerstrassenwetten',
#   'Memesfortheboiz',
#   'cleveradvertising',
#   'wholesomejojo',
#   'CuratedTumblr',
#   'Wholesome_Jail',
#   'SubsTakenLiterally',
#   'tf2memes',
#   'fitnesscirclejerk',
#   'Vanossgaming',
#   'ApexConsole',
#   'twenty_one_idiots',
#   'lietuva',
#   'fnki',
#   'rurounikenshin',
#   'wholesomereddit',
#   'Woodszin',
#   'miaudiggi',
#   'TNG',
#   'GoodStarTrek',
#   'memeframe',
#   'GhostAdventures',
#   'Blessed_Images',
#   'OTMemes',
#   'SequelMemes',
#   'TABG',
#   'pelotonmemes',
#   'B_A_A_L',
#   'MementoUnusAnnus',
#   'DreamWasTaken',
#   'H3VR',
#   'FrasierMemes',
#   'GameTheorists',
#   'The8BitRyanReddit',
#   'heraldry',
#   'EmptyBrainCase',
#   'Miata',
#   'goodomens',
#   'Shark_Park',
#   'AmongUs',
#   'lilboredx',
#   'Angryupvote',
#   'TheLetterH',
#   'MAAU',
#   'SnipingSoup',
#   'GardeninWithTheHomies',
#   'mademesmilecry',
#   'calvinandhobbes',
#   'nyanners',
#   'Jordan_Peterson_Memes',
#   'Modest_Pelican_Gaming',
#   'WillNE',
#   'SpastenSpielen',
#   'Bandmemes',
#   'IKEA',
#   'Overwatch',
#   'gaymers',
#   'rapedwarflore',
#   'IRLEasterEggs',
#   'spratti',
#   'Markiplier',
#   'Vulfpeck',
#   'Jung',
#   'SquarePosting',
#   'gmod',
#   'thisisnotadoor',
#   'Scoobydoo',
#   'animation',
#   'CollegeRant',
#   'palantir',
#   'okaybuddyretard',
#   'SamONellaAcademy',
#   'evergiven',
#   'SuezCanalMemes',
#   'wholesomefloridaman',
#   'SPCE',
#   'Swimming',
#   'elmo',
#   'CFL',
#   'MemeTemplatesOfficial',
#   'satanism',
#   'digimon',
#   'just2good',
#   'lesbianmemes',
#   'BattleForDreamIsland',
#   'katamari',
#   'deadpool',
#   'goodanimemes',
#   'Ningen',
#   'UnusAnnus_Remembrance',
#   'atheistvids',
#   'unlimited_saved_posts',
#   'cringepics',
#   'HoldMyChefKnife',
#   'fullbodycringe',
#   'StocazzoAndCo2',
#   'BlatantMisogyny',
#   'youngpeopleyoutube',
#   'Duklock',
#   'christianmemes',
#   'antiprotest',
#   'TrollCoping',
#   'depressionmemes',
#   'TheThirdPanel',
#   'MiniTitan46',
#   'gametheorymemes',
#   'ironmouse',
#   'merlinbbc',
#   'mfa_irl',
#   'ForShub',
#   'aaaaaaaarrrrro',
#   'caillouhate',
#   'siegememes',
#   'aprilfools',
#   'PeterExplainsTheJoke',
#   'Calfreezy',
#   'hellsomememes',
#   'ComicStrips',
#   'blursed_memes',
#   'darkmemers',
#   'widowdarkthirty',
#   'Codependency',
#   'sadcomics',
#   'dave',
#   'Staples',
#   'bi_irl',
#   'chickennuggets',
#   'SKIPJACK',
#   'SmashBrosUltimate',
#   'BONKpatrol',
#   'roomba',
#   'Memes_Central',
#   'foundsatan',
#   'OddlyWholesome',
#   '1200isfineIGUESSugh',
#   'carshitposting',
#   'welcometonightvale',
#   'NolanMemes',
#   'Tetris',
#   'ConfusedTravolta',
#   'churchofpeppermintxxx',
#   'chillsnarrator',
#   'thisismemetown',
#   'SympatheticMonsters',
#   'ShitpostXIV',
#   'GenZHumor',
#   'mendrawingwomen',
#   'psychologymemes',
#   'boottoobig',
#   'iastate',
#   'Harambe',
#   'BirdingMemes',
#   'bropill',
#   'Fellowkidssuccess',
#   'FellowKids',
#   'quithavingfun',
#   'AmongUsCirclejerk',
#   'socialanxiety',
#   'rhettandlink',
#   'Nordiccountries',
#   'klakinn',
#   'lgbtmemes',
#   'MadeOfStyrofoam',
#   'MandJTV',
#   'TomSka',
#   'musicmemes',
#   'MyOwnMemeCollection',
#   'gentlefemdom',
#   'sbubby',
#   'Doom',
#   'ChildrenOfTheCurd',
#   'BridgertonNetflix',
#   'misfits',
#   'YegorGang',
#   'InclusiveOr',
#   'ChargeYourPhone',
#   'wholesomememes',
#   'G0ularte',
#   'Umphreys',
#   'IsThisADonkey',
#   'BedBros',
#   'DidThisLastNight',
#   'nukedmemes',
#   'GachaClubCringe',
#   'backtomysandwich',
#   'PutBungerInSmashBros',
#   'OCDmemes',
#   'Megaten',
#   'roblox_arsenal',
#   'beatlescirclejerk',
#   'HealthAnxiety',
#   'shittycoolguides',
#   'Zerkaa',
#   'UNC',
#   'Caleb',
#   'OnionLovers',
#   'MotivateInspire',
#   'CollegeHomeworkTips',
#   'lovememes',
#   'SuddenlyLesbian',
#   'ChronicPain',
#   'personalgrowthchannel',
#   'LaughTrackComment',
#   'hololivememes',
#   'Blursed',
#   'acoupleofnerds',
#   'Tarantino',
#   'Sherlock',
#   'TheRawKnee',
#   'kidsarefuckingmetal',
#   'ChristopherNolan',
#   'matt',
#   'titanfall',
#   'LittleBearsSpace',
#   'DnDart',
#   'mildlyamusing',
#   'W2S',
# ...
#   'Evacuations',
#   'extremeweatherevents',
#   'Shalligators',
#   'runescape',
#   'JonBams',
#   'unexpectedrunescape',
#   'unexpectedstormlight',
#   'AllTrendingStuffs',
#   'beginnerfitness',
#   'podcasts',
#   'Post_Dogmatism',
#   'sociopath',
#   'kurzgefragt',
#   'barnotes',
#   'malcolminthemiddle',
#   'BeefyJerk',
#   'backpacking',
#   'BigBendNationalPark',
#   'forestgardening',
#   'NoTillGrowery',
#   'LandscapeArchitecture',
#   'Vonnegut',
#   'SustainableFarming',
#   'UCSC',
#   'yarntrolls',
#   'TheGoldbergs',
#   'freaksandgeeks',
#   'iguanas',
#   'AtlantaTV',
#   'betterCallSaul',
#   'AustinGardening',
#   'Macgyverhacks',
#   'climate_science',
#   'Greenhouses',
#   'yardens',
#   'EdiblePlants',
#   'AgroForestry',
#   'UrbanGardening',
#   'WeAreTOTS',
#   'AskDocs',
#   'ismailis',
#   'landscapestudent',
#   'youtubehomesteaders',
#   'OrganicGardening',
#   'Preppertips',
#   'UrbanHomestead',
#   'containergardening',
#   'GreenFarming',
#   'guerillagardening',
#   'Hugelkultur',
#   'FarmVlogs',
#   'BackToEden',
#   'quails',
#   'garden',
#   'Raisedbed',
#   'OutdoorSkills',
#   'GardenGrowth',
#   'PermacultureBushcraft',
#   'OffTheGrid',
#   'smallfarms',
#   'greenhouse',
#   'Agronomy',
#   'thereifixedit',
#   'u_cloyego',
#   'creativegardening',
#   'livingofftheland',
#   'biomass',
#   'Fruitorchard',
#   'Bushcraft',
#   'deep_ecology',
#   'MissFortuneMains',
#   'FrontRoyal',
#   'Thruhiking',
#   'WinterCampingTipsGear',
#   'depressed',
#   'thesfamily',
#   'infj',
#   'EREX98',
#   'librarians',
#   'FamilyMatters',
#   'abc',
#   'sitcoms',
#   '90sTV',
#   'roseanne',
#   'TheConners',
#   'EatCheapAndHealthy',
#   'blackberrygang',
#   'BlackberryYOLO',
#   'PENNYSTOCKMAFIA',
#   'HotPeppers',
#   'printers',
#   'ACQR',
#   'KatuQR',
#   'OKmarijuana',
#   'muskogee',
#   'u_KPGTOK',
#   'socialskills',
#   'suggestmeabook',
#   'Wrapping',
#   'ArtisanVideos',
#   'billiards',
#   'FavoriteMedia',
#   'entourage',
#   'themiddle',
#   'sexandthecity',
#   'TheRanch',
#   'TheITcrowd',
#   'ILoveLucy',
#   'twobrokegirls',
#   'GoldenGirlsTV',
#   'UnbreakableKimmy',
#   'FavoriteCharacter',
#   'FreshPrince',
#   'fullhouse',
#   'MomTVshow',
#   'blackadder',
#   'BetterOffTed',
#   'WillAndGrace',
#   'RaisingHope',
#   '3rdrockfromthesun',
#   'EverybodyLovesRaymond',
#   'thebigbangtheory',
#   'NetflixSexEducation',
#   'Blackish',
#   'MasterofNone',
#   'FreshOfftheBoatTV',
#   'SavedByTheBell',
#   'Atypical',
#   'Everybodyhateschris',
#   'GeorgeLopez',
#   'keepingupappearances',
#   'dickvandyke',
#   'AppleTVPlus',
#   'UltraCitySmiths',
#   'PerpetualGraceLTD',
#   'MegaCitySmiths',
#   'DonDeLillo',
#   'robertobolano',
#   'davidfosterwallace',
#   'Gaddis',
#   'InfiniteDiscussion',
#   'Bloodhound',
#   'plantclinic',
#   'plantdisease',
#   'Landscaping_australia',
#   'ForAllMankind',
#   'ClimbingPartners',
#   'Home_garden_india',
#   'pothos',
#   'UCSD',
#   'Hammocks',
#   'BuyCanadian',
#   'study',
#   'pollution_masks',
#   'Pesticides',
#   'TheSecretTomato',
#   'naturalburial',
#   'CasualConversation',
#   'YouOnLifetime',
#   'getdisciplined',
#   'GetMotivatedGroup',
#   'u_FarmMatch',
#   'CSA',
#   'localfood',
#   'FarmersMarkets',
#   'FarmersMarket',
#   'TruEugene',
#   'SpringfieldOR',
#   'bikemessengers',
#   'UbereatsUK',
#   'u_UsernamesIrrelevant',
#   'Obscureknowledge',
#   'SustainabilityPlus',
#   'prepperpics',
#   'TruePreppers',
#   'Fishingmemes',
#   'backpacks',
#   'notill',
#   'SquareFootGardening',
#   'Drylands',
#   'nativeplants',
#   'OutdoorHacks',
#   'garden_maintenance',
#   'outdoorsvideos',
#   'HomesteadGarden',
#   'OrganicFarming',
#   'ExplorersOfReality',
#   'Outdoor',
#   'survivalism',
#   'foodforests',
#   'RelaxingYouTubeVids',
#   'backpackingNcampcraft',
#   'Creators_Of_Youtube',
#   'GardeningWise',
#   'GardeningIndoors',
#   'u_Fareenavblogs',
#   'deals',
#   'DMR',
#   'electrictractors',
#   'Balconygardening',
#   'USNonLeague',
#   'concacaf',
#   'CaptainFalconMains',
#   'rational',
#   'hoggies',
#   'EsotericIslam',
#   'exatheist',
#   'RegenerativeProjects',
#   'opendata',
#   'GrowingPineNuts',
#   'wetlands',
#   'SoilScience',
#   'SoilBioengineering'],
#  ['vegan',
#   'AnimalRights',
#   'veganarchism',
#   'VeganJusticeLeague',
#   'PacificNorthwest',
#   'antinatalism',
#   'vegancirclejerk',
#   'BanFactoryFarming',
#   'cancun',
#   'welfarebiology',
#   'natureisterrible',
#   'vegetarian',
#   'ARActivismCanada',
#   'VeganForCircleJerkers',
#   'VeganActivism',
#   'subvertising',
#   'VeganAntinatalists',
#   'Efilism',
#   'Columbus',
#   'soup',
#   'kiwiworld',
#   'AnimalRescue',
#   'noscrapleftbehind',
#   'ZeroWasteVegans',
#   'goldhoard',
#   'GifRecipes',
#   'vegangifrecipes',
#   'ketodrunk',
#   'intermittentfasting',
#   'modernrogue',
#   'fasting',
#   '1200isplenty',
#   'kitchentalk',
#   'CheeseburgerClub',
#   'woocancook',
#   'HealthyGifRecipes',
#   'GFRecipeGifs',
#   'BGRecipes',
#   'veganrecipes',
#   'FuckCilantro',
#   'MexicanFoodGore',
#   'glutenfreerecipes',
#   '0000zxcv',
#   'BasicallyHomeless',
#   'ketotrees',
#   'pallascatfans',
#   'ketobeginners',
#   'MorgansCookbook',
#   'AnimeFood',
#   'ShokugekiNoSoma',
#   'ratelrecipes',
#   'MuffinEats',
#   'sanjiskitchen',
#   'SushiAbomination',
#   'highvegans',
#   'badatfocusing',
#   'KarlsRecipeSub',
#   'AcquiredTastes',
#   'anneandreese',
#   'AbsentAgony',
#   'ketorecipes',
#   'irl_error',
#   'moneymonkies',
#   'osmlkdengoso',
#   'MekkanikLearns',
#   'WastelandRecipeBook',
#   'Bento',
#   'NicksRecipes',
#   'YushisoRecipes',
#   'recipegifs',
#   'shitwithcheese',
#   'SuccessionTV',
#   'Sourdough',
#   'fermentation',
#   'OSU',
#   'aaa123',
#   'smoothbrain',
#   'habie',
#   'AIP_Recipes',
#   'cowboybebop',
#   'Dragonballsuper',
#   'dbz',
#   'onepotmeals',
#   'AgainstAnimalViolence',
#   'Veganism',
#   'AntifaVegan',
#   'Indiemakeupandmore',
#   'debatemeateaters',
#   'wildanimalsuffering',
#   'animalwelfare',
#   'Sentientism',
#   'EffectiveAltruism',
#   'StopSpeciesism',
#   'TrueAntinatalists',
#   'negativeutilitarians',
#   'EAAnimalAdvocacy',
#   'FactoryFarms',
#   'veganfitness',
#   'Veganivore',
#   'truecrimeohio',
#   'AnimalRebellion',
#   'VeganZeroWaste',
#   'BlackVegans',
#   'HinduVegans',
#   'VeganInfographics',
#   'veganfashionadvice',
#   'intersectionalVegans',
#   'nabaty',
#   'PETA',
#   'VeganMartyr',
#   'AnimalLiberation',
#   'Juicing',
#   'insectsuffering',
#   'VeganAww',
#   'VeganRights',
#   'VeganSchools',
#   'VeganDoctors',
#   'CraftsmanDirect',
#   'artwork',
#   'olddogs',
#   'rescuedogs',
#   'AntiVegetarians',
#   'Vegan_tattoos',
#   'VeganBaking',
#   'VeganChill',
#   'VeganIndia',
#   'RVAvegans',
#   'hinduism',
#   'veganmemes',
#   'oakland',
#   'glutenfreevegan',
#   'EatCheapAndVegan',
#   'IF_Petites',
#   'CICO',
#   'promortalism',
#   'Syracuse',
#   'altcoinforum',
#   'Athkneovism',
#   'VeganDE',
#   'IndiaDivine',
#   'BellevueWA',
#   'queensgambit',
#   'Vegan_Food',
#   'ARLAW',
#   'MobKitchen',
#   'WholeFoodsPlantBased',
#   'cadernodereceitas',
#   'FatMoms',
#   'AlternateDayFasting',
#   'Water_Fasting',
#   'PSA',
#   'changeourworld',
#   'TheNewActivist',
#   'Yucatan',
#   'EAjobs',
#   'shaivism',
#   'TeaPictures',
#   'IndianFoodPhotos',
#   'VeganFoodPorn',
#   'TeaPorn',
#   'budgetfood',
#   'TopSecretRecipes',
#   'veganart',
#   'fundiefood',
#   'AskAnAntinatalist',
#   'areweinhell',
#   'conflictresolution',
#   'AskVegans',
#   'VeganDiscussion',
#   'yrwnova',
#   'Morganeisenberg',
#   'AllDeliciousRecipes',
#   'GifRecipesKeto',
#   'cookingvideos',
#   'gifrecipeshealthy',
#   'veganuk',
#   'VegRecipes',
#   'Nicecream',
#   'herbs',
#   'vegancheesemaking',
#   'vegancheese',
#   'drunkvegans',
#   'DrunkVegan',
#   'omadvegan',
#   'VeganWeightGain',
#   'Cheesitarian',
#   'vegetarianrecipes',
#   'vegetarianfoodporn',
#   'evopsych',
#   'SecularHumanism',
#   'BirthandDeathEthics',
#   'CFB',
#   'Recipe_Redux',
#   'adbusters',
#   'u_AnyCalligrapher9430',
#   'Cooking',
#   'CandyMakers',
#   'u_WooCanCook',
#   'OaklandFood',
#   'u_strillointhebox',
#   'VeganFood',
#   'RecipeCollection',
#   'dairyfreerecipes',
#   'Vegan__Sensei',
#   'RobinHood',
#   'slowcooking',
#   'Siapproved',
#   'ketodieting',
#   'Keto_Diet',
#   'lowcarb',
#   'KetoMeals',
#   'Ketodietbeginners',
#   'keto_food_log',
#   'EasyKetoMeal',
#   'ketogenicdiet',
#   'ketosis',
#   'KetoSnacks',
#   'KetoFoodPorn',
#   'ketoporn',
#   'Keto_Maintenance',
#   'ketogenic',
#   'xenofeminism',
#   'Pessimism',
#   'kreisvegs',
#   'Lendinghand',
#   'SPEAKtruth',
#   'Burien',
#   'Anacortes',
#   'camaswashington',
#   'GraysHarbor',
#   'Longview',
#   'Marysville',
#   'federalway',
#   'Kirkland',
#   'Kitsap',
#   'MealPics',
#   'RateMyPlate',
#   'TastyFood',
#   'AmateurFoodPorn',
#   'tonightsdinner',
#   'Cheap_Meals',
#   'mexicanfood',
#   'VeganFashion',
#   'CellularAgriculture',
#   'treesactivists',
#   'soybeans',
#   'cruelbreeders',
#   'saveplanetearth',
#   'MercyForAnimals',
#   'Veganity',
#   'VeganVideos',
#   'watchingcongress',
#   'VeganAnarchistPOC',
#   'cozumel',
#   'QuintanaRoo',
#   'mauritius',
#   'WouldYouRather',
#   'Frugallearning',
#   'Mayan',
#   'tacos',
#   'chichenitza',
#   'ramen',
#   'FarmBill',
#   'independentmusic',
#   'fanart',
#   'eastbay',
#   'u_Viv_iannart',
#   'characterdesigns',
#   'Portraiture',
#   'DigitalArtGallery',
#   'portraits',
#   'Portraitart',
#   'ARTIST',
#   'thequeensgambit_tv',
#   'AnyaTaylorJoy',
#   'digitalarts',
#   'Anya_TaylorJoy',
#   'Artists',
#   'AnyaTaylor_Joy',
#   'ArtBuddy',
#   'fuckHOA',
#   'running',
#   'VeganBeauty',
#   'DebateAVegan',
#   'Veganforbeginners',
#   'HealthyEatingnow',
#   '15minutefood',
#   'Vegetarianism',
#   'ISKCON',
#   'TheRamayana',
#   'RamaBhajans',
#   'HinduTemplesRock',
#   'HinduArt',
#   'JaiShreeRam',
#   'bhajan',
#   'ShivaBhajans',
#   'HinduDiscussion',
#   'placesofworship',
#   'EatLessMeat',
#   'ElvenFood',
#   'budgetcooking',
#   'PutAnEggOnIt',
#   'bachelorchef',
#   'TemplesHindu',
#   'SHIVA',
#   'Uttarakhand',
#   'ChinmayaMission',
#   'Sadhguru',
#   'icm',
#   'KrishnaConsciousness',
#   'animalwelfarescience',
#   'veganJews',
#   'VeganInCanada',
#   'veganhatecirclejerk',
#   'VeganChat',
#   'VegansOfFaith',
#   'UKvegan',
#   'ARActivism',
#   'AntiVirals',
#   'HerbalMedicine',
#   'FoodIsMedicine',
#   'planetbaseddiet'],
#  ['Dachschaden',
#   'CCP_Virus_Censorship',
#   'asozialesnetzwerk',
#   'RotLichtViertel',
#   'Kommunismus',
#   'JacksFilms',
#   'Switzerland',
#   'umwelt_de',
#   'Weibsvolk',
#   'CoronavirusDACH',
#   'Laesterschwestern',
#   'de',
#   'berlin',
#   'de_EDV',
#   'PietSmiet',
#   '600euro',
#   'KommHuhnismus',
#   'germantrees',
#   'Mainz',
#   'MemesforFriendsACMF',
#   'KaIT',
#   'ich_iel',
#   'fuckCCP',
#   'keinstresskochen',
#   'cologne',
#   'BoostForReddit',
#   'Audiomemes',
#   'imaginary_toilets',
#   'karlsruhe',
#   'jwd',
#   'Leipzig',
#   'bremen',
#   'Muenster',
#   'Saarland',
#   'Nurnberg',
#   'stuttgart',
#   'dresden',
#   'Rostock',
#   'Dell',
#   'Metrology',
#   'AgingWheels',
#   'afdwatch',
#   'CDU_CSUde',
#   'Nachrichten',
#   'AFD',
#   'mikrooekonomen',
#   'pozilei',
#   'DeutscherMittelstand',
#   'CDU',
#   'kreishust',
#   'aachen',
#   'SozenMemes',
#   'LassMich',
#   'CoronaKritiker',
#   'Bier',
#   'EndTheCCP',
#   'geography',
#   'whygoogle',
#   'creepyPMs',
#   'Wissenschaft',
#   'nutzlosesniemand',
#   'ichbin40undlustig',
#   'Sesos',
#   'wortwitzkasse',
#   'Shrek',
#   'OkBrudiMongo',
#   'Fotzenfritz',
#   'u_nicolasvdr',
#   'GermanMemes',
#   'Anarchismus',
#   'Arbeiterbewegung',
#   'anarchie',
#   'DIE_LINKE',
#   'DiePartei',
#   'modnews',
#   'changelog',
#   'dredmorbius',
#   'GeschichtsMaimais',
#   'zeitzeugen',
#   'MillieWorkShop',
#   'YellowSonic',
#   'badflags',
#   'BadNepaliFlags',
#   'accidentalitalian'],
#  ['indianews',
#   'ABCDesis',
#   'lovefromabrownplanet',
#   'IndiansAcrossTheWorld',
#   'Chodi',
#   'Hijabis',
#   'yoga',
#   'India4all',
#   'IndiaNonPolitical',
#   'pune',
#   'ABCDCircleJerk',
#   'NewBrunswickNJ',
#   'TwoXIndia',
#   'humanize',
#   'MuslimMarriage',
#   'DesiTwoX',
#   'SouthAsianMasculinity',
#   'Kerala',
#   'BollyBlindsNGossip',
#   'AgainstHinduphobia',
#   'MarathiAsmita',
#   'MarathiMemes',
#   'shahanpana',
#   'MarathiMantra',
#   'MarathiMeme',
#   'MemesMarathi',
#   'IndianNewsBias',
#   'TheSubcontinent',
#   'bollywood',
#   'hindu',
#   'cmmreddit',
#   'HindutvaRises',
#   'Bhagwa_Feminism',
#   'EvangelistsOfIndia',
#   'IndiaConversionMafia',
#   'FascistIndianLeft',
#   'AnandaBanga',
#   'IndianMeyMeys',
#   'TheSouthAsia',
#   'Virathindumemes',
#   'indiapolicy',
#   'politicalhinduism',
#   'WesternHinduphobia',
#   'RightWingIndia',
#   'BharatasyaItihaas',
#   'unitedstatesofindia',
#   'NewDelhi',
#   'JammuandKashmir',
#   'jammu',
#   'JammuKashmir',
#   'kolkata',
#   'Parkinggonewild',
#   'karnataka',
#   'canconfirmiamindian',
#   'IndiansRead',
#   'Swatantra',
#   'VasudheivaKutumbakam',
#   'BollywoodFashion',
#   'u_meghnadasodissi',
#   'DailyHistoryIndia'],
#  ['okc',
#   'Porsche',
#   'Marvel',
#   'BeatemupsYTCommunity',
#   'Funnypics',
#   'lamborghini',
#   'KeanuReeves',
#   'Falcom',
#   'residentevil',
#   'Taycan',
#   'Daredevil',
#   'Defenders',
#   'capcom',
#   'StreetsofRage',
#   'NintendoSwitch',
#   'SwitchUpdates',
#   'midwestshitfest',
#   'Trailerclub',
#   'car',
#   'CallOfDutyMemes',
#   'HisDarkMaterialsBBC',
#   'Cadillac',
#   'exoticautos',
#   'ComicArtSociety',
#   'ImaginaryDC',
#   'WonderWoman',
#   'GhostRider',
#   'ImaginaryDemons',
#   'hulk',
#   'ComicsCentral',
#   'Inhumans',
#   'JessicaJones',
#   'thepunisher',
#   'new_comics_this_week',
#   'ImaginaryMarvel',
#   'drdoom',
#   'ImaginaryImmortals',
#   'comicbookcollecting',
#   'ImaginaryCarnage',
#   'comicbookart',
#   'u_sophie_valentine',
#   'SEGA',
#   'nintendo',
#   'SmartGamingDeals',
#   'BrzrkrByKeanu',
#   'comicbookshelves',
#   'indiecomics',
#   'retrocars',
#   'Ferrari',
#   'XYONetwork',
#   'Bugatti',
#   'superexotics',
#   'SupercarsAlliance',
#   'supercars',
#   'u_Acceptable_Ad_6952',
#   'DubaiExoticsAuction',
#   'whatcarshouldIbuy'],
#  ['bigfoot',
#   'creepypasta',
#   'Scary',
#   'AusMemes',
#   'unnerving',
#   'wanttobelieve',
#   'truecreepy',
#   'terrifying',
#   'GypsyRoad',
#   'UnexplainedPhenomena7',
#   'BigfootEncounters',
#   'theunexplained',
#   'SirSpooks',
#   'squatchersonly',
#   'UrbanLegends',
#   'cryptids',
#   'UrbanMyths',
#   'ParanormalReddit',
#   'MysteryMedia',
#   'Haunted',
#   'mysteriesoftheworld',
#   'veryspookyvideos',
#   'Unexplained',
#   'welcometohell',
#   'scaryasfuck',
#   'Paranormalsss',
#   'hauntedhouses',
#   'ghostsightings',
#   'Mandela_Effect',
#   'MetaMandela',
#   'MandelaEffectBenefits',
#   'mandelaeffects',
#   'ParallelUniverse',
#   'ShittyFanTheories',
#   'multiverse',
#   'matrixmemes',
#   'MatrixReality',
#   'Lets_Be_Friends'],
#  ['AmazonFBAOnlineRetail',
#   'u_Alseid',
#   'FacebookAds',
#   'startdropshipping',
#   'ecommentrepreneurs',
#   'AmazonSellerAbuse',
#   'amazondropshipping',
#   'DropshippingBiz',
#   'AmazonTools',
#   'PodcastSharing',
#   'AmazonFBATips',
#   'FBAadvanced',
#   'AmazonFBASellerTools',
#   'BetaTestersNeeded',
#   'u_Slowrolljoe',
#   'Dropshipping_France'],
#  ['murderers',
#   'forensics',
#   'crime',
#   'BeyondHorrors',
#   'DiscoveryID',
#   'murders',
#   'TrueCrimeLink',
#   'CrimePlus',
#   'CriminalProfiling',
#   'CrimeMugshots',
#   'ForensicPsych',
#   'serial_killers',
#   'UnsolvedCrime',
#   'MissingPersons',
#   'crime_documentaries'],
#  ['goodanimememes',
#   'guro',
#   'Weebdom',
#   'weeb',
#   'UnitedWeebFront',
#   'GoodAnimeme',
#   'GreatestAnimeMemes',
#   'MemesOfAnime',
#   'LandoftheWeebs',
#   'animeanarchist',
#   'Animememesforgods',
#   'guromemes'],
#  ['Koreanfilm',
#   '80s',
#   'TrulyBadCinema',
#   'AbsurdMovies',
#   'HKMovies',
#   'badMovies',
#   'ForeignMovies',
#   'Goremovies',
#   'kungfucinema',
#   'AsianMoviePulse',
#   'AsianFilmFans'],
#  ['Mexico_News',
#   'mexico_politics',
#   'polexico',
#   'privacidadmx',
#   'covidmx',
#   'Mexico_Videos',
#   'mexico_politicalhumor',
#   'POLACA',
#   'Mexico_FactCheck',
#   'Mexico_Economy'],
#  ['anime',
#   'araragi',
#   'steinsgate',
#   'LeviCult',
#   'ErwinSmith',
#   'Gintama',
#   'WiseWolfQuantumBunny',
#   'Anime4breakfast'],
#  ['SnekGang',
#   'OneTrueMiia',
#   'TongueTwisterGirls',
#   'Lamia',
#   'SFWmonstergirls',
#   'MonsterMusume',
#   'Miia',
#   'MonsterMusume_NSFW'],
#  ['arkmemes',
#   'playarkmobile',
#   'ARKSurvivalEvolved',
#   'u_Elite_StatusSaurus',
#   'ARK_pc',
#   'arkmeme',
#   'arkmobile'],
#  ['Lichfield',
#   'Stafford',
#   'StokeCityFC',
#   'stokeontrent',
#   'Tamworth',
#   'burtonontrent',
#   'Cannock'],
#  ['danganronpa',
#   'DanganronpaMemes',
#   'UltimateSwimmingPro',
#   'UltimatePhotographer',
#   'ultimategamer',
#   'CathedralOfChiaki'],
#  ['BOLIVIA',
#   'FranceInsoumise',
#   'melenchon',
#   'u_the_wildsheepnews',
#   'News_Feed'],
#  ['accelworld', 'awwnime', 'longhairedwaifus', 'ChurchofBelly'],
#  ['nikolainvestorsclub', 'NikolaCorporation', 'NKLA', 'RealNikola'],
#  ['EdmontonMarijuana',
#   'microgrowery',
#   'MagicBeansGenetics',
#   'Inhousegenetics'],
#  ['LeftySomalia', 'XSomalian', 'Somalia'],
#  ['nebraskajobs', 'TrueOmaha']]
