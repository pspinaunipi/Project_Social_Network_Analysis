# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import gc
import warnings
import numpy as np
import powerlaw
import praw
import random

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
def remove_useless_data(df):
    df_1 = df[df["parent"] == df["to"]]
    # delete duplicate rows from dataframe
    new_df = df.drop(df_1.index)
    #delete useless data to free memory
    del df,df_1
    gc.collect()
    #reset the indexes in the new DataFrame
    new_df.reset_index(inplace=True,drop=True)
    return new_df

# %%
if __name__=="__main__":

    data = pd.read_csv("scraping data/data/data_subreddit_direct.csv",index_col=0)
    no_duplicates = remove_useless_data(data)
    G = nx.convert_matrix.from_pandas_edgelist(no_duplicates,source = "parent",target="to",
                                                            edge_attr=True, create_using= nx.DiGraph())

# %%
nx.draw(G)
plt.show()

# %%
G.number_of_nodes()
# Out:
# 24819

# %%
G.number_of_edges()
# Out:
# 107094

# %%
G.is_directed()
# Out:
# True

# %%
data.shape
# Out:
# (107094, 6)

# %%
data.head()
# Out:
#    parent                 to  interactions  crossposts          date   weights
# 0  nature        environment        1746.0           1  1.619228e+09  7.465655
# 1  nature     EcoNewsNetwork         154.0          13  1.615282e+09  5.043425
# 2  nature        PublicLands           3.0           1  1.619177e+09  1.386294
# 3  nature  EndangeredSpecies          28.0           2  1.618449e+09  3.367296
# 4  nature       animalimpact           5.0           3  1.615263e+09  1.791759

# %%
for n in G.nodes():
    # do something
    pass
for e in G.edges():
    # do something
    pass

# %%
G.in_degree()
# Out:
# InDegreeView({'nature': 12, 'environment': 131, 'EcoNewsNetwork': 132, 'PublicLands': 4, 'EndangeredSpecies': 11, 'animalimpact': 17, 'sharks': 22, 'Soil': 3, 'Fuck_This_Guy': 16, 'vegan': 126, 'Animals': 11, 'UpliftingNews': 52, 'organizedhealing': 21, 'Green_News': 23, 'wildlifecorridors': 19, 'Outdoors': 25, 'SpeculativeEvolution': 8, 'WomenInNews': 2, 'TheFightThatMatters': 123, 'WomensRightsNews': 10, 'prochoice': 4, 'worldnews': 47, 'europes': 10, 'indepthstories': 17, 'Midwives': 1, 'catalonia': 9, 'blackladies': 3, 'ClimateCrisis': 14, 'xxstem': 1, 'HydroHomies': 127, 'anime_titties': 46, 'cleanstreetbets': 9, 'BigTent': 67, 'ClimateDenialism': 12, 'BigAgro': 9, 'DoomsdayNow': 33, 'DoomsdayBook': 22, 'greeninvestor': 10, 'DivineRightOfKings': 36, 'energy': 57, 'LockCarbon': 22, 'Toadbook': 12, 'SGU': 10, 'GoodRisingTweets': 308, 'Reterra': 2, 'organic': 6, 'left_urbanism': 28, 'EnoughMuskSpam': 26, 'bicycling': 30, 'patient_hackernews': 96, 'canadaleft': 56, 'CitizenPlanners': 7, 'KochWatch': 11, 'TaiwanChina': 17, 'taiwan': 22, 'TheEndOfHumanityShow': 20, 'soundsaboutright': 31, 'economy': 63, 'CapitalismInDecay': 6, 'Allopatria': 25, 'AnythingGoesNews': 53, 'ABoringDystopia': 181, 'Indigenous': 11, 'Hozhor': 14, 'PlantBased4ThePlanet': 18, 'sustainability': 44, 'Ohio': 24, 'Agriculture': 10, 'climatejustice': 18, 'GreatLakes': 6, 'RuralDemocrats': 32, 'climateaction': 34, 'climatepolicy': 33, 'DemocracyNow': 22, 'usa': 95, 'ClimateChangeSolution': 32, 'USNews2': 45, 'USGovernment': 41, 'usapolitics': 8, 'world': 77, 'WarOnEarth': 10, 'europe': 39, 'alltheleft': 143, 'TheAbditory': 153, 'terrifyingstatistics': 20, 'Communalists': 42, 'wheresthebeef': 6, 'GreenConsumersUnion': 3, 'newjersey': 11, 'Energy_unbiased': 8, 'NuclearPower': 18, 'airlines': 9, 'florida': 24, 'DemocratsforDiversity': 35, 'EarthEnthusiasts': 23, 'PlanetEarth': 6, 'ClimateAndEnvironment': 37, 'planet': 10, 'ClimateActivism': 19, 'netzero': 5, 'CleanEnergy': 34, 'north_america': 25, 'EmissionsTax': 2, 'carboncapture': 8, 'northamerica': 29, 'Hawaii': 10, 'goodnews': 49, 'hawaiinews': 3, 'Restoration_Ecology': 11, 'oceans': 11, 'CoralRestoration': 8, 'Positivity': 14, 'marinebiology': 21, 'environmentaljustice': 20, 'ClimateActionPlan': 30, 'ocean': 20, 'Futurology': 50, 'Michigan_Politics': 6, 'solarpower': 11, 'gmc': 3, 'michigandemocrats': 4, 'midwest': 8, 'michiganpolitics': 12, 'Renewable': 27, 'usanews': 43, 'solarpowerplants': 3, 'windpower': 9, '2030': 2, 'climateskeptics': 23, 'ClimateNews': 11, 'smartcities': 16, 'SouthAsia': 12, 'IndiaSpeaks': 45, 'airpollution': 6, 'indianews': 42, 'Cities': 29, 'Sustainable': 39, 'RenewableEnergy': 21, 'AppleInvestors': 2, 'WarfNews': 13, 'SunriseMovement': 23, 'ideasforgovt': 13, 'PhysicalGeography': 11, 'Kossacks_for_Sanders': 112, 'veganscience': 11, 'Environmentalism': 42, 'Green': 48, 'PeopleDoGood': 11, 'GetIt2Gether': 3, 'FuckNestle': 26, 'collapse': 41, 'vego': 27, 'lostgeneration': 121, 'AmazoNope': 22, 'ArmedEnvironmentalism': 13, 'uspolitics': 63, 'HC_Capitalism': 23, 'NoLawns': 8, 'AtheismComedy': 32, 'LocalismEngland': 11, 'IndianCountry': 22, 'UnfuckTheWorld': 15, 'actualconspiracies': 1, 'Corruption': 54, 'workthatreconnects': 7, 'Permanence': 3, 'MachineThatMakesMoney': 27, 'TechOfTheFuture': 12, 'water': 13, 'StopFossilFuels': 3, 'Systemic_Risk': 11, 'ausenviro': 2, 'DystopiaToday': 24, 'China_irl': 55, 'bioscience': 7, 'AnimalRights': 43, 'veganarchism': 16, 'climate': 24, 'ForestHealth': 11, 'SearchScene': 3, 'doomists': 10, 'brasil': 78, 'greatfilterpodcast': 2, 'Cleveland': 6, 'GreatLakesPrepping': 1, 'Environmental_Policy': 33, '2020': 43, 'OhioGovernment': 2, 'Cetacea': 7, 'Positive_News': 53, 'whales': 25, 'CarbonFootprint': 5, 'GreenNewDeal': 22, 'GreenNewIdeas': 6, 'decarbonize': 1, 'coal': 9, 'FossilFuels': 7, '2035': 2, 'COVID19RippleEffects': 27, 'AnarchoPacifism': 8, 'theworldnews': 11, 'environmentallaw': 7, 'EnvironmentProtectors': 2, 'greed': 19, 'RuralNewsNetwork': 174 ...

# %%
G.out_degree()
# Out:
# OutDegreeView({'nature': 16, 'environment': 217, 'EcoNewsNetwork': 54, 'PublicLands': 6, 'EndangeredSpecies': 8, 'animalimpact': 1, 'sharks': 2, 'Soil': 3, 'Fuck_This_Guy': 31, 'vegan': 65, 'Animals': 5, 'UpliftingNews': 222, 'organizedhealing': 0, 'Green_News': 44, 'wildlifecorridors': 4, 'Outdoors': 15, 'SpeculativeEvolution': 0, 'WomenInNews': 14, 'TheFightThatMatters': 0, 'WomensRightsNews': 13, 'prochoice': 1, 'worldnews': 1126, 'europes': 7, 'indepthstories': 18, 'Midwives': 0, 'catalonia': 0, 'blackladies': 2, 'ClimateCrisis': 7, 'xxstem': 0, 'HydroHomies': 46, 'anime_titties': 71, 'cleanstreetbets': 2, 'BigTent': 7, 'ClimateDenialism': 0, 'BigAgro': 1, 'DoomsdayNow': 12, 'DoomsdayBook': 0, 'greeninvestor': 5, 'DivineRightOfKings': 0, 'energy': 124, 'LockCarbon': 1, 'Toadbook': 0, 'SGU': 0, 'GoodRisingTweets': 0, 'Reterra': 0, 'organic': 4, 'left_urbanism': 9, 'EnoughMuskSpam': 1, 'bicycling': 16, 'patient_hackernews': 0, 'canadaleft': 13, 'CitizenPlanners': 1, 'KochWatch': 7, 'TaiwanChina': 8, 'taiwan': 25, 'TheEndOfHumanityShow': 0, 'soundsaboutright': 6, 'economy': 75, 'CapitalismInDecay': 0, 'Allopatria': 0, 'AnythingGoesNews': 30, 'ABoringDystopia': 146, 'Indigenous': 2, 'Hozhor': 1, 'PlantBased4ThePlanet': 10, 'sustainability': 44, 'Ohio': 51, 'Agriculture': 4, 'climatejustice': 30, 'GreatLakes': 18, 'RuralDemocrats': 6, 'climateaction': 6, 'climatepolicy': 2, 'DemocracyNow': 0, 'usa': 99, 'ClimateChangeSolution': 0, 'USNews2': 24, 'USGovernment': 89, 'usapolitics': 0, 'world': 35, 'WarOnEarth': 0, 'europe': 354, 'alltheleft': 105, 'TheAbditory': 0, 'terrifyingstatistics': 0, 'Communalists': 66, 'wheresthebeef': 18, 'GreenConsumersUnion': 0, 'newjersey': 4, 'Energy_unbiased': 5, 'NuclearPower': 5, 'airlines': 7, 'florida': 9, 'DemocratsforDiversity': 14, 'EarthEnthusiasts': 3, 'PlanetEarth': 0, 'ClimateAndEnvironment': 0, 'planet': 0, 'ClimateActivism': 0, 'netzero': 0, 'CleanEnergy': 3, 'north_america': 19, 'EmissionsTax': 1, 'carboncapture': 0, 'northamerica': 13, 'Hawaii': 3, 'goodnews': 52, 'hawaiinews': 0, 'Restoration_Ecology': 2, 'oceans': 5, 'CoralRestoration': 6, 'Positivity': 0, 'marinebiology': 17, 'environmentaljustice': 4, 'ClimateActionPlan': 57, 'ocean': 2, 'Futurology': 621, 'Michigan_Politics': 10, 'solarpower': 0, 'gmc': 1, 'michigandemocrats': 0, 'midwest': 3, 'michiganpolitics': 2, 'Renewable': 27, 'usanews': 8, 'solarpowerplants': 0, 'windpower': 12, '2030': 0, 'climateskeptics': 9, 'ClimateNews': 3, 'smartcities': 0, 'SouthAsia': 0, 'IndiaSpeaks': 41, 'airpollution': 0, 'indianews': 4, 'Cities': 18, 'Sustainable': 20, 'RenewableEnergy': 35, 'AppleInvestors': 8, 'WarfNews': 0, 'SunriseMovement': 15, 'ideasforgovt': 0, 'PhysicalGeography': 37, 'Kossacks_for_Sanders': 28, 'veganscience': 12, 'Environmentalism': 15, 'Green': 42, 'PeopleDoGood': 3, 'GetIt2Gether': 0, 'FuckNestle': 17, 'collapse': 110, 'vego': 0, 'lostgeneration': 77, 'AmazoNope': 3, 'ArmedEnvironmentalism': 1, 'uspolitics': 37, 'HC_Capitalism': 0, 'NoLawns': 2, 'AtheismComedy': 0, 'LocalismEngland': 25, 'IndianCountry': 34, 'UnfuckTheWorld': 18, 'actualconspiracies': 0, 'Corruption': 7, 'workthatreconnects': 0, 'Permanence': 0, 'MachineThatMakesMoney': 0, 'TechOfTheFuture': 0, 'water': 14, 'StopFossilFuels': 0, 'Systemic_Risk': 0, 'ausenviro': 2, 'DystopiaToday': 0, 'China_irl': 8, 'bioscience': 3, 'AnimalRights': 5, 'veganarchism': 4, 'climate': 70, 'ForestHealth': 1, 'SearchScene': 1, 'doomists': 0, 'brasil': 28, 'greatfilterpodcast': 0, 'Cleveland': 3, 'GreatLakesPrepping': 0, 'Environmental_Policy': 20, '2020': 0, 'OhioGovernment': 5, 'Cetacea': 4, 'Positive_News': 12, 'whales': 2, 'CarbonFootprint': 0, 'GreenNewDeal': 12, 'GreenNewIdeas': 0, 'decarbonize': 0, 'coal': 0, 'FossilFuels': 3, '2035': 0, 'COVID19RippleEffects': 27, 'AnarchoPacifism': 1, 'theworldnews': 0, 'environmentallaw': 1, 'EnvironmentProtectors': 0, 'greed': 2, 'RuralNewsNetwork': 15, 'realtruthpolitics': 0, 'MAGAs': 56, 'libclimateactivism': 7, 'neoliberal': ...

# %%
#Degree Centrality
indegrees = dict(G.in_degree())
ranks = [(k, v) for k, v in sorted(indegrees.items(), key=lambda item: -item[1])]
ranks[0:]
# Out:
# [('GoodRisingTweets', 308),
#  ('LateStageCapitalism', 221),
#  ('aww', 217),
#  ('Pikabu', 190),
#  ('PublicFreakout', 186),
#  ('ABoringDystopia', 181),
#  ('premiuminternet', 180),
#  ('VaushV', 179),
#  ('RuralNewsNetwork', 174),
#  ('awfuleverything', 172),
#  ('Anarcho_Capitalism', 162),
#  ('Anarchism', 158),
#  ('TIHI', 157),
#  ('WayOfTheBern', 154),
#  ('TheAbditory', 153),
#  ('therewasanattempt', 153),
#  ('COMPLETEANARCHY', 145),
#  ('yourmomshousepodcast', 145),
#  ('alltheleft', 143),
#  ('Political_Revolution', 143),
#  ('AbruptChaos', 143),
#  ('MxRMods', 135),
#  ('antiwork', 133),
#  ('EcoNewsNetwork', 132),
#  ('environment', 131),
#  ('HolUp', 130),
#  ('DemocraticSocialism', 128),
#  ('HydroHomies', 127),
#  ('oddlyterrifying', 127),
#  ('vegan', 126),
#  ('TheFightThatMatters', 123),
#  ('lostgeneration', 121),
#  ('AntifascistsofReddit', 120),
#  ('Ytqaz2019', 120),
#  ('Bad_Cop_No_Donut', 118),
#  ('dontputyourdickinthat', 116),
#  ('FUCKYOUINPARTICULAR', 115),
#  ('BirdsArentReal', 114),
#  ('DownloadVideo', 113),
#  ('Kossacks_for_Sanders', 112),
#  ('Bossfight', 111),
#  ('nonononoyes', 110),
#  ('MakeMeSuffer', 105),
#  ('socialism', 102),
#  ('yesyesyesyesno', 102),
#  ('ACAB', 101),
#  ('animalsdoingstuff', 97),
#  ('patient_hackernews', 96),
#  ('technicallythetruth', 96),
#  ('Instantregret', 96),
#  ('usa', 95),
#  ('Superstonk', 94),
#  ('International', 94),
#  ('Formyberb', 94),
#  ('donthelpjustfilm', 94),
#  ('NoLockedThreads', 92),
#  ('conspiracy', 92),
#  ('KGBTR', 92),
#  ('killthecameraman', 92),
#  ('SweatyPalms', 91),
#  ('MyPeopleNeedMe', 91),
#  ('Hasan_Piker', 90),
#  ('NoNewNormal', 88),
#  ('Whatcouldgowrong', 88),
#  ('oddlysatisfying', 86),
#  ('JordanPeterson', 85),
#  ('thalassophobia', 84),
#  ('shitposting', 84),
#  ('mildlyinfuriating', 82),
#  ('Astuff', 81),
#  ('GME', 81),
#  ('forbiddensnacks', 81),
#  ('brasilivre', 80),
#  ('LPOTL', 80),
#  ('nope', 79),
#  ('brasil', 78),
#  ('me_irl', 78),
#  ('world', 77),
#  ('wholesome', 76),
#  ('yesyesyesno', 76),
#  ('IASIP', 75),
#  ('SuddenlyGay', 75),
#  ('fucktheccp', 74),
#  ('nouseforatitle', 73),
#  ('Eyebleach', 73),
#  ('BakaNewsJP', 72),
#  ('DidntKnowIWantedThat', 72),
#  ('MiscellaneousContent', 71),
#  ('LeftWithoutEdge', 71),
#  ('ANormalDayInRussia', 71),
#  ('thedavidpakmanshow', 70),
#  ('JustUnsubbed', 70),
#  ('trees', 70),
#  ('h3h3productions', 69),
#  ('ItemShop', 69),
#  ('perfectlycutscreams', 69),
#  ('union', 68),
#  ('GenZedong', 68),
#  ('thanksihateit', 68),
#  ('LooneyTunesLogic', 68),
#  ('Satisfyingasfuck', 68),
#  ('BigTent', 67),
#  ('GreenAndPleasant', 67),
#  ('cellbits', 67),
#  ('WhyWomenLiveLonger', 67),
#  ('anJoDelCo', 66),
#  ('likeus', 66),
#  ('iboopyou', 66),
#  ('actualliberalgunowner', 65),
#  ('Catswithjobs', 65),
#  ('worldpolitics', 64),
#  ('lgbt', 64),
#  ('PavelQualityMemes', 64),
#  ('economy', 63),
#  ('uspolitics', 63),
#  ('RepublicanValues', 63),
#  ('toptalent', 63),
#  ('DiscoverEarth', 62),
#  ('woahdude', 62),
#  ('hitmanimals', 62),
#  ('PrequelMemes', 62),
#  ('Trumpet_of_Discord', 61),
#  ('savedPostyStuff', 61),
#  ('jimmydore', 60),
#  ('pics', 60),
#  ('religiousfruitcake', 59),
#  ('totallynotrobots', 59),
#  ('NoRules', 59),
#  ('ConcentrationOfWealth', 58),
#  ('DankLeft', 58),
#  ('Currentlytripping', 58),
#  ('energy', 57),
#  ('CoronavirusCirclejerk', 57),
#  ('exmormon', 57),
#  ('ReptiloidsLeague', 57),
#  ('pyrocynical', 57),
#  ('canadaleft', 56),
#  ('leftistveterans', 56),
#  ('FuckYouKaren', 56),
#  ('megalophobia', 56),
#  ('mildlypenis', 56),
#  ('China_irl', 55),
#  ('UnitedSlothSaves', 55),
#  ('Mujico', 55),
#  ('youseeingthisshit', 55),
#  ('trippy', 55),
#  ('burgers_and_sushi', 55),
#  ('mostrepostedposts', 55),
#  ('Hornyjail', 55),
#  ('Corruption', 54),
#  ('JusticeServed', 54),
#  ('weed', 54),
#  ('SelfAwarewolves', 54),
#  ('Awww', 54),
#  ('ProperAnimalNames', 54),
#  ('AccidentalSlapStick', 54),
#  ('AnythingGoesNews', 53),
#  ('Positive_News', 53),
#  ('BlackLivesMatter', 53),
#  ('ActualPublicFreakouts', 53),
#  ('JustGuysBeingDudes', 53),
#  ('gifsthatkeepongiving', 53),
#  ('UpliftingNews', 52),
#  ('labor', 52),
#  ('exchristian', 52),
#  ('myfavoritemurder', 52),
#  ('MarchAgainstNazis', 52),
#  ('ireland', 52),
#  ('Aoxxt2', 52),
#  ('rickygervais', 52),
#  ('uffz', 52),
#  ('neoliberal', 51),
#  ('Beebola', 51),
#  ('NEWPOLITIC', 51),
#  ('DanLeBatardShow', 51),
#  ('IWW', 51),
#  ('shittyaskscience', 51),
#  ('EmKay', 51),
#  ('WhitePeopleTwitter', 51),
#  ('BreadTube', 51),
#  ('WhatsWrongWithYourDog', 51),
#  ('Futurology', 50),
#  ('musharado', 50),
#  ('goodnews', 49),
#  ('YangForPresidentHQ', 49),
#  ('Fuck45', 49),
#  ('AnarchismZ', 49),
#  ('IronFrontUSA', 49),
#  ('dsa', 49),
#  ('BrandNewSentence', 49),
#  ('chonglangTV', 49),
#  ('KitchenConfidential', 49),
#  ('france', 49),
#  ('LunaNegra', 49),
#  ('DunderMifflin', 49),
#  ('titleporn', 49),
#  ('theyknew', 49),
#  ('Green', 48),
#  ('occupywallstreet', 48),
#  ('antinatalism', 48),
#  ('CartoonMoment', 48),
#  ('ExtinctionRebellion', 48),
#  ('DeliriumSC', 48),
#  ('SorcerersVsSuffering', 48),
#  ('yourlearningcurve', 48),
#  ('TheDepthsBelow', 48),
#  ('funnyvideos', 48),
#  ('noisygifs', 48),
#  ('PraiseTheCameraMan', 48),
#  ('TILI', 48),
#  ('cakebeans', 48),
#  ('worldnews', 47),
#  ('deepfatfried', 47),
#  ('AmericanPolitics', 47),
#  ('NoahGetTheBoat', 47),
#  ('LateStageImperialism', 47),
#  ('IdiotsFightingThings', 47),
#  ('anarchocommunism', 47),
#  ('KyleTaylor', 47),
#  ('watchpeoplesurvive', 47),
#  ('DinosaurKnight', 47),
#  ('Memes_Of_The_Dank', 47),
#  ('TheLowCalCalzoneZone', 47),
#  ('anime_titties', 46),
#  ('Honkyandthebadger', 46),
#  ('Government_is_lame', 46),
#  ('McRecap', 46),
#  ('IveSeenThatOneAlready', 46),
#  ('GifsErestynLikes', 46),
#  ('USNews2', 45),
#  ('IndiaSpeaks', 45),
#  ('internettoday', 45),
#  ('conservatives', 45),
#  ('WallStreetbetsELITE', 45),
#  ('politics', 45),
#  ('nursing', 45),
#  ('Zoomies', 45),
#  ('AnimalsBeingStrange', 45),
#  ('cute', 45),
#  ('GTAorRussia', 45),
#  ('cat', 45),
#  ('sustainability', 44),
#  ('DemocraticDiscussions', 44),
#  ('GlobalNews', 44),
#  ('Iamactuallyverybadass', 44),
#  ('interesting', 44),
#  ('HumansAreMetal', 44),
#  ('solarpunk', 44),
#  ('nevertellmetheodds', 44),
#  ('PublicRumpus', 44),
#  ('ContagiousLaughter', 44),
#  ('PlayItAgainSam', 44),
#  ('DiWHY', 44),
#  ('redneckengineering', 44),
#  ('usanews', 43),
#  ('AnimalRights', 43),
#  ('2020', 43),
#  ('boringdystopia', 43),
#  ('MarshallBrain', 43),
#  ('newsokunomoral', 43),
#  ('collapze', 43),
#  ('Grimdank', 43),
#  ('discworld', 43),
#  ('Tierzoo', 43),
#  ('confusingperspective', 43),
#  ('PeopleFuckingDying', 43),
#  ('GenZommunist', 43),
#  ('Communalists', 42),
#  ('indianews', 42),
#  ('Environmentalism', 42),
#  ('Cyberpunk', 42),
#  ('ksi', 42),
#  ('fragilecommunism', 42),
#  ('ape', 42),
#  ('worldnews247', 42),
#  ('interestingasfuck', 42),
#  ('StoppedWorking', 42),
#  ('MXRplays', 42),
#  ('ThatLookedExpensive', 42),
#  ('mesodumb', 42),
#  ('TheRightCantMeme', 42),
#  ('USGovernment', 41),
#  ('collapse', 41),
#  ('2020PoliceBrutality', 41),
#  ('StallmanWasRight', 41),
#  ('imatotalpeiceofshit', 41),
#  ('LincolnProject', 41),
#  ('Trumpvirus', 41),
#  ('texas', 41),
#  ('PandR', 41),
#  ('Master0fwar', 41),
#  ('infp', 41),
#  ('instantkarma', 41),
#  ('DaniDev', 41),
#  ('PaymoneyWubby', 41),
#  ('WhatsWrongWithYourCat', 41),
#  ('MAGAs', 40),
#  ('ANormalDayInAmerica', 40),
#  ('BigTech', 40),
#  ('esist', 40),
#  ('protest', 40),
#  ('accidentallycommunist', 40),
#  ('GreenParty', 40),
#  ('wowfuckthewhat', 40),
#  ('walmart', 40),
#  ('Chadtopia', 40),
#  ('cremposting', 40),
#  ('stabbot', 40),
#  ('Makesmybloodboil', 40),
#  ('GradualChaos', 40),
#  ('LaschesTeilen', 40),
#  ('IllegallySmolCats', 40),
#  ('europe', 39),
#  ('Sustainable', 39),
#  ('HillbillyNerdTalk', 39),
#  ('LeopardsAteMyFace', 39),
#  ('DonutOperator', 39),
#  ('democracy', 39),
#  ('TimPool', 39),
#  ('PoliticalCompassMemes', 39),
#  ('aesthetics13_saved', 39),
#  ('adhdmeme', 39),
#  ('DivorcedBirds', 39),
#  ('tippytaps', 39),
#  ('AAAAAAAAAAAAAAAAA', 39),
#  ('watchthingsfly', 39),
#  ('gifsthatendtoosoon', 39),
#  ('TheCatReport', 39),
#  ('actuallesbians', 39),
#  ('WtWBBot', 39),
#  ('audihertz', 38),
#  ('SyndiesUnited', 38),
#  ('PoliticalPundits', 38),
#  ('police', 38),
#  ('Philippines', 38),
#  ('seculartalk', 38),
#  ('theydidthemath', 38),
#  ('MSsEcReTPoDcAsT', 38),
#  ('seinfeld', 38),
#  ('CoronavirusRecession', 38),
#  ('LouderWithCrowder', 38),
#  ('China', 38),
#  ('bisexual', 38),
#  ('awwwtf', 38),
#  ('dannygroen', 38),
#  ('misleadingthumbnails', 38),
#  ('VideosPraVerChapado', 38),
#  ('delola3100', 38),
#  ('kayotic123', 38),
#  ('holdmyfeedingtube', 38),
#  ('NuxTakuSubmissions', 38),
#  ('TwoBestFriendsPlay', 38),
#  ('ClimateAndEnvironment', 37),
#  ('ZeroWaste', 37),
#  ('SocialistRA', 37),
#  ('Anticonsumption', 37),
#  ('demsocialists', 37),
#  ('NormMacdonald', 37),
#  ('EssentialEmployees', 37),
#  ('Firearms', 37),
#  ('Mindalteringsituation', 37),
#  ('EntitledBitch', 37),
#  ('AnarchistGenerationZ', 37),
#  ('WalmartCelebrities', 37),
#  ('urbanplanning', 37),
#  ('CatsStandingUp', 37),
#  ('UpvotedBecauseBoobs', 37),
#  ('DivineRightOfKings', 36),
#  ('EnoughTrumpSpam', 36),
#  ('CCP_virus', 36),
#  ('AntiComAction', 36),
#  ('TopReposts', 36),
#  ('AtheisticTeens', 36),
#  ('valheim', 36),
#  ('ThingsWeeLike', 36),
#  ('IrrationalMadness', 36),
#  ('fightporn', 36),
#  ('dankvideos', 36),
#  ('Spoopychatmemes', 36),
#  ('aaaaaaacccccccce', 36),
#  ('Lazysharer', 36),
#  ('DemocratsforDiversity', 35),
#  ('leftist', 35),
#  ('PostScarcityNow', 35),
#  ('mexico', 35),
#  ('UnitedNations', 35),
#  ('teenagersnew', 35),
#  ('Damnthatsinteresting', 35),
#  ('ForOtherPeople', 35),
#  ('GlitchInTheMatrix', 35),
#  ('MEOW_IRL', 35),
#  ('Thisismylifemeow', 35),
#  ('climateaction', 34),
#  ('CleanEnergy', 34),
#  ('TimDillon', 34),
#  ('AirForce', 34),
#  ('extremelyinfuriating', 34),
#  ('MBMBAM', 34),
#  ('420PT', 34),
#  ('HumanForScale', 34),
#  ('aspiememes', 34),
#  ('upvotebecauseboy', 34),
#  ('DayMemeing', 34),
#  ('FullShrimp', 34),
#  ('FunnyandSad', 34),
#  ('untrustworthypoptarts', 34),
#  ('INTP', 34),
#  ('Catculations', 34),
#  ('ClassicalLibertarians', 34),
#  ('ozzonepazzopazzopazzo', 34),
#  ('DoomsdayNow', 33),
#  ('climatepolicy', 33),
#  ('Environmental_Policy', 33),
#  ('QualityOfLifeLobby', 33),
#  ('UpliftingPraxis', 33),
#  ('conspiracy_commons', 33),
#  ('gay', 33),
#  ('gardening', 33),
#  ('whatintarnation', 33),
#  ('AquaticAsFuck', 33),
#  ('nightvale', 33),
#  ('2007scape', 33),
#  ('EllesHappyPlace', 33),
#  ('holdmyfries', 33),
#  ('AmericasSocialists', 33),
#  ('TerminallyStupid', 33),
#  ('2meirl4meirl', 33),
#  ('RuralDemocrats', 32),
#  ('ClimateChangeSolution', 32),
#  ('AtheismComedy', 32),
#  ('MeidasTouch', 32),
#  ('newyorkcity', 32),
#  ('thestateofshit', 32),
#  ('The_Mueller', 32),
#  ('AntiHateCommunities', 32),
#  ('gunpolitics', 32),
#  ('daverubin', 32),
#  ('CoronavirusUS', 32),
#  ('Digital_Manipulation', 32),
#  ('technology', 32),
#  ('chaoticgood', 32),
#  ('GeorgeFloydRevolution', 32),
#  ('DangelsHub', 32),
#  ('neocentrism', 32),
#  ('CommunismWorldwide', 32),
#  ('Reddit50k', 32),
#  ('squashmountainscouts', 32),
#  ('southafrica', 32),
#  ('business', 32),
#  ('newsokur', 32),
#  ('somecoolguys', 32),
#  ('30ROCK', 32),
#  ('Neverbrokeabone', 32),
#  ('KarmaConspiracy', 32),
#  ('PutYourDickInThat', 32),
#  ('catsarealiens', 32),
#  ('LibertarianSocialism', 32),
#  ('killedthecameraman', 32),
#  ('UpvoteBecauseButt', 32),
#  ('ryryandtay', 32),
#  ('mine75', 32),
#  ('COVID', 32),
#  ('ChildrenFallingOver', 32),
#  ('2truthand1lie', 32),
#  ('PartyParrot', 32),
#  ('cringepics', 32),
#  ('soundsaboutright', 31),
#  ('Fuckthealtright', 31),
#  ('PeopleBeingAssholes', 31),
#  ('newsokuexp', 31),
#  ('MorbidReality', 31),
#  ('TheMajorityReport', 31),
#  ('Qult_Headquarters', 31),
#  ('shitamericanspayfor', 31),
#  ('InternetCommentEtiq', 31),
#  ('NewPatriotism', 31),
#  ('Turkey', 31),
#  ('islam', 31),
#  ('ToiletPaperUSA', 31),
#  ('minnesota', 31),
#  ('ClimateOffensive', 31),
#  ('DescentIntoTyranny', 31),
#  ('LateStageCarnism', 31),
#  ('worldnews2', 31),
#  ('confidentlyincorrect', 31),
#  ('gay_irl', 31),
#  ('YogurtOwlsInLove', 31),
#  ('mildlyterrifying', 31),
#  ('flatearth', 31),
#  ('zblinks', 31),
#  ('fakehistoryporn', 31),
#  ('animalsbytodd', 31),
#  ('worldnewsvideo', 31),
#  ('UnexpectedJoJo', 31),
#  ('instantbarbarians', 31),
#  ('CrazyHuman', 31),
#  ('LibertarianLeft', 31),
#  ('A_EomionisVow', 31),
#  ('coltonsmemes', 31),
#  ('bicycling', 30),
#  ('ClimateActionPlan', 30),
#  ('fuckyoufascists', 30),
#  ('DefundPolice', 30),
#  ('AIandRobotics', 30),
#  ('ShitLiberalsSay', 30),
#  ('Republican', 30),
#  ('WorldNews_Serious', 30),
#  ('2020Election', 30),
#  ('onguardforthee', 30),
#  ('sendinthetanks', 30),
#  ('VeganForCircleJerkers', 30),
#  ('destiny2', 30),
#  ('FuckYouParty', 30),
#  ('AnimalsBeingMoms', 30),
#  ('LateStageColonialism', 30),
#  ('pomfreymd', 30),
#  ('hacha', 30),
#  ('makesitlookeasy', 30),
#  ('Nuthinbuttrouble', 30),
#  ('IllegallySmol', 30),
#  ('LiminalSpace', 30),
#  ('ConfusedBoners', 30),
#  ('lostpause', 30),
#  ('savedtosendyou', 30),
#  ('holdmyjuicebox', 30),
#  ('MadeMeCry', 30),
#  ('DenseGifs', 30),
#  ('justforsocialmedia', 30),
#  ('InternationalLeft', 30),
#  ('Benjibulia', 30),
#  ('1MostImportantStuff', 30),
#  ('catsarefuckingstupid', 30),
#  ('Covid19_economics', 30),
#  ('Corridor', 30),
#  ('Blessed_Images', 30),
#  ('HeavyFuckingWind', 30),
#  ('repost', 30),
#  ('northamerica', 29),
#  ('Cities', 29),
#  ('FuckTheProudBoys', 29),
#  ('policebrutality', 29),
#  ('humanrights', 29),
#  ('conspiracyfact', 29),
#  ('aznidentity', 29),
#  ('GeoVideos', 29),
#  ('democraticparty', 29),
#  ('PeoplesPartyUSA', 29),
#  ('TheDollop', 29),
#  ('ClimateMemes', 29),
#  ('PoliticalVideo', 29),
#  ('Thatsactuallyverycool', 29),
#  ('DudeFuckThat', 29),
#  ('nextfuckinglevel', 29),
#  ('wholesomegifs', 29),
#  ('maybemaybemaybemaybe', 29),
#  ('Crazyppl', 29),
#  ('suddenlysexoffender', 29),
#  ('tooktoomuch', 29),
#  ('AbruptComposure', 29),
#  ('CitationsNeeded', 29),
#  ('pointlesslygendered', 29),
#  ('CatsBeingCats', 29),
#  ('left_urbanism', 28),
#  ('enviroaction', 28),
#  ('EarningTheHate', 28),
#  ('nyc', 28),
#  ('FreeSpeech', 28),
#  ('Dear_Mr_Atheist', 28),
#  ('iamapieceofshit', 28),
#  ('oddlyspecific', 28),
#  ('NewsHub', 28),
#  ('2020electioncrisis', 28),
#  ('DeclineIntoCensorship', 28),
#  ('drugscirclejerk', 28),
#  ('Interesting_Shit', 28),
#  ('twicewife', 28),
#  ('satisfying', 28),
#  ('Shittyaskflying', 28),
#  ('ShamelesslyStolen', 28),
#  ('bigboye', 28),
#  ('90dayfianceuncensored', 28),
#  ('Meetingofthemindz', 28),
#  ('CatTaps', 28),
#  ('WhyCatHowCat', 28),
#  ('CatsAreAssholes', 28),
#  ('videosthatendtoosoon', 28),
#  ('holdmycosmo', 28),
#  ('AnimalsBeingGeniuses', 28),
#  ('LifeofBoris', 28),
#  ('upvotebecausebear', 28),
#  ('PunPatrol', 28),
#  ('CumTownChat', 28),
#  ('BookStew', 28),
#  ('starwarsmemes', 28),
#  ('LeftieZ', 28),
#  ('InformedTankie', 28),
#  ('ShittyLifeProTips', 28),
#  ('fail_gifs', 28),
#  ('Renewable', 27),
#  ('vego', 27),
#  ('MachineThatMakesMoney', 27),
#  ('COVID19RippleEffects', 27),
#  ('StandAgainstTyranny', 27),
#  ('HowGodWorks', 27),
#  ('maskfreakouts', 27),
#  ('TheBellmanStillRings', 27),
#  ('AmericanFascism2020', 27),
#  ('Belgium_kingdomOf', 27),
#  ('Snorkblot', 27),
#  ('chomsky', 27),
#  ('timesuck', 27),
#  ('AOC', 27),
#  ('lotrmemes', 27),
#  ('onsshareplekkie', 27),
#  ('Castelbon', 27),
#  ('OddlyArousing', 27),
#  ('ntbdbiwdfta', 27),
#  ('hmm', 27),
#  ('copaganda', 27),
#  ('InterestingVideoClips', 27),
#  ('holdmybraincells', 27),
#  ('AccidentalTerrorism', 27),
#  ('AdultsAreFuckinStupid', 27),
#  ('lingling40hrs', 27),
#  ('oompasubs', 27),
#  ('suspiciouslyspecific', 27),
#  ('Jreg', 27),
#  ('woof_irl', 27),
#  ('knowyourshit', 27),
#  ('forgotthethe', 27),
#  ('StupidFood', 27),
#  ('FullScorpion', 27),
#  ('MAAU', 27),
#  ('EnoughMuskSpam', 26),
#  ('FuckNestle', 26),
#  ('BlackFridayProtest', 26),
#  ('These_Fucking_People', 26),
#  ('Military', 26),
#  ('NEWSfun', 26),
#  ('SzechuanSauceSeekers', 26),
#  ('iamanutterpieceofshit', 26),
#  ('2ALiberals', 26),
#  ('inthenews', 26),
#  ('CarsCarbsCardsKabis', 26),
#  ('Quebec', 26),
#  ('UnexpectedlyWholesome', 26),
#  ('foreignpolicy', 26),
#  ('LatinAmerica', 26),
#  ('asozialesnetzwerk', 26),
#  ('MapPorn', 26),
#  ('awwtf', 26),
#  ('AccidentalWesAnderson', 26),
#  ('BirdsAreWeird', 26),
#  ('Monke', 26),
#  ('GusAndEddy', 26),
#  ('mindMYcrack', 26),
#  ('catdimension', 26),
#  ('TibblesandRosie', 26),
#  ('lunzen', 26),
#  ('IdiotsOnBikes', 26),
#  ('justneckbeardthings', 26),
#  ('CrazyFuckingVideos', 26),
#  ('ZeroFucksWereGiven', 26),
#  ('ItHadToBeBrazil', 26),
#  ('TikTokCringe', 26),
#  ('asianpeoplegifs', 26),
#  ('perfectlycutyeets', 26),
#  ('ParentsAreFuckingDumb', 26),
#  ('moon2mars', 26),
#  ('tloaHuman', 26),
#  ('formuladank', 26),
#  ('xqcow', 26),
#  ('khajiithaswares', 26),
#  ('ofcoursethatsathing', 26),
#  ('The8BitRyanReddit', 26),
#  ('cats', 26),
#  ('BONKpatrol', 26),
#  ('thecatdimension', 26),
#  ('Outdoors', 25),
#  ('Allopatria', 25),
#  ('north_america', 25),
#  ('whales', 25),
#  ('WeAreNotAsking', 25),
#  ('hotposts', 25),
#  ('jakeandamir', 25),
#  ('AntiVegan', 25),
#  ('trans', 25),
#  ('ArcherFX', 25),
#  ('BasicIncome', 25),
#  ('SocialDemocracy', 25),
#  ('HighStrangeness', 25),
#  ('FreeAsInFreedom', 25),
#  ('electricvehicles', 25),
#  ('theserfstv', 25),
#  ('SoundsLikeMusic', 25),
#  ('RealLifePokemon', 25),
#  ('TheLewinsons', 25),
#  ('Breath_of_the_Wild', 25),
#  ('4g11', 25),
#  ('mildyinteresting', 25),
#  ('ApexOutlands', 25),
#  ('3dorks1brain', 25),
#  ('Natureiscursed', 25),
#  ('subnautica', 25),
#  ('beyondwholesome', 25),
#  ('reddeadredemption2', 25),
#  ('BicyclingCirclejerk', 25),
#  ('ItsNotJustInYourHead', 25),
#  ('Hirnschiss', 25),
#  ('VoluntaristMemes', 25),
#  ('AAVideoArchive', 25),
#  ('thelauras', 25),
#  ('Tendies', 25),
#  ('FunnyASF', 25),
#  ('MoldyMemes', 25),
#  ('Veganism', 25),
#  ('Tiresaretheenemy', 25),
#  ('dailyspam', 25),
#  ('worldeconomy', 25),
#  ('shittyrobots', 25),
#  ('AreTheOmnisOkay', 25),
#  ('VredditDownloader', 25),
#  ('michaelbaygifs', 25),
#  ('accidentalwrestling', 25),
#  ('FinalDestinationShit', 25),
#  ('nasstyb1tch', 25),
#  ('Ohio', 24),
#  ('florida', 24),
#  ('DystopiaToday', 24),
#  ('climate', 24),
#  ('EmergingRisks', 24),
#  ('USMC', 24),
#  ('CapitolConsequences', 24),
#  ('CallToActionWisconsin', 24),
#  ('BidenCoalition', 24),
#  ('infuriatingasfuck', 24),
#  ('bayarea', 24),
#  ('EuropeanNews', 24),
#  ('Capitalism', 24),
#  ('CITILOP', 24),
#  ('ActiveMeasures', 24),
#  ('worldevents', 24),
#  ('NoahGetTheDeathStar', 24),
#  ('fuqae', 24),
#  ('johngrillo', 24),
#  ('indonesia', 24),
#  ('norwayonreddit', 24),
#  ('walkaway', 24),
#  ('mayahiga', 24),
#  ('absoluteunit', 24),
#  ('thefighterandthekid', 24),
#  ('trypophobia', 24),
#  ('Sneks', 24),
#  ('Mihrberg', 24),
#  ('bending', 24),
#  ('Target', 24),
#  ('WatchAnimalsDieInside', 24),
#  ('sidekickofsteele', 24),
#  ('OkBuddyPoliceOfficer', 24),
#  ('akagas', 24),
#  ('BeardTube', 24),
#  ('Construction', 24),
#  ('seenstit', 24),
#  ('enlightenedbirdmen', 24),
#  ('TheLeftCantMeme', 24),
#  ('0000xfyuzn', 24),
#  ('scody15', 24),
#  ('clevercomebacks', 24),
#  ('me_irlgbt', 24),
#  ('BobsBurgers', 24),
#  ('Jesswouldlikethat', 24),
#  ('qwijibo', 24),
#  ('DogsAreFuckingStupid', 24),
#  ('Charmx', 24),
#  ('StuffJazzMightLike', 24),
#  ('goodhumorforfuckssake', 24),
#  ('BurningAsFuck', 24),
#  ('Funmix', 24),
#  ('InternationalDev', 24),
#  ('coolguides', 24),
#  ('OuchMyBalls', 24),
#  ('SneakyBackgroundFeet', 24),
#  ('howtokeepanidiotbusy', 24),
#  ('Green_News', 23),
#  ('EarthEnthusiasts', 23),
#  ('climateskeptics', 23),
#  ('SunriseMovement', 23),
#  ('HC_Capitalism', 23),
#  ('AmazonFC', 23),
#  ('oregon', 23),
#  ('NewOrleans', 23),
#  ('Idiotswithguns', 23),
#  ('Dailyslant', 23),
#  ('ArcanaPost', 23),
#  ('USPS', 23),
#  ('howardstern', 23),
#  ('COVIDGoodNews', 23),
#  ('sweden', 23),
#  ('CryptoCurrency', 23),
#  ('argentina', 23),
#  ('Sham_Sharma_Show', 23),
#  ('theAlgorithmHasSpoken', 23),
#  ('ccp', 23),
#  ('newyork', 23),
#  ('impoliteconversation', 23),
#  ('CreaturesOfTheHaunt', 23),
#  ('thingsforants', 23),
#  ('ItsRainingMemes', 23),
#  ('qcGottaSeeThis', 23),
#  ('whatsthisallabout', 23),
#  ('enissa', 23),
#  ('rance', 23),
#  ('TheLastAirbender', 23),
#  ('titanfolk', 23),
#  ('natureisfuckingmetal', 23),
#  ('Birbs', 23),
#  ('hmmm', 23),
#  ('FirstNameBasis', 23),
#  ('meme', 23),
#  ('goodpraxis', 23),
#  ('dumbasseswithlighters', 23),
#  ('HeheMoment', 23),
#  ('thestraightdopesub', 23),
#  ('CinnamonToastKen', 23),
#  ('BadChoicesGoodStories', 23),
#  ('tf2shitposterclub', 23),
#  ('ScaryTechnology', 23),
#  ('3Dprinting', 23),
#  ('HelloInternet', 23),
#  ('specializedtools', 23),
#  ('Labour', 23),
#  ('Achievement_Hunter', 23),
#  ('memeswithoutmods', 23),
#  ('NuxTaku', 23),
#  ('CoronaVirusWorldNews', 23),
#  ('capitalism_in_decay', 23),
#  ('SneakyAnimals', 23),
#  ('tamperstew', 23),
#  ('electricians', 23),
#  ('onejob', 23),
#  ('holdmycatnip', 23),
#  ('watchcatsdieinside', 23),
#  ('Lubriderm', 23),
#  ('libertarianunity', 23),
#  ('crosspost', 23),
#  ('mindblowing', 23),
#  ('anything', 23),
#  ('DamnThatsTerrifying', 23),
#  ('sharks', 22),
#  ('DoomsdayBook', 22),
#  ('LockCarbon', 22),
#  ('taiwan', 22),
#  ('DemocracyNow', 22),
#  ('AmazoNope', 22),
#  ('IndianCountry', 22),
#  ('GreenNewDeal', 22),
#  ('GunsAreCool', 22),
#  ('atheism', 22),
#  ('TrueAnon', 22),
#  ('ThereIsNoBottom', 22),
#  ('thesystemisrigged', 22),
#  ('cnn', 22),
#  ('AmazonDSPDrivers', 22),
#  ('Moronavirus', 22),
#  ('UnethicalCompanies', 22),
#  ('Seenthatcoming', 22),
#  ('politicly', 22),
#  ('pakistan', 22),
#  ('OneyPlays', 22),
#  ('revolution', 22),
#  ('uninsurable', 22),
#  ('AnInfuriatingDystopia', 22),
#  ('RealBlueMidterm', 22),
#  ('mildlyevangelion', 22),
#  ('CasualUK', 22),
#  ('Wallstreetbetsnew', 22),
#  ('YangGang', 22),
#  ('TrueAntiVaccination', 22),
#  ('Accounting', 22),
#  ('HowHumanBeingsWork', 22),
#  ('excatholic', 22),
#  ('StardewValley', 22),
#  ('ViolentlyAdorable', 22),
#  ('STFUitsadragon', 22),
#  ('Pareidolia', 22),
#  ('dumaflache', 22),
#  ('Epicentr', 22),
#  ('gtaonline', 22),
#  ('Cursed_Images', 22),
#  ('qcFunny', 22),
#  ('mallninjashit', 22),
#  ('suddenlytractor', 22),
#  ('Campey45', 22),
#  ('OneTopicAtATime', 22),
#  ('AntiMSM', 22),
#  ('goldhoard', 22),
#  ('poopisland', 22),
#  ('Founditsavedit', 22),
#  ('Sustainable_Energy', 22),
#  ('VZC', 22),
#  ('physicsgifs', 22),
#  ('SubsTakenLiterally', 22),
#  ('iwouldtotallybuythis', 22),
#  ('blackcats', 22),
#  ('organizedhealing', 21),
#  ('marinebiology', 21),
#  ('RenewableEnergy', 21),
#  ('SocialismAndVeganism', 21),
#  ('wisconsin', 21),
#  ('AllCopsAreBad', 21),
#  ('capitolcoup', 21),
#  ('women', 21),
#  ('ems', 21),
#  ('BerniesRevolution', 21),
#  ('BrasildoB', 21),
#  ('TheWorkersCouncil', 21),
#  ('Healthcare_costs', 21),
#  ('massachusetts', 21),
#  ('AntiAmazon', 21),
#  ('Coronaphobia', 21),
#  ('Seattle', 21),
#  ('BabyBumps', 21),
#  ('golf', 21),
#  ('badwomensanatomy', 21),
#  ('childrenofdemocracy', 21),
#  ('Psychedelics', 21),
#  ('DamnNatureYouScary', 21),
#  ('Feminism', 21),
#  ('NewColdWar', 21),
#  ('Scotland', 21),
#  ('SomeOrdinaryGmrs', 21),
#  ('playboicarti', 21),
#  ('Foxhidesinfo', 21),
#  ('InconvenientFacts', 21),
#  ('waterbros', 21),
#  ('awwnverts', 21),
#  ('Green_Anarchism', 21),
#  ('freefolk', 21),
#  ('ShowTheKids', 21),
#  ('HappyAndRelaxing', 21),
#  ('FuckYouImAShark', 21),
#  ('blockchainio', 21),
#  ('Giraffesdontexist', 21),
#  ('sharedwithlove', 21),
#  ('BirdsBeingDicks', 21),
#  ('NotMeantToBeFunny', 21),
#  ('VeganAntinatalists', 21),
#  ('AnarchyChess', 21),
#  ('peopleofwalmart', 21),
#  ('videoswithsubtitles', 21),
#  ('Dogsfreakout', 21),
#  ('BitchImATrain', 21),
#  ('adorableoldpeople', 21),
#  ('dresdenfiles', 21),
#  ('ANormalDayInIndia', 21),
#  ('Error418', 21),
#  ('gatesopencomeonin', 21),
#  ('AdviceAtheists', 21),
#  ('thanksimcured', 21),
#  ('MeansTV', 21),
#  ('DrinkingProblems', 21),
#  ('uselessredcircle', 21),
#  ('GenZapatista', 21),
#  ('antimeme', 21),
#  ('fbiagent37', 21),
#  ('trashpandas', 21),
#  ('shittyfoodporn', 21),
#  ('SamONellaAcademy', 21),
#  ('1gay', 21),
#  ('TheEndOfHumanityShow', 20),
#  ('terrifyingstatistics', 20),
#  ('environmentaljustice', 20),
#  ('ocean', 20),
#  ('PoliceAccountability1', 20),
#  ('DarkViperAU', 20),
#  ('LaceyWA', 20),
#  ('RacismAgainstAsians', 20),
#  ('autism', 20),
#  ('NotoQanon', 20),
#  ('Connecticut', 20),
#  ('CorpFree', 20),
#  ('AntiTrumpAlliance', 20),
#  ('PKA', 20),
#  ('biology', 20),
#  ('exjw', 20),
#  ('BroProduction', 20),
#  ('SandersForPresident', 20),
#  ('EarthStrike', 20),
#  ('hungary', 20),
#  ('ReplaceCapitalism', 20),
#  ('CuriousAndFascinating', 20),
#  ('China_Debate', 20),
#  ('BillBurr', 20),
#  ('FreePolDiscussion', 20),
#  ('internationalpolitics', 20),
#  ('republicans', 20),
#  ('Sciencology', 20),
#  ('atheismindia', 20),
#  ('FloridaPolitics', 20),
#  ('shittydarksouls', 20),
#  ...]

# %%
outdegrees = dict(G.out_degree())
ranks = [(k, v) for k, v in sorted(outdegrees.items(), key=lambda item: -item[1])]
ranks[0:]
# Out:
# [('interestingasfuck', 2732),
#  ('nextfuckinglevel', 2377),
#  ('funny', 2071),
#  ('PublicFreakout', 1880),
#  ('aww', 1613),
#  ('Unexpected', 1492),
#  ('Damnthatsinteresting', 1336),
#  ('memes', 1273),
#  ('politics', 1192),
#  ('science', 1140),
#  ('worldnews', 1126),
#  ('gifs', 1121),
#  ('news', 1101),
#  ('pics', 990),
#  ('NatureIsFuckingLit', 926),
#  ('oddlysatisfying', 871),
#  ('WTF', 836),
#  ('Whatcouldgowrong', 751),
#  ('WinStupidPrizes', 710),
#  ('WatchPeopleDieInside', 697),
#  ('mildlyinteresting', 662),
#  ('MadeMeSmile', 661),
#  ('Futurology', 621),
#  ('ForUnitedStates', 602),
#  ('IdiotsInCars', 602),
#  ('BeAmazed', 594),
#  ('technology', 536),
#  ('todayilearned', 532),
#  ('ThatsInsane', 530),
#  ('AnimalsBeingDerps', 518),
#  ('videos', 514),
#  ('Wellthatsucks', 501),
#  ('instant_regret', 477),
#  ('dataisbeautiful', 467),
#  ('AbruptChaos', 427),
#  ('coolguides', 412),
#  ('maybemaybemaybe', 411),
#  ('HolUp', 404),
#  ('therewasanattempt', 402),
#  ('Eyebleach', 398),
#  ('natureismetal', 395),
#  ('dankmemes', 392),
#  ('facepalm', 358),
#  ('europe', 354),
#  ('TikTokCringe', 353),
#  ('blackmagicfuckery', 353),
#  ('nottheonion', 336),
#  ('Coronavirus', 335),
#  ('wallstreetbets', 330),
#  ('WhitePeopleTwitter', 329),
#  ('awfuleverything', 299),
#  ('TIHI', 296),
#  ('PoliticalHumor', 286),
#  ('BetterEveryLoop', 285),
#  ('Cringetopia', 278),
#  ('wholesomememes', 276),
#  ('AnimalsBeingJerks', 272),
#  ('blursedimages', 266),
#  ('space', 265),
#  ('gaming', 258),
#  ('shitposting', 248),
#  ('hackernews', 243),
#  ('oddlyterrifying', 239),
#  ('Bad_Cop_No_Donut', 236),
#  ('MakeMeSuffer', 234),
#  ('perfectlycutscreams', 224),
#  ('iamatotalpieceofshit', 223),
#  ('UpliftingNews', 222),
#  ('woahdude', 221),
#  ('environment', 217),
#  ('KidsAreFuckingStupid', 215),
#  ('worldnewsvideo', 211),
#  ('LateStageCapitalism', 207),
#  ('MapPorn', 207),
#  ('youseeingthisshit', 205),
#  ('ActualPublicFreakouts', 203),
#  ('mildlyinfuriating', 203),
#  ('trashy', 203),
#  ('CPUSA', 199),
#  ('ATBGE', 199),
#  ('gifsthatkeepongiving', 198),
#  ('teenagers', 196),
#  ('CatastrophicFailure', 191),
#  ('DiWHY', 188),
#  ('instantkarma', 187),
#  ('Awwducational', 183),
#  ('AskReddit', 182),
#  ('ANormalDayInRussia', 177),
#  ('BreadTube', 175),
#  ('VideosMP4', 175),
#  ('196', 171),
#  ('JusticeServed', 170),
#  ('WayOfTheBern', 168),
#  ('toptalent', 167),
#  ('educationalgifs', 166),
#  ('AnimalsBeingBros', 164),
#  ('BlackPeopleTwitter', 163),
#  ('cats', 162),
#  ('ActualFreakouts', 161),
#  ('tumblr', 161),
#  ('Documentaries', 160),
#  ('fightporn', 159),
#  ('holdmycosmo', 158),
#  ('comics', 154),
#  ('conspiracy', 151),
#  ('rarepuppers', 151),
#  ('ABoringDystopia', 146),
#  ('Anarchism', 146),
#  ('specializedtools', 144),
#  ('Art', 144),
#  ('International', 143),
#  ('EverythingScience', 142),
#  ('PeopleFuckingDying', 141),
#  ('technicallythetruth', 139),
#  ('Instantregret', 138),
#  ('AbsoluteUnits', 136),
#  ('HumansBeingBros', 134),
#  ('StartledCats', 134),
#  ('UnitedNations', 133),
#  ('PraiseTheCameraMan', 130),
#  ('Zoomies', 129),
#  ('WhatsWrongWithYourDog', 129),
#  ('announcements', 129),
#  ('HistoryMemes', 126),
#  ('holdmybeer', 126),
#  ('energy', 124),
#  ('IdiotsNearlyDying', 124),
#  ('me_irl', 123),
#  ('photoshopbattles', 122),
#  ('3Dprinting', 122),
#  ('SweatyPalms', 121),
#  ('yesyesyesyesno', 121),
#  ('CrappyDesign', 120),
#  ('LifeProTips', 119),
#  ('Conservative', 119),
#  ('NoNewNormal', 118),
#  ('CoronavirusUS', 118),
#  ('stupidpol', 118),
#  ('SandersForPresident', 117),
#  ('OneSecondBeforeDisast', 117),
#  ('COMPLETEANARCHY', 116),
#  ('NoahGetTheBoat', 116),
#  ('AgainstHateSubreddits', 116),
#  ('Political_Revolution', 115),
#  ('cursedcomments', 115),
#  ('Refdrops', 115),
#  ('LeopardsAteMyFace', 114),
#  ('holdmyfeedingtube', 113),
#  ('HadToHurt', 111),
#  ('collapse', 110),
#  ('nonononoyes', 110),
#  ('tooktoomuch', 110),
#  ('lgbt', 107),
#  ('CasualUK', 107),
#  ('alltheleft', 105),
#  ('IdiotsFightingThings', 104),
#  ('pyrocynical', 104),
#  ('ContagiousLaughter', 104),
#  ('GifRecipes', 103),
#  ('Superstonk', 102),
#  ('GlobalNews', 101),
#  ('FuckYouKaren', 101),
#  ('tippytaps', 101),
#  ('MurderedByWords', 100),
#  ('usa', 99),
#  ('insanepeoplefacebook', 98),
#  ('movies', 98),
#  ('Economics', 98),
#  ('GME', 97),
#  ('comedyheaven', 97),
#  ('EarthPorn', 97),
#  ('TheLegacyFHP', 97),
#  ('NewDealAmerica', 96),
#  ('PrequelMemes', 96),
#  ('AreTheStraightsOkay', 96),
#  ('australia', 96),
#  ('2020PoliceBrutality', 95),
#  ('MarchAgainstNazis', 94),
#  ('AmericanFascism2020', 94),
#  ('IllegallySmolCats', 94),
#  ('IAmA', 93),
#  ('NuxTakuSubmissions', 92),
#  ('FragrantHarbour', 91),
#  ('Libertarian', 90),
#  ('beyondwholesome', 90),
#  ('dankvideos', 90),
#  ('Hornyjail', 90),
#  ('USGovernment', 89),
#  ('GreenAndPleasant', 88),
#  ('StrangeAndFunny', 87),
#  ('nevertellmetheodds', 86),
#  ('privacy', 86),
#  ('InternetIsBeautiful', 86),
#  ('pcmasterrace', 86),
#  ('Trumpvirus', 85),
#  ('BrandNewSentence', 85),
#  ('IrrationalMadness', 85),
#  ('HeckThisIsWholesome', 85),
#  ('TechNewsToday', 84),
#  ('InternationalLeft', 84),
#  ('confusing_perspective', 84),
#  ('Jregosphere', 84),
#  ('hmmm', 83),
#  ('Traitors_and_Patriots', 83),
#  ('socialism', 81),
#  ('canada', 81),
#  ('freecryptokens', 81),
#  ('YouShouldKnow', 80),
#  ('Minecraft', 80),
#  ('antiwork', 79),
#  ('climatesolutions', 78),
#  ('redditoryt', 78),
#  ('lostgeneration', 77),
#  ('Bossfight', 77),
#  ('China', 77),
#  ('unitedkingdom', 77),
#  ('DemocraticSocialism', 76),
#  ('actualliberalgunowner', 76),
#  ('AmazonDSPDrivers', 76),
#  ('WhatsWrongWithYourCat', 76),
#  ('economy', 75),
#  ('TheDepthsBelow', 75),
#  ('repost', 75),
#  ('savemonke', 75),
#  ('worldpolitics', 74),
#  ('CrazyFuckingVideos', 74),
#  ('FavoriteMedia', 74),
#  ('Catswithjobs', 73),
#  ('BlackLivesMatter', 72),
#  ('ShittyLifeProTips', 72),
#  ('anime_titties', 71),
#  ('OldSchoolCool', 71),
#  ('climate', 70),
#  ('Fuckthealtright', 70),
#  ('technews', 70),
#  ('dontbestupid', 70),
#  ('television', 70),
#  ('neoliberal', 69),
#  ('business', 69),
#  ('InsaneParler', 69),
#  ('StoppedWorking', 69),
#  ('atheism', 68),
#  ('JoeBiden', 68),
#  ('bestoftheinternet', 68),
#  ('suspiciouslyspecific', 68),
#  ('FluentInFinance', 68),
#  ('CapitolConsequences', 67),
#  ('Wallstreetbetsnew', 67),
#  ('AOC', 67),
#  ('Communalists', 66),
#  ('AR10', 66),
#  ('okbuddyretard', 66),
#  ('bestof', 66),
#  ('vegan', 65),
#  ('whatcouldgoright', 65),
#  ('2meirl4meirl', 65),
#  ('InformedTankie', 65),
#  ('BadChoicesGoodStories', 64),
#  ('de', 64),
#  ('BONKpatrol', 63),
#  ('Animators', 63),
#  ('MurderedByAOC', 62),
#  ('india', 62),
#  ('libertarian_music', 62),
#  ('WorkplaceOrganizing', 61),
#  ('ukpolitics', 61),
#  ('HongKong', 60),
#  ('myanmar', 60),
#  ('EngineeringPorn', 60),
#  ('Catswhoyell', 60),
#  ('WitchesVsPatriarchy', 60),
#  ('CryptoCurrency', 59),
#  ('GetMotivated', 59),
#  ('conservatives', 58),
#  ('chomsky', 58),
#  ('internationalpolitics', 58),
#  ('DebateVaccines', 58),
#  ('thisismylifenow', 58),
#  ('petbacking', 58),
#  ('ClimateActionPlan', 57),
#  ('geopolitics', 57),
#  ('holdmyredbull', 57),
#  ('gifsthatendtoosoon', 57),
#  ('NonPoliticalTwitter', 57),
#  ('AreTheStraightsOK', 57),
#  ('bizarrelife', 57),
#  ('CoreMu', 57),
#  ('SustainabilityPlus', 57),
#  ('MAGAs', 56),
#  ('yesyesyesno', 56),
#  ('EZLN', 56),
#  ('tech', 55),
#  ('holdmyjuicebox', 55),
#  ('trippinthroughtime', 55),
#  ('EcoNewsNetwork', 54),
#  ('Anarcho_Capitalism', 54),
#  ('VaushV', 54),
#  ('GoldandBlack', 54),
#  ('books', 54),
#  ('solar', 54),
#  ('mechanical_gifs', 54),
#  ('whitepeoplegifs', 54),
#  ('AbandonedPorn', 54),
#  ('SocialistRA', 53),
#  ('AmericanPolitics', 53),
#  ('progun', 53),
#  ('OurPresident', 53),
#  ('MeansTV', 53),
#  ('goodnews', 52),
#  ('uninsurable', 52),
#  ('shittyfoodporn', 52),
#  ('interestingnewsworld', 52),
#  ('TrueReddit', 52),
#  ('PermacultureBushcraft', 52),
#  ('Ohio', 51),
#  ('meme', 51),
#  ('memeswithoutmods', 51),
#  ('TechNewsTomorrow', 50),
#  ('infuriatingasfuck', 49),
#  ('ToiletPaperUSA', 49),
#  ('SelfAwarewolves', 49),
#  ('creepy', 49),
#  ('GamerSupremeRace', 49),
#  ('Chonkers', 49),
#  ('ConvenientCop', 49),
#  ('Seattle', 48),
#  ('bisexual', 48),
#  ('VeganActivism', 48),
#  ('ThatLookedExpensive', 48),
#  ('newyorkcity', 47),
#  ('occupywallstreet', 47),
#  ('gunpolitics', 47),
#  ('HumansAreMetal', 47),
#  ('Catculations', 47),
#  ('skeptic', 47),
#  ('madlads', 47),
#  ('youtubehomesteaders', 47),
#  ('BopUnderground', 47),
#  ('HydroHomies', 46),
#  ('LateStageImperialism', 46),
#  ('islam', 46),
#  ('ALLTHEANIMALS', 46),
#  ('badassanimals', 46),
#  ('Thatsactuallyverycool', 46),
#  ('EmKay', 46),
#  ('InterestingVideoClips', 46),
#  ('GenZommunist', 46),
#  ('watchpeoplesurvive', 46),
#  ('starterpacks', 46),
#  ('CoronavirusSupport', 46),
#  ('AnarchoMovies', 46),
#  ('animalsincars', 46),
#  ('gadgets', 46),
#  ('DiscoverEarth', 45),
#  ('NotoQanon', 45),
#  ('DankLeft', 45),
#  ('TheUnitedUmmah', 45),
#  ('FridayNightFunkin', 45),
#  ('Animal_Sanctuary', 45),
#  ('philosophy', 45),
#  ('Green_News', 44),
#  ('sustainability', 44),
#  ('ClimateOffensive', 44),
#  ('VoteDEM', 44),
#  ('AquaticAsFuck', 44),
#  ('hitmanimals', 44),
#  ('DidntKnowIWantedThat', 44),
#  ('NewProductPorn', 44),
#  ('gay', 43),
#  ('FloridaPolitics', 43),
#  ('PoliticalCompassMemes', 43),
#  ('HardcoreNature', 43),
#  ('watchthingsfly', 43),
#  ('CatsAreAssholes', 43),
#  ('HUEstation', 43),
#  ('Crazyppl', 43),
#  ('rastaknowledge', 43),
#  ('blessedimages', 43),
#  ('GardenGrowth', 43),
#  ('sadcringe', 43),
#  ('Green', 42),
#  ('ParlerWatch', 42),
#  ('QanonKaren', 42),
#  ('China_Debate', 42),
#  ('wholesomegifs', 42),
#  ('blackpeoplegifs', 42),
#  ('ItHadToBeBrazil', 42),
#  ('TwoXChromosomes', 42),
#  ('Chadposting', 42),
#  ('WholesomeAsHeck', 42),
#  ('Blessed_Images', 42),
#  ('BernieSanders', 42),
#  ('Bitcoin', 42),
#  ('Portland', 42),
#  ('soccer', 42),
#  ('spaceporn', 42),
#  ('IndiaSpeaks', 41),
#  ('ACAB', 41),
#  ('labor', 41),
#  ('dontputyourdickinthat', 41),
#  ('Fireworksgonewrong', 41),
#  ('SoulSnacks', 41),
#  ('USEmpire', 41),
#  ('Limenade', 41),
#  ('CrimethInc', 41),
#  ('lifehacks', 41),
#  ('GachaClubCringe', 41),
#  ('RuinedMyDay', 41),
#  ('pussypassdenied', 41),
#  ('Music', 40),
#  ('CANNABISfuturus', 40),
#  ('FUCKYOUINPARTICULAR', 40),
#  ('voteforbernie', 40),
#  ('PewdiepieSubmissions', 40),
#  ('ArtefactPorn', 40),
#  ('TheNarcoblog701', 40),
#  ('UNBGBBIIVCHIDCTIICBG', 40),
#  ('Simulated', 40),
#  ('DesignPorn', 40),
#  ('ReviewsOffers', 40),
#  ('AnarchismZ', 39),
#  ('nycpolitics', 39),
#  ('LeftWithoutEdge', 39),
#  ('NoahGetTheDeathStar', 39),
#  ('confidentlyincorrect', 39),
#  ('redneckengineering', 39),
#  ('CrackheadCraigslist', 39),
#  ('union', 38),
#  ('thalassophobia', 38),
#  ('Permaculture', 38),
#  ('Africa', 38),
#  ('AnarchistRC', 38),
#  ('GamePhysics', 38),
#  ('InternationalDev', 38),
#  ('perfectloops', 38),
#  ('nononono', 38),
#  ('dontflinch', 38),
#  ('canadaguns', 38),
#  ('u_rmb_hot', 38),
#  ('PhysicalGeography', 37),
#  ('uspolitics', 37),
#  ('ireland', 37),
#  ('Virginia', 37),
#  ('ChunghwaMinkuo', 37),
#  ('forbiddensnacks', 37),
#  ('likeus', 37),
#  ('assholedesign', 37),
#  ('agedlikemilk', 37),
#  ('ChildrenFallingOver', 37),
#  ('wisconsin', 36),
#  ('TheMajorityReport', 36),
#  ('AntiFANG', 36),
#  ('fragilecommunism', 36),
#  ('programming', 36),
#  ('AnimalsBeingStrange', 36),
#  ('NoRules', 36),
#  ('iamverybadass', 36),
#  ('KrazyRabb1t', 36),
#  ('MEOW_IRL', 36),
#  ('cringepics', 36),
#  ('ConservativeMemes', 36),
#  ('WatchandLearn', 36),
#  ('2spooky4me', 36),
#  ('entirebodyexercises', 36),
#  ('world', 35),
#  ('RenewableEnergy', 35),
#  ('AntifascistsofReddit', 35),
#  ('Cyberpunk', 35),
#  ('inthenews', 35),
#  ('EuropeanSocialists', 35),
#  ('NewColdWar', 35),
#  ('BasicIncome', 35),
#  ('SuddenlyGay', 35),
#  ('DataHoarder', 35),
#  ('VACCINES', 35),
#  ('InconvenientFacts', 35),
#  ('fakehistoryporn', 35),
#  ('PublicFreakoutX', 35),
#  ('Dogberg', 35),
#  ('Politsturm', 35),
#  ('asian', 35),
#  ('surrealmemes', 35),
#  ('IndianCountry', 34),
#  ('StallmanWasRight', 34),
#  ('communism', 34),
#  ('ProtectOurForests', 34),
#  ('stopworking', 34),
#  ('weedstocks', 34),
#  ('electricvehicles', 34),
#  ('holdmyfries', 34),
#  ('britposting', 34),
#  ('housingforall', 34),
#  ('BJG', 34),
#  ('rareinsults', 34),
#  ('illegallysmolbirbs', 34),
#  ('Foodforthought', 34),
#  ('GreenFarming', 34),
#  ('The_Mueller', 33),
#  ('Military', 33),
#  ('SimDemocracy', 33),
#  ('Howie2020', 33),
#  ('singularity', 33),
#  ('animalsdoingstuff', 33),
#  ('illegallysmolanimals', 33),
#  ('KidsAreFuckingEvil', 33),
#  ('EnoughIDWspam', 33),
#  ('BAMEVoicesUK', 33),
#  ('asshole', 33),
#  ('Liberate_Canada', 33),
#  ('unpopularopinion', 33),
#  ('trees', 32),
#  ('Republica_Argentina', 32),
#  ('FoodPorn', 32),
#  ('AfricanCities', 32),
#  ('Justrolledintotheshop', 32),
#  ('SurvivalGrid', 32),
#  ('seemeCSC', 32),
#  ('Fuck_This_Guy', 31),
#  ('HumanForScale', 31),
#  ('DelusionsOfAdequacy', 31),
#  ('Memes_Of_The_Dank', 31),
#  ('democrats', 31),
#  ('HeavyFuckingWind', 31),
#  ('OliverMarkusMalloy', 31),
#  ('TheRightCantMeme', 31),
#  ('nomansland', 31),
#  ('StimulationAddiction', 31),
#  ('AnythingGoesNews', 30),
#  ('climatejustice', 30),
#  ('esist', 30),
#  ('TenantUnion', 30),
#  ('philadelphia', 30),
#  ('Firearms', 30),
#  ('onguardforthee', 30),
#  ('megalophobia', 30),
#  ('MyPeopleNeedMe', 30),
#  ('CloneWarsMemes', 30),
#  ('ShamelesslyStolen', 30),
#  ('urbanplanning', 30),
#  ('dogecoin', 30),
#  ('cursedvideos', 30),
#  ('Denver', 30),
#  ('CatGifs', 30),
#  ('food', 30),
#  ('cryptoleftists', 30),
#  ('dndmemes', 30),
#  ('u_cloyego', 30),
#  ('itookapicture', 30),
#  ('fuckpeta', 30),
#  ('YangForPresidentHQ', 29),
#  ('religiousfruitcake', 29),
#  ('Policestudies', 29),
#  ('Awww', 29),
#  ('nope', 29),
#  ('TouchThaFishy', 29),
#  ('OkBuddyPoliceOfficer', 29),
#  ('PraxisGuides', 29),
#  ('PraxisTube', 29),
#  ('Cursed_Images', 29),
#  ('libertarianmeme', 29),
#  ('tf2shitposterclub', 29),
#  ('traaaaaaannnnnnnnnns', 29),
#  ('UnpopularFacts', 29),
#  ('aviation', 29),
#  ('Themepark', 29),
#  ('progressive', 29),
#  ('AnarchismBookClub', 29),
#  ('moderatepolitics', 29),
#  ('inslee2020', 29),
#  ('sciences', 29),
#  ('u_mtimetraveller', 29),
#  ('Kossacks_for_Sanders', 28),
#  ('brasil', 28),
#  ('Qult_Headquarters', 28),
#  ('EndlessWar', 28),
#  ('CCP_virus', 28),
#  ('cybersecurity', 28),
#  ('DunderMifflin', 28),
#  ('ShaunAndJen', 28),
#  ('dogswithjobs', 28),
#  ('socialistalternative', 28),
#  ('youtubehaiku', 28),
#  ('Renewable', 27),
#  ('COVID19RippleEffects', 27),
#  ('thedavidpakmanshow', 27),
#  ('AntiTrumpAlliance', 27),
#  ('librandu', 27),
#  ('AsianSocialists', 27),
#  ('Covid19Assholes', 27),
#  ('landconservation', 27),
#  ('mirroring', 27),
#  ('rojava', 27),
#  ('linux', 27),
#  ('pennystocks', 27),
#  ('AntiMSM', 27),
#  ('StupidFood', 27),
#  ('Sino', 27),
#  ('PartyParrot', 27),
#  ('u_RiseUp4Rojava_', 27),
#  ('TheOutlawsAssociation', 27),
#  ('CatLovesThat', 27),
#  ('bonehurtingjuice', 27),
#  ('sports', 27),
#  ('whatisthisthing', 27),
#  ('Ego_Death_Club', 27),
#  ('ontario', 27),
#  ('ZeroWaste', 26),
#  ('furry_irl', 26),
#  ('WatchRedditDie', 26),
#  ('daverubin', 26),
#  ('AntiVaxxers', 26),
#  ('lotrmemes', 26),
#  ('shittyrobots', 26),
#  ('Webadas', 26),
#  ('MostBeautiful', 26),
#  ('FellowKids', 26),
#  ('criticalblunder', 26),
#  ('entertainment', 26),
#  ('HistoryPorn', 26),
#  ('UnexplainedPhenomena7', 26),
#  ('HighQualityGifs', 26),
#  ('GamingNewsSpot', 26),
#  ('taiwan', 25),
#  ('LocalismEngland', 25),
#  ('IWW', 25),
#  ('SpaceXLounge', 25),
#  ('cvnews', 25),
#  ('propublica', 25),
#  ('DaniDev', 25),
#  ('clevercomebacks', 25),
#  ('bestarticles', 25),
#  ('opensource', 25),
#  ('aPeoplesCalendar', 25),
#  ('VeganLibs', 25),
#  ('rccars', 25),
#  ('goodanimemes', 25),
#  ('WallstreetBreakers', 25),
#  ('LosAngeles', 25),
#  ('toolsinaction', 25),
#  ('greentext', 25),
#  ('LivestreamFail', 25),
#  ('TanmoyKayesen', 25),
#  ('Impeach_Trump', 25),
#  ('anal', 25),
#  ('USNews2', 24),
#  ('WholeWorker', 24),
#  ('AntiComAction', 24),
#  ('LSD', 24),
#  ('ncpolitics', 24),
#  ('StarWars', 24),
#  ('GrouchySocialists', 24),
#  ('selfreliance', 24),
#  ('ManufacturingPorn', 24),
#  ('nukedmemes', 24),
#  ('nba', 24),
#  ('IslamicHistoryMeme', 24),
#  ('OutOfTheLoop', 24),
#  ('NotMyJob', 24),
#  ('AustralianCulture', 24),
#  ('Airports', 24),
#  ('AnimalYawnKingdom', 24),
#  ('baseball', 24),
#  ('ProtectAndServe', 23),
#  ('Palestine', 23),
#  ('COVIDGoodNews', 23),
#  ('DescentIntoTyranny', 23),
#  ('anarchocommunism', 23),
#  ('exmuslim', 23),
#  ('electionreform', 23),
#  ('PoliticalVideo', 23),
#  ('donthelpjustfilm', 23),
#  ('JustGuysBeingDudes', 23),
#  ('leftistposters', 23),
#  ('combinedgifs', 23),
#  ('ich_iel', 23),
#  ('ChoosingBeggars', 23),
#  ('Shitty_Car_Mods', 23),
#  ('PinkWug', 23),
#  ('Rakingthemuck', 23),
#  ('LockdownSkepticism', 23),
#  ('HydrogenSocieties', 23),
#  ('straightturnedgay', 23),
#  ('Isitaccuratetho', 23),
#  ('nyc', 22),
#  ('BAME_UK', 22),
#  ('demsocialists', 22),
#  ('LandlordLove', 22),
#  ('megafaunarewilding', 22),
#  ('softwaregore', 22),
#  ('JordanPeterson', 22),
#  ('LatinAmerica', 22),
#  ('GQP', 22),
#  ('Pikabu', 22),
#  ('IllegallySmol', 22),
#  ('Austin', 22),
#  ('InsaneProtestors', 22),
#  ('peopleofwalmart', 22),
#  ('theyknew', 22),
#  ('ClassPoliticsTwitter', 22),
#  ('houseplants', 22),
#  ('HornyPolice', 22),
#  ('worldeconomy', 22),
#  ('PetsareAmazing', 22),
#  ('vicio', 22),
#  ('ProtestCringe', 22),
#  ('chemistrymemes', 22),
#  ('pessimismmemes', 22),
#  ('LakeErie', 22),
#  ('RoadTrafficAccidents', 22),
#  ('ethereum', 22),
#  ('happycowgifs', 22),
#  ('ScientificNutrition', 22),
#  ('NewsOfTheWeird', 22),
#  ('TopMindsOfReddit', 22),
#  ('AskDocs', 22),
#  ('AskHistorians', 22),
#  ('archtec', 22),
#  ('SyndiesUnited', 21),
#  ('ShitLiberalsSay', 21),
#  ('offbeat', 21),
#  ('2020Election', 21),
#  ('arabs', 21),
#  ('CoronaVirus_2019_nCoV', 21),
#  ('xrmed', 21),
#  ('HighStrangeness', 21),
#  ('UberDeutschland', 21),
#  ('localism', 21),
#  ('ReallyAmerican', 21),
#  ('GeorgiaUS', 21),
#  ('ItsNotJustInYourHead', 21),
#  ('PeoplesFront', 21),
#  ('killedthecameraman', 21),
#  ('meirl', 21),
#  ('christiananarchism', 21),
#  ('Labour', 21),
#  ('Omaha', 21),
#  ('TheBeliefInstinct', 21),
#  ('longevity', 21),
#  ('Internet', 21),
#  ('ofcoursethatsathing', 21),
#  ('howto', 21),
#  ('CuratedTumblr', 21),
#  ('HTDYB', 21),
#  ('MilitaryPorn', 21),
#  ('TrendyJunkie', 21),
#  ('BeDazzled', 21),
#  ('ClassicRock', 21),
#  ('Bloomberg_Plutocrat', 21),
#  ('Sustainable', 20),
#  ('Environmental_Policy', 20),
#  ('demsocialist', 20),
#  ('maryland', 20),
#  ('jimmydore', 20),
#  ('Feminism', 20),
#  ('MiddleEastNews', 20),
#  ('tucker_carlson', 20),
#  ('sanepolitics', 20),
#  ('Intelligence', 20),
#  ('blender', 20),
#  ('JoeRogan', 20),
#  ('Miniworlds', 20),
#  ('RealLifeShinies', 20),
#  ('AnarchoGaming', 20),
#  ('StreetMartialArts', 20),
#  ('gtaonline', 20),
#  ('WhyWomenLiveLonger', 20),
#  ('CrazyHuman', 20),
#  ('PoliticsPeopleTwitter', 20),
#  ('VoteBlue', 20),
#  ('CatsStandingUp', 20),
#  ('Sentientism', 20),
#  ('spacecolonization', 20),
#  ('cat', 20),
#  ('Thisismylifemeow', 20),
#  ('ElectricCarsNews', 20),
#  ('VeganInfographics', 20),
#  ('RealMerryPranksters', 20),
#  ('MildlyStartledCats', 20),
#  ('DidThisLastNight', 20),
#  ('okbuddyimperialist', 20),
#  ('ProgrammerHumor', 20),
#  ('formula1', 20),
#  ('SomeoneCall911', 20),
#  ('MarsSociety', 20),
#  ('peoplesliberation', 20),
#  ('marvelstudios', 20),
#  ('FreeKurdistan', 20),
#  ('52BooksForCommunists', 20),
#  ('SocialJusticeInAction', 20),
#  ('powerwashingporn', 20),
#  ('MMA', 20),
#  ('Maps', 20),
#  ('FunnyAdvertising', 20),
#  ('north_america', 19),
#  ('StandAgainstTyranny', 19),
#  ('RepublicanValues', 19),
#  ('TrueAnon', 19),
#  ('NEWPOLITIC', 19),
#  ('Iamactuallyverybadass', 19),
#  ('CoronavirusCirclejerk', 19),
#  ('samharris', 19),
#  ('AntiAmazon', 19),
#  ('france', 19),
#  ('cannabis', 19),
#  ('EarthStrike', 19),
#  ('playboicarti', 19),
#  ('OneTermPresident', 19),
#  ('Cyberdelinaut', 19),
#  ('justneckbeardthings', 19),
#  ('FuckTheCIA', 19),
#  ('Tiresaretheenemy', 19),
#  ('COVID19', 19),
#  ('ArchitecturePorn', 19),
#  ('SocialistPartyUSA', 19),
#  ('Traabutyescommunism', 19),
#  ('IceFishing', 19),
#  ('AskWomenOfColorOver30', 19),
#  ('vexillology', 19),
#  ('Product_Hub', 19),
#  ('mapgore', 19),
#  ('ShitPostCrusaders', 19),
#  ('media_criticism', 19),
#  ('UKForeignPolicy', 19),
#  ('aliens', 19),
#  ('UnresolvedMysteries', 19),
#  ('USSpaceForce', 19),
#  ('TheTrueGospelOfJesus', 19),
#  ('cars', 19),
#  ('AmItheAsshole', 19),
#  ('Achterbahnen', 19),
#  ('SoGoodtoBeBad', 19),
#  ('CamSluts', 19),
#  ('indepthstories', 18),
#  ('GreatLakes', 18),
#  ('wheresthebeef', 18),
#  ('Cities', 18),
#  ('UnfuckTheWorld', 18),
#  ('N_N_N', 18),
#  ('ConspiracyPastPresent', 18),
#  ('Iowa', 18),
#  ('StrikeAction', 18),
#  ('worldpolitics2', 18),
#  ('conservation', 18),
#  ('funnyvideos', 18),
#  ('ItemShop', 18),
#  ('satisfying', 18),
#  ('bigboye', 18),
#  ('FreeKarma4U', 18),
#  ('CatTaps', 18),
#  ('ufc', 18),
#  ('ENLIGHTENEDCENTRISM', 18),
#  ('DeskToDefender', 18),
#  ('VoluntaristMemes', 18),
#  ('GroceryStores', 18),
#  ('misc', 18),
#  ('Sims4', 18),
#  ('socialistprogrammers', 18),
#  ('antiwar', 18),
#  ('YoungEcoSocialists', 18),
#  ('Charmx', 18),
#  ('dashcams', 18),
#  ('youngpeopleyoutube', 18),
#  ('SelfCareCharts', 18),
#  ('YuB', 18),
#  ('HotDemocracyWatch', 18),
#  ('DamnThatsGottaHurt', 18),
#  ('WorldAroundEwe', 18),
#  ('anarchomusic', 18),
#  ('Kashmiri', 18),
#  ('cringe', 18),
#  ('explainlikeimfive', 18),
#  ('mcckla', 18),
#  ('Showerthoughts', 18),
#  ('AbolishHumanRentals', 18),
#  ('Mainepolitics', 18),
#  ('AlanMoore', 18),
#  ('u_Viv_iannart', 18),
#  ('marinebiology', 17),
#  ('FuckNestle', 17),
#  ('bayarea', 17),
#  ('FreeTheUyghurs', 17),
#  ('CovIdiots', 17),
#  ('seculartalk', 17),
#  ('EnoughTrumpSpam', 17),
#  ('EuropeanNews', 17),
#  ('LouderWithCrowder', 17),
#  ('voterfraud', 17),
#  ('CommunismWorldwide', 17),
#  ('EnoughCommieSpam', 17),
#  ('wowfuckthewhat', 17),
#  ('RinoDinoPorcupino', 17),
#  ('vote', 17),
#  ('2020Reclamation', 17),
#  ('Tierzoo', 17),
#  ('420', 17),
#  ('Makesmybloodboil', 17),
#  ('CombatFootage', 17),
#  ('DnD', 17),
#  ('GuardiansOfLiberty', 17),
#  ('CoronaVirusWorldNews', 17),
#  ('infrastructure', 17),
#  ('engrish', 17),
#  ('lego', 17),
#  ('meatcrayon', 17),
#  ('C_AT', 17),
#  ('PropagandaPosters', 17),
#  ('Animemes', 17),
#  ('CrazyDoorbellFootage', 17),
#  ('WeWantPlates', 17),
#  ('LDQ', 17),
#  ('PeopleBeingJerks', 17),
#  ('PhillyWiki', 17),
#  ('Defund_NPR_and_PBS', 17),
#  ('prisons', 17),
#  ('AdviceAnimals', 17),
#  ('1000pandas', 17),
#  ('lesbians', 17),
#  ('5axisCNC', 17),
#  ('nature', 16),
#  ('bicycling', 16),
#  ('Louisville', 16),
#  ('democracy', 16),
#  ('ViralTexas', 16),
#  ('yourmomshousepodcast', 16),
#  ('antinatalism', 16),
#  ('CoronavirusCA', 16),
#  ('AbolishTheMonarchy', 16),
#  ('republicans', 16),
#  ('OntarioCanada', 16),
#  ('AntiCapitalistRants', 16),
#  ('chile', 16),
#  ('popping', 16),
#  ('oddlyweird', 16),
#  ('elephantgifs', 16),
#  ('good_cop_bad_cop', 16),
#  ('FullShrimp', 16),
#  ('starwarsmemes', 16),
#  ('NexusAurora', 16),
#  ('InvestmentClub', 16),
#  ('leftpodcasts', 16),
#  ('trashpandas', 16),
#  ('IRLEasterEggs', 16),
#  ('learningtocat', 16),
#  ('amcstock', 16),
#  ('YOUGETTOBEAMOD', 16),
#  ('loadingicon', 16),
#  ('woodworking', 16),
#  ('AnarchoComics', 16),
#  ('TheEret', 16),
#  ('u_NationofChange', 16),
#  ('ScienceUncensored', 16),
#  ('apple', 16),
#  ('CreativeSociety', 16),
#  ('botecodoreddit', 16),
#  ('CryptoMoonShots', 16),
#  ('demurragecryptoincome', 16),
#  ('TinyYTubers', 16),
#  ('Outdoors', 15),
#  ('SunriseMovement', 15),
#  ('Environmentalism', 15),
#  ('RuralNewsNetwork', 15),
#  ('aznidentity', 15),
#  ('weed', 15),
#  ('EnoughLibertarianSpam', 15),
#  ('PacificNorthwest', 15),
#  ('fucktheccp', 15),
#  ('texas', 15),
#  ('GenZedong', 15),
#  ('StockLaunchers', 15),
#  ('TransSpace', 15),
#  ('Satisfyingasfuck', 15),
#  ('LiminalSpace', 15),
#  ('NorthCarolina', 15),
#  ('peopledyinginside', 15),
#  ('Construction', 15),
#  ('HoldMyKibble', 15),
#  ('law', 15),
#  ('TheCatTrapIsWorking', 15),
#  ('stocks', 15),
#  ('finance', 15),
#  ('gatekeeping', 15),
#  ('Stepdadreflexes', 15),
#  ('BurningAsFuck', 15),
#  ('Petsnurturing', 15),
#  ('GunMemes', 15),
#  ('Shortsqueeze', 15),
#  ('ADailyDoseOfInternet', 15),
#  ('FunnyAnimals', 15),
#  ('sbubby', 15),
#  ('japan', 15),
#  ('thebakery', 15),
#  ('GypsyRoad', 15),
#  ('ChinaMemes', 15),
#  ('DeepIntoYouTube', 15),
#  ('CoronavirusSouth', 15),
#  ('PBS_NewsHour', 15),
#  ('BuildingTrades', 15),
#  ('FragileWhiteRedditor', 15),
#  ('insaneparents', 15),
#  ('OSHA', 15),
#  ...]

# %%
#average in degree
sum(dict(G.in_degree()).values())/float(len(G))
# Out:
# 4.31500060437568

# %%
#average out degree
sum(dict(G.out_degree()).values())/float(len(G))
# Out:
# 4.31500060437568

# %%
sum(dict(G.degree()).values())/float(len(G))
# Out:
# 8.63000120875136

# %%
def plot_dist(G):
    M = nx.to_scipy_sparse_matrix(G)
    xmin = min([d[1] for d in G.degree()])
    indegrees = M.sum(0).A[0]
    degree = np.bincount(indegrees)
    fit = powerlaw.Fit(np.array(degree)+1, fit_method='KS')#, xmin=xmin, xmax=max(degree)-xmin,discrete=True)
    
    
    fig = plt.figure(figsize=(16, 6)) 
    """ Plot Distribution """
    plt.subplot(1, 3, 1)
    plt.plot(range(len(degree)),degree,'b.')   
    plt.loglog()
    plt.xlim((min(degree), max(degree)))
    plt.xlabel('Degree')
    plt.ylabel('P(k)')


    """ Plot CDF """
    plt.subplot(1, 3, 2)
    fit.plot_cdf()
    plt.xlabel("Degree")
    plt.ylabel('CDF')

    """ Plot CCDF """
    plt.subplot(1, 3, 3)
    fit.plot_ccdf()
    plt.ylabel('CCDF')
    plt.xlabel('Degree')
    plt.tight_layout()
    plt.show()

# %%
plot_dist(G)
# Out:
# Calculating best minimal value for power law fit

# %%
ego = nx.ego_graph(G, 'politics')
nx.draw(ego, with_labels=False)

# %%
nx.density(G)
# Out:
# 0.00017386576695848496

# %%
list(G.neighbors('politics'))
# Out:
# ['environment',
#  'RuralNewsNetwork',
#  'EcoNewsNetwork',
#  'TheFightThatMatters',
#  'WomenForTrump',
#  'leftist',
#  'ConcentrationOfWealth',
#  'CITILOP',
#  'These_Fucking_People',
#  'Winnipeg',
#  'demsocialist',
#  'conspiracyfact',
#  'Mercerinfo',
#  'KochWatch',
#  'revolution',
#  'ConspiracyPastPresent',
#  'ANormalDayInAmerica',
#  'Feminism',
#  'WomensRightsNews',
#  'uspolitics',
#  'voterfraud',
#  'WhiteHouseHyperReal',
#  'Astuff',
#  'LeftWithoutEdge',
#  'TexasPolitics',
#  'latinos',
#  'IvankaTrump',
#  'BurismaNews',
#  'florida',
#  'NewPatriotism',
#  'leftistveterans',
#  'EmergingRisks',
#  'antiwork',
#  'AnythingGoesNews',
#  'resistentem_tyrannide',
#  'Fuck45',
#  'Corruption',
#  'DemocraticDiscussions',
#  'DemocraticSocialism',
#  'actualliberalgunowner',
#  'BigTent',
#  'labor',
#  'ClimateDenialism',
#  'politicly',
#  'energy',
#  'electricvehicles',
#  'BigAgro',
#  'farming',
#  'PoliceAccountability1',
#  'Bad_Cop_No_Donut',
#  'VaushV',
#  'audihertz',
#  'ACAB',
#  'BlackLivesMatter',
#  'DefundPolice',
#  'MAGAs',
#  'ObsurdPolitics',
#  'conspiracy',
#  'Trumpet_of_Discord',
#  'VoterProtection',
#  'TrumpCivilWar',
#  'Cult_Right',
#  'LeftvsRightDebate',
#  'sdrawkcabtidder',
#  'OneTermPresident',
#  'KentuckyPolitics',
#  'TrumpHeadlines',
#  'orlando',
#  'WHHR7',
#  'RepublicanValues',
#  'PizzaGaetz',
#  'fuckyoufascists',
#  'MeidasTouch',
#  'WHHR4',
#  'LiberalMeltdown',
#  'HillaryMeltdown',
#  '45th_President',
#  'The_Mueller',
#  'republicans',
#  'AmericanPolitics',
#  'vzla',
#  'usa',
#  'atheism',
#  'ABCDesis',
#  'yoga',
#  'aznidentity',
#  'atheismindia',
#  'Vastlystupid',
#  'religiousfruitcake',
#  'exchristian',
#  'Republican',
#  'AntiHateCommunities',
#  'WHHR_PostTrump',
#  'RacismAgainstAsians',
#  'usanews',
#  'HumanTrafficking',
#  'LouderWithCrowder',
#  'watergaetz',
#  'Republikkkans',
#  'Ohio',
#  'mattgaetz',
#  'FuckJimJordan',
#  'Albuquerque',
#  'internettoday',
#  'PoliticsInsider',
#  'Qult_Headquarters',
#  'NoNewNormal',
#  'TimPool',
#  'VaccinesMeds',
#  'DoomsdayNow',
#  'FOXNEWS',
#  'LeopardsAteMyFace',
#  'FoxFiction',
#  'PuertoRico',
#  'shittyaskscience',
#  'TimDillon',
#  'ExposingRussia',
#  'PeopleBeingAssholes',
#  'fuckmarjorietaylor',
#  'FawningLiberalMedia',
#  'MarchAgainstNazis',
#  'LockUpTrump',
#  'washingtondc',
#  'SocialistRA',
#  'ThereIsNoBottom',
#  'EnoughTrumpSpam',
#  'Digital_Manipulation',
#  'nouseforatitle',
#  'coronabr',
#  'brasilivre',
#  'brasil',
#  'BadGOP_NoDoughnuts',
#  'ArcanaPost',
#  'Healthcare_costs',
#  'InsanityWPC',
#  'fucktrump',
#  'WHHR6',
#  '2ndcivilwar',
#  'Technocracy',
#  'premed',
#  'GoodRisingTweets',
#  'CallToActionWisconsin',
#  '2020PoliceBrutality',
#  'OpenArgs',
#  'UpliftingNews',
#  'SexWorkers',
#  'Classical_Liberals',
#  'Anarcho_Capitalism',
#  'LeftWingNonFeminist',
#  'AskLawyers',
#  'socialists',
#  'Socialist',
#  'Kossacks_for_Sanders',
#  'SocialistMAGA',
#  'basicincomejapan',
#  'AntifascistsofReddit',
#  'LincolnProject',
#  'WestVirginia',
#  'LateStageCapitalism',
#  'Libraries',
#  'ContagiousACB',
#  'conspiracytheories',
#  'FuckYouParty',
#  'esist',
#  'kansascity',
#  'MissouriPolitics',
#  'Fuckthealtright',
#  'Hasan_Piker',
#  'gunpolitics',
#  'seculartalk',
#  'TransSpace',
#  'LGBTnews',
#  'conservativeterrorism',
#  'mississippi',
#  'BidenHarris_2020',
#  'grandjunction',
#  'JimJordan',
#  'RetardsTalkAboutSaudi',
#  'TopConspiracy',
#  'PostScarcityNow',
#  'honeybadgerparty',
#  'Political_Revolution',
#  'SocialDemocracy',
#  'McDonaldsEmployees',
#  'RaiseTheWage',
#  'GreenParty',
#  'AmericasCollapse',
#  'Investorshub',
#  'AmericanPoverty',
#  'SandersForPresident',
#  'KyleTaylor',
#  'CryptoCurrency',
#  'BasicIncome',
#  'digitalmoney',
#  'YangForPresidentHQ',
#  'WayOfTheBern',
#  'GME',
#  'fairtax',
#  'HumanResponse',
#  'johngrillo',
#  'WeNeedAThirdParty',
#  'thisveryday',
#  'BigTech',
#  'yourlearningcurve',
#  'CancelWallStreet',
#  'Chester2024',
#  'WallStreetTrader',
#  'WallStreetbetsELITE',
#  'ReplaceCapitalism',
#  'SocialismAndVeganism',
#  'Derfla_bookmarks',
#  'ABoringDystopia',
#  'collapze',
#  'NoShitSherlock',
#  'alltheleft',
#  'Ytqaz2019',
#  'EnoughLibertarianSpam',
#  'fuckcars',
#  'deepfatfried',
#  'boringdystopia',
#  'TrackSCOTUS',
#  'cuntspiracytheories',
#  'thedavidpakmanshow',
#  'mopolitics',
#  'IndianCountry',
#  'propaganda',
#  'Euromaidan2014',
#  'wichita',
#  'worldpolitics',
#  'BlogsAndThinkpieces',
#  'USPS',
#  'TrueCatholicPolitics',
#  'DivineRightOfKings',
#  'GunsAreCool',
#  'ContrarianLeft',
#  'BOLIVIA',
#  'HowGodWorks',
#  'Anarchism',
#  'Arkansas',
#  'SatanGetTheDelorian',
#  'politicsunmodded',
#  'WAlitics',
#  'FuckMitchMcConnell',
#  'True_Kentucky',
#  'TrillbillyPodcast',
#  'BadTurtleNoLettuce',
#  'StaceyAbrams',
#  'Foxhidesinfo',
#  'TheAbditory',
#  'conservative_CJ',
#  'LibtardPropaganda',
#  'thisisntwhoweare',
#  'SlanderousLiberalNews',
#  'rmbrown',
#  'alabamapolitics',
#  'Birmingham',
#  'trees',
#  'TrackDOJ',
#  'AntiTrumpAlliance',
#  'conservatives',
#  'FuckTheProudBoys',
#  'UnelectableAirwaves',
#  'inthemorning',
#  'ftm',
#  'FuckLaurenBoebert',
#  'LaurenBoebert',
#  'capitolcoup',
#  'TuckerTheFucker',
#  'TrackTrumpLawsuits',
#  'TTAMF',
#  'NEWSfun',
#  'ExRepublicans',
#  'RussiaLago',
#  'BlackFridayProtest',
#  'PledgeToImpeach',
#  'behindthebastards',
#  'IWork4DavidBrock',
#  'AngryTaxPayer',
#  'vegas',
#  'Veteranpolitics',
#  'Coronaphobia',
#  'TrumpDepression',
#  'gogopgo',
#  'shitthatdoesntmatter',
#  'cordcutters',
#  'theta_network',
#  'weedstocks',
#  'AnimalsBeingMoms',
#  'ShermanPosting',
#  'IronFrontUSA',
#  'direito',
#  'UncapTheHouse',
#  'WeAreNotAsking',
#  'USCensus2020',
#  'indepthstories',
#  'PreventCivilWar',
#  'DoomsdayBook',
#  'MarshallBrain',
#  'Freethought',
#  'IASIP',
#  'HermanCainAward',
#  'Fuck_This_Guy',
#  'CoronavirusRegret',
#  'climatejustice',
#  'racism',
#  'WarOnEarth',
#  'wisconsin',
#  'FRJ',
#  'greenland',
#  'SenatorRonJohnson',
#  'MontanaPolitics',
#  'RenewableEnergy',
#  'climate',
#  'newsly',
#  'RepublicanTerrorism',
#  'missouri',
#  'AOC',
#  'MedicareForAll',
#  'FreeKarm',
#  'pushbidenleft',
#  'whatthehellarewedoing',
#  'myfavoritemurder',
#  'WealthColdWar',
#  'union',
#  'socialism',
#  'phoenix',
#  'NEWPOLITIC',
#  'ConspiracyII',
#  'ArizonaLeft',
#  'arizonapolitics',
#  'Iowa',
#  'Newiowaproject',
#  'yourmomshousepodcast',
#  'trumpscult',
#  'metacanada',
#  'childrenofdemocracy',
#  'DeepMyth',
#  'Pensacola',
#  'FreePolDiscussion',
#  'RealBlueMidterm',
#  '2020',
#  'greed',
#  'goworldview',
#  'guam',
#  'KlanOfGreenGables',
#  'HotZone',
#  'Pete_Buttigieg',
#  'Ted_Cruz_constituents',
#  'ViralTexas',
#  'CapitolConsequences',
#  'Durango',
#  'ColoradoPolitics',
#  'FuckYouLaurenBoebert',
#  'ClimateMemes',
#  'composting',
#  'theouterworlds',
#  'DeathPositive',
#  'SonsofOrpheus',
#  'DenverCirclejerk',
#  'USNews2',
#  'weed',
#  'Infrastructurist',
#  'ForUnitedStates',
#  'FuckTedCruz',
#  'RepublicanPsychology',
#  'GunOwners4Reform',
#  'InconvenientFacts',
#  'Aoxxt2',
#  'ColdCivilWar',
#  'LockCarbon',
#  'texas',
#  'IThinkYouShouldLeave',
#  'conspriacytheroy',
#  'massachusetts',
#  'neoliberal',
#  'todayspaper',
#  'RuralDemocrats',
#  'TennesseePolitics',
#  'AnarchismOnline',
#  'bread_irl',
#  'Seattle',
#  'SeaWA',
#  'SeattleChat',
#  'TrueAnon',
#  'AlaskaPolitics',
#  'TheCrescent',
#  'NativeAmerican',
#  'FloridaPolitics',
#  'tampa',
#  'CapitolRiots',
#  'LateStageColonialism',
#  'nyc',
#  'NortheastUS',
#  'propublica',
#  'TrueWhiteCrime',
#  'Police_the_Police_ACP',
#  'Amreeka',
#  'asheville',
#  'policebrutality',
#  'BrutalityTracker',
#  'ExposePoliceBrutality',
#  'handmaids_irl',
#  'DarkFuturology',
#  'PublicFreakout',
#  'Brooklyn',
#  'CivilRights',
#  'DarkNow',
#  'Trumpvirus',
#  'theserfstv',
#  'LaceyWA',
#  'doughboys',
#  'TIHI',
#  'spoobylair',
#  'ContinueToServe',
#  'Military',
#  'terrifyingstatistics',
#  'ThatWasWellSaid',
#  'StandAgainstTyranny',
#  'Kamala',
#  'WatchdogJournalism',
#  'KushnerForPrison',
#  'FixTheSenate',
#  'Dailyslant',
#  'CorporateMisconduct',
#  'Policeoversight',
#  'lolomemescom',
#  'chomsky',
#  'thenewcoldwar',
#  'supremecourt',
#  'awfuleverything',
#  'lgbt',
#  'adultsnew',
#  'LibertarianUncensored',
#  'socialjustice',
#  'murderers',
#  'DataPolice',
#  'inthenews',
#  'Positive_News',
#  'WeDemandChange',
#  'COMPLETEANARCHY',
#  'FuckPiggies',
#  'thanksgivingammo',
#  'lostgeneration',
#  'svihs',
#  'FreeSpeech',
#  'tucker_carlson',
#  'DonutOperator',
#  'DescentIntoTyranny',
#  'WhereAreTheChildren',
#  'Anarquismo',
#  'Communalists',
#  'BerniesRevolution',
#  'ProtectingandServing',
#  'killthosewhodisagree',
#  'aclu',
#  'AmericanFascism2020',
#  'USNEWS',
#  'CoronavirusUS',
#  'Weather_Modification',
#  'WikileaksTaskForce',
#  'publix',
#  'JoshHawley',
#  'SouthCarolinaPolitics',
#  'OutcastingMedia',
#  'GAPol',
#  'NotoQanon',
#  'GQP',
#  'holyshit',
#  'FloridaCoronavirus',
#  'wokekids',
#  'conspiracyhub',
#  'Georgia',
#  'BanTheGOP',
#  'newjersey',
#  'LegalEagle',
#  'nottheonion',
#  'TrumpLegalTalk',
#  'PDXProtests',
#  'wisconsinpolitics',
#  'FightFascists',
#  'Sacramento',
#  'ArrestedStormers',
#  'sanepolitics',
#  'ConspiracyUltra',
#  'KnowledgeFight',
#  'Government_is_lame',
#  'Beebola',
#  'Dear_Mr_Atheist',
#  'walkaway',
#  'FixedThatForYa',
#  'GaetzGate',
#  'bluenecks',
#  'best_of_two_x',
#  'KamalToe',
#  'ToxicLeft',
#  'LGBTQ_Community',
#  'AutoMechanics',
#  'CrimesAgainstAsianity',
#  'badlegaladvice',
#  'ThanksSherlock',
#  'Trumpgret',
#  'SENATORMcConnell',
#  'shittydarksouls',
#  'GAPolitics',
#  'SzechuanSauceSeekers',
#  'america',
#  'Thebenjaminbeacon',
#  'TeenPoliticsDiscord',
#  'lukewarmsalmon',
#  'The_Dotard',
#  'imatotalpeiceofshit',
#  'Frombothsides',
#  'courageforfree',
#  'paradoxpolitics',
#  'WHHR8',
#  'HillaryForPrison',
#  'Master0fwar',
#  'ImpeachmentWatch',
#  'postanything',
#  'AnxietyWarHate',
#  'Minneapolis',
#  'Idaho',
#  'ReallyAmerican',
#  'GeorgeLucasTalkShow',
#  'Firearms',
#  'RepublicanHypocrisy',
#  'SelfAwarewolves',
#  'Alabama',
#  'UglyHumanity',
#  'noyoucantwatch',
#  'transalabama',
#  'media_has_resurfaced',
#  'DitchMitch',
#  'desmoines',
#  'GabWatch',
#  'ParlerTrick',
#  'CATVStock',
#  'ParlerWatch',
#  'TheBellmanStillRings',
#  'CannabisInvestors',
#  'ConspiracyPsychology',
#  'democracy',
#  'illinoispolitics',
#  'Trump2020',
#  'Louisville',
#  'lexington',
#  'CornbreadLiberals',
#  'AmazoNope',
#  'unionizeDSP',
#  'fuckyoujeffbezos',
#  'dsa',
#  'Trump_Impeachment',
#  'Copy_and_Paste_Roger',
#  'americandad',
#  'FargoTV',
#  'LawSchool',
#  '13or30',
#  'BoycottChinaRussiaUSA',
#  'offbeat',
#  'Marjorie_Taylor_Green',
#  'China_irl',
#  'Irony',
#  'EssentialEmployees',
#  'noagenda',
#  'WHHR5',
#  'AlexeiNavalny',
#  'Duckworth',
#  'SunriseMovement',
#  'politicsunitedstates',
#  'erasethehate',
#  'NoLockedThreads',
#  'thestateofshit',
#  'protest',
#  'Superstonk',
#  'TheSwampDrain',
#  'unchainedpolitics',
#  'Smino',
#  'jimmydore',
#  'Veep',
#  'soundsaboutright',
#  'internationallaw',
#  'GlobalNews',
#  'MBMBAM',
#  'FuckTuckerCarlson',
#  'TrumpTellsTales',
#  'Republica_Argentina',
#  'Albertapolitics',
#  'ndp',
#  'FoundCaptainObvious',
#  'Capitalism',
#  'walmart',
#  'retailrevolutionaries',
#  'FuckWalmart',
#  'ftmstoners',
#  'cannabisconisuier',
#  'sendinthetanks',
#  'LatinoRA',
#  'DemocratsforDiversity',
#  'women',
#  'gendertroubles',
#  'PeoplesPartyUSA',
#  'Intactivism',
#  'LateStageImperialism',
#  'trueprolife',
#  'TrumpCamps',
#  'anarchogeoism',
#  'THERAPYlite',
#  'NewDealAmerica',
#  'organizedhealing',
#  'fucktheccp',
#  'Apocalympics2022',
#  'mildlyinfuriating',
#  'notesandnews',
#  'newscategory',
#  'JordanPeterson',
#  'FoxBrain',
#  'InsaneParler',
#  'KarenTrump',
#  'aretheNTsokay',
#  'confidentlyincorrect',
#  'refusedMask',
#  'Arkansas_Politics',
#  'TrumpCorruption',
#  'technology',
#  'political',
#  'schadenfreude',
#  'ElPaso',
#  'realtruthpolitics',
#  'WomenAreMetal',
#  'AgainstPolarization',
#  'FuckJoshHawley',
#  'PleezeMakeItHomeSafe',
#  'fuckrushlimbaugh',
#  'Dysevidentia',
#  'MakeMeSmile',
#  'BetoORourke',
#  'Louisiana',
#  'SquadDemocrats',
#  'AlexandriaOcasio',
#  'NinaTurner',
#  'blackmirror',
#  'IBEW',
#  'alexandriacortez',
#  'CoriBush',
#  'ArmedEnvironmentalism',
#  'ActiveMeasures',
#  'Oregon_Politics',
#  'oregon',
#  'westlinn',
#  'occupywallstreet',
#  'MAGAretards',
#  'FuckYouKaren',
#  'PoliticalPundits',
#  'Fakertarians',
#  'beholdthemasterrace',
#  'technews',
#  'AnarchistRC',
#  'BidenCoalition',
#  'economy',
#  'Democrats2020',
#  'WhatBidenHasDone',
#  'curb',
#  'nature',
#  'BirdsArentReal',
#  'WhatHaveDemocratsDone',
#  'GarbageApes',
#  'architecture',
#  'FCMentee',
#  'KamalaHarris',
#  'DanCrenshaw',
#  'BiglyForBiden',
#  'TwinCities',
#  'UnderReportedNews',
#  'bayarea',
#  'deaf',
#  'Accounting',
#  'Golden_State',
#  'patient_hackernews',
#  'disabledrights',
#  'RinoDinoPorcupino',
#  'RooseveltRepublicans',
#  'YangGang',
#  'worldpolitics2',
#  'GoodBlackNews',
#  'LoveForAmazon',
#  'Full_news',
#  'thesystemisrigged',
#  'Boycott_FOXNews',
#  'SecondGreatDepression',
#  'DeclineofUS',
#  'baltimore',
#  'TheGraniteState',
#  'Bozeman',
#  'shitneoliberalismsays',
#  'LibJerk',
#  'FauxNews',
#  'SwarmOfWokeists',
#  'PositiveNewsCovid19',
#  'PaMedicalMarijuana',
#  'CanopyGrowthCorp',
#  'EntsoftheDMV',
#  'PRICXwatch',
#  'AntifaMyth',
#  'CivilianDefense',
#  'WorshipTaylorSwift',
#  'SimDemocracy',
#  'TakeaPlantLeaveaPlant',
#  'IsTheMicStillOn',
#  'IRLProgressives',
#  '2020elections',
#  'NOCRISISJUSTCHANGE',
#  'VoteByMail',
#  'CoronavirUSA',
#  'nova',
#  'Virginia',
#  'Maine',
#  'VirginiaPolitics',
#  'horserace',
#  'philately',
#  'CPUSA',
#  'humanrights',
#  'GreenNewDeal',
#  'MassachusettsPolitics',
#  'chicannabis',
#  'Pennsylvania',
#  'whowillbuildtheroads',
#  'Shadowrun',
#  'FactCheckCNN',
#  'PoliticalCoverage',
#  'democraticparty',
#  'Sane_Political',
#  'PoweredPolitic',
#  'stopworking',
#  'excitingdystopia',
#  'universalincome',
#  'ObserverNews',
#  'MensRights',
#  'GenZedong',
#  'SPACs',
#  'AntiCapitalistRants',
#  'bartenders',
#  'NewOrleans',
#  'Delaware',
#  'ufl',
#  'hotposts',
#  'demsocialists',
#  'Intelligence',
#  'Allopatria',
#  'anarchotranshumanist',
#  'yimby',
#  'IamTheVictim',
#  'FragileMarxistReditor',
#  'FragileMarxist',
#  'ForeignInfluence',
#  '2020electioncrisis',
#  'WHHR3',
#  'exmormon',
#  'fookinplaguerats',
#  'Biden_OnTheRecord',
#  'UnitedSlothSaves',
#  'NormMacdonald',
#  'JustUnsubbed',
#  'WoodyGuthriesGuitar',
#  'americancivilconflict',
#  'AmerikanSpring',
#  'OcasioCortez2024',
#  'AOC2024',
#  'AlexandriaOcasio2024',
#  'WHHR2',
#  'QualityOfLifeLobby',
#  'SurprisingNoOne',
#  'UnfuckTheWorld',
#  'BannedFromThe_Donald',
#  'COVIDDarwinAwards',
#  'WHATYOUFUCKINGDESERVE',
#  'televisioncirclejerk',
#  'REVOLUTIONARIE',
#  'Cheers',
#  'newsokur',
#  'sunlesssea',
#  'World_Politics',
#  'islamicleft',
#  'krulife',
#  'UpliftingPraxis',
#  'somecoolguys',
#  'UnexpectedMulaney',
#  'raimimemes',
#  'IndiansAcrossTheWorld',
#  'theAlgorithmHasSpoken',
#  'bernie',
#  'centerleftpolitics',
#  'TechDystopia',
#  'fragilecommunism',
#  'bostonlegal',
#  'gammasecretkings',
#  'Colt45An2Impeachments',
#  'WeLoveRachelMaddow',
#  'atlanticdiscussions',
#  'PennsylvaniaPolitics',
#  'Montana',
#  'SouthBend',
#  'Teflon_Don',
#  'bad_judge_no_bribe',
#  'infrasociology',
#  'AntiFANG',
#  'Against_Astroturfing',
#  'EndQualifiedImmunity',
#  'itcouldhappenhere',
#  'publichealth',
#  'truenews',
#  'Agriculture',
#  'Slimtinfox',
#  'RiotTactics',
#  'Myanmar2021',
#  'Asean',
#  'toxicology',
#  'Rational_skeptic',
#  'Vettage',
#  'antivax',
#  'netneutrality',
#  'fakenews',
#  'CoronaVirusUSA',
#  'ReligionExposed',
#  'AtheisticTeens',
#  'AfterThereforeBecause',
#  'GoScienceFuckPolitics',
#  'TrumpFlu',
#  'notactuallyworldnews',
#  'novel_coronavirus',
#  'worldnews',
#  'redacted',
#  'NewCharismaticism',
#  'OutingDominionism',
#  'FeMRADebates',
#  'scandinavia',
#  'INGuns',
#  'liberalgunowners',
#  'CAguns',
#  'NJGuns',
#  'progun',
#  '2ALiberals',
#  'Kalashaholics',
#  'nra',
#  'DEGuns',
#  'redflaglawabuses',
#  'ronpaul',
#  'dankmeme',
#  'clown',
#  'DonOperInfo',
#  'GeorgeFloydRevolution',
#  '321',
#  'houston',
#  'FridayNightFunkin',
#  'PrimateDominanceGame',
#  'censorship',
#  'Longreads',
#  'Green_News',
#  'Rebuplican',
#  'Qonservative',
#  'Snowflake_Meltdown',
#  'demonsemen',
#  'RedditFruitSalad',
#  'mitchmcconnell',
#  'KarmaFarming4Pros',
#  'NIVEJ',
#  'Wallstreetbetsnew',
#  'DownTimePodcast',
#  'gay',
#  'AbuseInterrupted',
#  'The_Rudy',
#  'SLCUnedited',
#  'Dixie',
#  'PoliticalCompassMemes',
#  'HuntsvilleAlabama',
#  'DHSPACT',
#  'ClearlyRussianTrolls',
#  'YACUHQ',
#  'liestrumptoldus',
#  '2404',
#  'Coppassdenied',
#  'Trump666',
#  'accidentallyleftwing',
#  'Trumpthreatens',
#  'popularpost',
#  'PKA',
#  'TheSocialDilemma',
#  'DrakeAndJoshTwitter',
#  'NEET',
#  'PandR',
#  'CoronavirusRecession',
#  'FuckAmerica',
#  '30ROCK',
#  'DystopiaToday',
#  '1984isreality',
#  'governmentoppression',
#  'Protest2020',
#  'police',
#  'evolutionReddit',
#  'Alec',
#  'nyspolitics',
#  'FakeProtesters',
#  'CainPolitique',
#  'BloomingtonModerate',
#  'NYvsTrump',
#  'TravisCoResistance',
#  'GNV',
#  'ChurchOfSuffrage',
#  'PopCultureGifs',
#  'TaiwanChina',
#  'Idiotswithguns',
#  'KillFacebook',
#  'fuckyoutucker',
#  'Professors',
#  'LibertarianFreeState',
#  'fifthamendment',
#  'The_Khashoggi_Effect',
#  'donaldtrumpjr',
#  'punchableface',
#  'accidentallycommunist',
#  'trumpsbeingtrumps',
#  'theDonaldTrumpJr',
#  'electionfraud',
#  'JoeBidenIsADisaster',
#  'IndianaPolitics',
#  'asozialesnetzwerk',
#  'LibertarianPartyUSA',
#  'minnesota',
#  'Autodivestment',
#  'ProtestsofPeace',
#  'CoronavirusJapan',
#  'cvnews',
#  'sph',
#  'CorruptionOnAPlatter',
#  'RedditMadeMeRightWing',
#  'ShitLiberalsSay',
#  'OrangeManBad',
#  'EndTheDuopoly',
#  'Rights',
#  'Michigan',
#  'rva',
#  'CovidPanel',
#  'Liberal_Conservatives',
#  'Ballots',
#  'China',
#  'TedCruzHasNoBalls',
#  'Tonedeafcelebs',
#  'LightsCameraPodcast',
#  '2020Headlines',
#  'KeithAndTheGirl',
#  'suicidebykarma',
#  'OnCinemaAtTheCinema',
#  'TheBoys',
#  'thechristianleft',
#  'southcarolina',
#  'AlexandriaCortez2024',
#  'Cistem',
#  'Cortez2024',
#  'gardening',
#  'MelaniaTrumpIsARobot',
#  'Kanye',
#  '1998TeenMovie',
#  'NewJerseyEnts',
#  'ncpolitics',
#  'CoronavirusCirclejerk',
#  'Chinatown_irl',
#  'vouched',
#  'Environmental_Policy',
#  'BasicFood',
#  'BrandNewSentence',
#  'aaronswartz',
#  'ShahidButtar',
#  'Democrat',
#  'Election2020',
#  'philadelphia',
#  'Tucson',
#  'stimuluscheck',
#  'CultureShipNames',
#  'DuggarsSnark',
#  'BanFactoryFarming',
#  'vegan',
#  'fresno',
#  'wholefoods',
#  'BobGood',
#  'StLouis',
#  'RatsLeavingTheShip',
#  'alaska',
#  'DemocracyNow',
#  'Ternion',
#  'theydidthemath',
#  'LiberalsOutOfContext',
#  'SubsGonePolarized',
#  'climatepolicy',
#  'XLFleetInvestorclub',
#  'BidenHarrisForAmerica',
#  'environmentaljustice',
#  'FuturologyPolitics',
#  'BernieFor2020',
#  'PresidentialRaceMemes',
#  'Howie2020',
#  'GreenBallot',
#  ...]

# %%
H= G.to_undirected()
nx.number_connected_components(H)
# Out:
# 1

# %%
comps = list(nx.connected_components(H)) # get a list of connected components (for decreasing size)
comp_1 = nx.subgraph(H, comps[0])

# %%
nx.diameter(H.subgraph(comps[0]))
# Out:
# 10

# %%
nx.triangles(H)
# Out:
# {'nature': 58,
#  'environment': 2527,
#  'EcoNewsNetwork': 939,
#  'PublicLands': 7,
#  'EndangeredSpecies': 30,
#  'animalimpact': 27,
#  'sharks': 62,
#  'Soil': 0,
#  'Fuck_This_Guy': 209,
#  'vegan': 1131,
#  'Animals': 13,
#  'UpliftingNews': 1311,
#  'organizedhealing': 58,
#  'Green_News': 352,
#  'wildlifecorridors': 78,
#  'Outdoors': 109,
#  'SpeculativeEvolution': 11,
#  'WomenInNews': 14,
#  'TheFightThatMatters': 1134,
#  'WomensRightsNews': 46,
#  'prochoice': 1,
#  'worldnews': 7190,
#  'europes': 27,
#  'indepthstories': 54,
#  'Midwives': 0,
#  'catalonia': 3,
#  'blackladies': 2,
#  'ClimateCrisis': 35,
#  'xxstem': 0,
#  'HydroHomies': 1673,
#  'anime_titties': 613,
#  'cleanstreetbets': 15,
#  'BigTent': 387,
#  'ClimateDenialism': 12,
#  'BigAgro': 13,
#  'DoomsdayNow': 255,
#  'DoomsdayBook': 68,
#  'greeninvestor': 9,
#  'DivineRightOfKings': 183,
#  'energy': 1111,
#  'LockCarbon': 82,
#  'Toadbook': 42,
#  'SGU': 10,
#  'GoodRisingTweets': 3117,
#  'Reterra': 0,
#  'organic': 14,
#  'left_urbanism': 120,
#  'EnoughMuskSpam': 88,
#  'bicycling': 174,
#  'patient_hackernews': 355,
#  'canadaleft': 389,
#  'CitizenPlanners': 5,
#  'KochWatch': 25,
#  'TaiwanChina': 61,
#  'taiwan': 151,
#  'TheEndOfHumanityShow': 74,
#  'soundsaboutright': 151,
#  'economy': 959,
#  'CapitalismInDecay': 1,
#  'Allopatria': 88,
#  'AnythingGoesNews': 614,
#  'ABoringDystopia': 3757,
#  'Indigenous': 18,
#  'Hozhor': 33,
#  'PlantBased4ThePlanet': 93,
#  'sustainability': 433,
#  'Ohio': 333,
#  'Agriculture': 13,
#  'climatejustice': 165,
#  'GreatLakes': 37,
#  'RuralDemocrats': 134,
#  'climateaction': 253,
#  'climatepolicy': 189,
#  'DemocracyNow': 110,
#  'usa': 1306,
#  'ClimateChangeSolution': 186,
#  'USNews2': 472,
#  'USGovernment': 741,
#  'usapolitics': 8,
#  'world': 742,
#  'WarOnEarth': 29,
#  'europe': 2053,
#  'alltheleft': 2440,
#  'TheAbditory': 1512,
#  'terrifyingstatistics': 53,
#  'Communalists': 499,
#  'wheresthebeef': 31,
#  'GreenConsumersUnion': 1,
#  'newjersey': 14,
#  'Energy_unbiased': 18,
#  'NuclearPower': 51,
#  'airlines': 26,
#  'florida': 87,
#  'DemocratsforDiversity': 197,
#  'EarthEnthusiasts': 79,
#  'PlanetEarth': 4,
#  'ClimateAndEnvironment': 236,
#  'planet': 17,
#  'ClimateActivism': 70,
#  'netzero': 5,
#  'CleanEnergy': 216,
#  'north_america': 197,
#  'EmissionsTax': 2,
#  'carboncapture': 14,
#  'northamerica': 206,
#  'Hawaii': 6,
#  'goodnews': 496,
#  'hawaiinews': 3,
#  'Restoration_Ecology': 19,
#  'oceans': 25,
#  'CoralRestoration': 10,
#  'Positivity': 27,
#  'marinebiology': 132,
#  'environmentaljustice': 79,
#  'ClimateActionPlan': 522,
#  'ocean': 74,
#  'Futurology': 3941,
#  'Michigan_Politics': 16,
#  'solarpower': 35,
#  'gmc': 2,
#  'michigandemocrats': 2,
#  'midwest': 7,
#  'michiganpolitics': 22,
#  'Renewable': 266,
#  'usanews': 223,
#  'solarpowerplants': 2,
#  'windpower': 68,
#  '2030': 0,
#  'climateskeptics': 91,
#  'ClimateNews': 18,
#  'smartcities': 40,
#  'SouthAsia': 19,
#  'IndiaSpeaks': 219,
#  'airpollution': 3,
#  'indianews': 83,
#  'Cities': 198,
#  'Sustainable': 237,
#  'RenewableEnergy': 321,
#  'AppleInvestors': 5,
#  'WarfNews': 20,
#  'SunriseMovement': 110,
#  'ideasforgovt': 30,
#  'PhysicalGeography': 135,
#  'Kossacks_for_Sanders': 1238,
#  'veganscience': 32,
#  'Environmentalism': 244,
#  'Green': 552,
#  'PeopleDoGood': 24,
#  'GetIt2Gether': 2,
#  'FuckNestle': 134,
#  'collapse': 922,
#  'vego': 85,
#  'lostgeneration': 2071,
#  'AmazoNope': 66,
#  'ArmedEnvironmentalism': 44,
#  'uspolitics': 621,
#  'HC_Capitalism': 55,
#  'NoLawns': 12,
#  'AtheismComedy': 73,
#  'LocalismEngland': 33,
#  'IndianCountry': 180,
#  'UnfuckTheWorld': 96,
#  'actualconspiracies': 0,
#  'Corruption': 368,
#  'workthatreconnects': 13,
#  'Permanence': 3,
#  'MachineThatMakesMoney': 43,
#  'TechOfTheFuture': 18,
#  'water': 49,
#  'StopFossilFuels': 2,
#  'Systemic_Risk': 13,
#  'ausenviro': 0,
#  'DystopiaToday': 84,
#  'China_irl': 239,
#  'bioscience': 10,
#  'AnimalRights': 162,
#  'veganarchism': 50,
#  'climate': 497,
#  'ForestHealth': 27,
#  'SearchScene': 1,
#  'doomists': 26,
#  'brasil': 618,
#  'greatfilterpodcast': 1,
#  'Cleveland': 3,
#  'GreatLakesPrepping': 0,
#  'Environmental_Policy': 253,
#  '2020': 208,
#  'OhioGovernment': 6,
#  'Cetacea': 13,
#  'Positive_News': 259,
#  'whales': 95,
#  'CarbonFootprint': 9,
#  'GreenNewDeal': 108,
#  'GreenNewIdeas': 10,
#  'decarbonize': 0,
#  'coal': 14,
#  'FossilFuels': 35,
#  '2035': 1,
#  'COVID19RippleEffects': 253,
#  'AnarchoPacifism': 7,
#  'theworldnews': 15,
#  'environmentallaw': 9,
#  'EnvironmentProtectors': 1,
#  'greed': 74,
#  'RuralNewsNetwork': 1377,
#  'realtruthpolitics': 18,
#  'MAGAs': 500,
#  'libclimateactivism': 61,
#  'neoliberal': 592,
#  'WayOfTheBern': 2899,
#  'Fuckthealtright': 539,
#  'DemocraticSocialism': 2018,
#  'MeidasTouch': 126,
#  'BigEnergy': 65,
#  'Charlotte': 41,
#  'audihertz': 149,
#  'climatescience': 8,
#  'N_N_N': 41,
#  'CleanWater': 2,
#  'DavidDistributed': 39,
#  'UnitedSlothSaves': 261,
#  'darkfacts': 0,
#  'supplychain': 31,
#  'Waste': 1,
#  'kellogg': 0,
#  'ZeroWaste': 273,
#  'enviroaction': 73,
#  'COMPLETEANARCHY': 2328,
#  'BlackFridayProtest': 88,
#  'gogopgo': 5,
#  'HillbillyNerdTalk': 241,
#  'ProEarth': 13,
#  'DiscoverEarth': 639,
#  'UpstateUrban': 0,
#  'Greenspo': 9,
#  'Urbanism': 0,
#  'yimby': 20,
#  'NUMTOT': 0,
#  'VeganJusticeLeague': 18,
#  'news': 6436,
#  'environmental_science': 29,
#  'furry_irl': 32,
#  'HotZone': 44,
#  'nottheonion': 1777,
#  'srilanka': 7,
#  'PuertoRico': 13,
#  'IvankaTrump': 28,
#  'Trumpet_of_Discord': 333,
#  'SocialismAndVeganism': 41,
#  'drillshitpost': 8,
#  'Elephants': 50,
#  'elephantsbeingbros': 3,
#  'BlackLivesMatter': 1013,
#  'Bad_Cop_No_Donut': 3687,
#  '2020PoliceBrutality': 1034,
#  'AntifascistsofReddit': 1241,
#  'norfolk': 1,
#  'wisconsin': 179,
#  'Anarcho_Capitalism': 1675,
#  'FuckTheProudBoys': 106,
#  'PoliceAccountability1': 95,
#  'ACAB': 1112,
#  'TrueCrimeDiscussion': 14,
#  'AmIFreeToGo': 86,
#  'leftistveterans': 361,
#  'EarningTheHate': 130,
#  'ContinueToServe': 52,
#  'WatchdogJournalism': 38,
#  'Policeoversight': 35,
#  'shitguncontrollerssay': 19,
#  'ProtectingandServing': 65,
#  'NoLockedThreads': 477,
#  'StandAgainstTyranny': 217,
#  'GunsAreCool': 111,
#  'AllCopsAreBad': 117,
#  'WomenForTrump': 23,
#  'conspiracy': 1650,
#  'YangForPresidentHQ': 426,
#  'Superstonk': 1022,
#  'RetailNews': 15,
#  'CancelWallStreet': 4,
#  'Ytqaz2019': 1137,
#  'LeopardsAteMyFace': 1008,
#  'OSINT': 0,
#  'ParlerWatch': 286,
#  'capitolcoup': 67,
#  'DarkViperAU': 54,
#  'newyorkcity': 297,
#  'uscg': 3,
#  'policebrutality': 141,
#  'NoGoodCops': 5,
#  'conservativeterrorism': 21,
#  'foreignservice': 0,
#  'EmergingRisks': 89,
#  'Euromaidan2014': 10,
#  'PublicFreakout': 17763,
#  'WhitePrivilegeDenied': 0,
#  'labor': 572,
#  'ExposingRussia': 9,
#  'humanrights': 98,
#  'Astuff': 374,
#  'PeopleBeingAssholes': 83,
#  'demsocialist': 113,
#  'news6': 0,
#  'DemocraticDiscussions': 202,
#  'USMC': 116,
#  'actualliberalgunowner': 479,
#  'Stargate': 43,
#  'sdrawkcabtidder': 17,
#  'thestateofshit': 116,
#  'DenverProtests': 20,
#  'Political_Revolution': 2557,
#  'TimDillon': 164,
#  'OustGhislaineMaxwell': 0,
#  'HumanTrafficking': 16,
#  'EpsteinFakedHisDeath': 3,
#  'Ghislaine': 1,
#  'thelandofthefree': 3,
#  'Louisiana': 38,
#  'awfuleverything': 5304,
#  'WatchRedditDie': 32,
#  'Anarchism': 2510,
#  'drunkenpeasants': 8,
#  'leftist': 69,
#  'PerpetualPixelNews': 4,
#  'WorldProtests': 47,
#  'boringdystopia': 354,
#  'Real_Communism': 67,
#  'These_Fucking_People': 69,
#  'ConspiracyPastPresent': 137,
#  'conspiracyfact': 89,
#  'Amreeka': 85,
#  'TriCitiesWA': 2,
#  'WAlitics': 11,
#  'LouisianaPolitics': 6,
#  'PRICXwatch': 3,
#  'MiscellaneousContent': 365,
#  'LaceyWA': 42,
#  'Fuck45': 325,
#  'prisonreform': 7,
#  'theFutureLiberalsWant': 7,
#  'WApeoplesparty': 1,
#  'CivilianDefense': 24,
#  'PostScarcityNow': 178,
#  'alllivesmatter': 25,
#  'SeaWA': 21,
#  'Tacoma': 5,
#  'aznidentity': 96,
#  'RacismAgainstAsians': 45,
#  'nouseforatitle': 573,
#  'JusticeServed': 1786,
#  'USNEWS': 28,
#  'UglyHumanity': 44,
#  'FortWorth': 77,
#  'ViolenceAgainstAsians': 37,
#  'WNC': 2,
#  'SocialistRA': 538,
#  'HowGodWorks': 61,
#  'atheism': 430,
#  'inthemorning': 36,
#  'exchristian': 291,
#  'religiousfruitcake': 458,
#  'ReligionExposed': 13,
#  'ANormalDayInAmerica': 208,
#  'Cult_Right': 51,
#  'McMansionHell': 29,
#  'BidenHarris_2020': 29,
#  'honeybadgerparty': 54,
#  'jschlatt': 8,
#  'WhatsonNow': 2,
#  'women': 48,
#  'WheresMyWAIFU': 0,
#  'sextrafficking': 1,
#  'memphis': 8,
#  'Buffalo': 11,
#  'deepfatfried': 233,
#  'RepublicanValues': 450,
#  'britishmilitary': 5,
#  'neoconNWO': 38,
#  'The_Mueller': 386,
#  'TuckerTheFucker': 10,
#  'fuckyoutucker': 15,
#  'FuckTuckerCarlson': 7,
#  'AntiHateCommunities': 52,
#  'myfavoritemurder': 358,
#  'tookyoulongenough': 21,
#  'NoNewNormal': 1123,
#  'PositiveNewsCovid19': 50,
#  'ArizonaLeft': 102,
#  'Albuquerque': 42,
#  'FourCorners': 7,
#  'CoronavirusMa': 18,
#  'upbeatnews': 1,
#  'PrepperIntel': 30,
#  'Iowa': 120,
#  'desmoines': 23,
#  'NoShitSherlock': 77,
#  'ems': 43,
#  'LateStageCapitalism': 5178,
#  'AmazonFC': 131,
#  'fuckyoujeffbezos': 1,
#  'BigTech': 236,
#  'fuckyoufascists': 122,
#  'racism': 51,
#  'seasteading': 23,
#  'Anticonsumption': 170,
#  'Veryfuckingstupid': 55,
#  'TheHumanPlague': 6,
#  'FOXNEWS': 24,
#  'maskfreakouts': 98,
#  'HermanCainAward': 30,
#  'AmericanPolitics': 568,
#  'SubGenius': 1,
#  'arizonapolitics': 57,
#  'NativeAmerican': 55,
#  'SyndiesUnited': 318,
#  'internettoday': 179,
#  'conservatives': 473,
#  'MarchAgainstNazis': 1014,
#  'TheBellmanStillRings': 51,
#  'UFOs': 26,
#  'skeptics': 6,
#  'BoogieMonster': 25,
#  'ASU': 0,
#  'catpics': 6,
#  'cmu': 0,
#  'PeteZaHutt': 3,
#  'anJoDelCo': 359,
#  'guam': 8,
#  'Antivaxers': 0,
#  'NoahGetTheBoat': 939,
#  'ireland': 391,
#  'Kappa': 2,
#  'SatanicRitualAbuse': 9,
#  'Music': 30,
#  'GenX': 20,
#  'TTAMF': 4,
#  'rorius': 0,
#  'ConspiracyUltra': 35,
#  'Beebola': 217,
#  'KGBTR': 895,
#  'AnarchismZ': 535,
#  'esist': 390,
#  'IronFrontUSA': 314,
#  'DefundPolice': 140,
#  'Post_Is_Locked': 0,
#  'Calgary': 2,
#  'Manitoba': 0,
#  'CoronaVirusUSA': 8,
#  'povertyfinance': 78,
#  'oregon': 63,
#  'Eugene': 6,
#  'conspriacytheroy': 7,
#  'Libertarian': 490,
#  'StallmanWasRight': 323,
#  'freesoftware': 22,
#  'antiwork': 2159,
#  'bootlickingnews': 81,
#  'OrphanCrushingMachine': 3,
#  'SubstituteTeachers': 0,
#  'uptiltingnews': 0,
#  'PerseverancePorn': 0,
#  'NotRealUpliftingNews': 3,
#  'Metalocalypse': 0,
#  'NasaHOAX': 0,
#  'True_Kentucky': 9,
#  'Louisville': 169,
#  'TrueAnon': 120,
#  'Policestudies': 58,
#  'nyc': 137,
#  'nyspolitics': 34,
#  'StopPoliceBrutality': 0,
#  'McJuggerNuggets': 0,
#  'SwitzerlandIsFake': 15,
#  'CapitolConsequences': 494,
#  'newsokuexp': 117,
#  'MorbidReality': 89,
#  'OGoogleReaders': 5,
#  'policeuk': 47,
#  'NoEvidenceNoCrime': 3,
#  'MARCIANOTECH': 0,
#  'Cyberpunk': 341,
#  'DonutOperator': 277,
#  'boulder': 12,
#  'ThatsHowThingsWork': 8,
#  'occupywallstreet': 599,
#  'TheMajorityReport': 283,
#  'thedavidpakmanshow': 557,
#  'VaushV': 2072,
#  'aclu': 10,
#  'PleezeMakeItHomeSafe': 2,
#  'GoodIdeasForAustralia': 3,
#  'Hasan_Piker': 737,
#  'BerniesRevolution': 67,
#  'fuckthepolice': 73,
#  'TrueWhiteCrime': 9,
#  'NEWPOLITIC': 300,
#  'Police_the_Police_ACP': 71,
#  'imatotalpeiceofshit': 306,
#  'Noctor': 17,
#  'protest': 188,
#  'OpenArgs': 10,
#  'DrainTheSwamp': 8,
#  'TIHI': 4918,
#  'BrutalityTracker': 16,
#  'PoliceUseOfForce': 1,
#  'PoliticalPundits': 150,
#  'socialism': 1515,
#  'GeorgeFloydRiots': 15,
#  'ExposePoliceBrutality': 30,
#  'Amash4President2020': 0,
#  'truenews': 47,
#  'LoveForUnions': 0,
#  'GlobalNews': 683,
#  '2404': 1,
#  'PoliticalTakes': 0,
#  'americancivilconflict': 6,
#  'Hong_Kong': 25,
#  'gunpolitics': 214,
#  'policeabuse': 12,
#  'AutisticPride': 5,
#  'MensRights': 49,
#  'neurodiversity': 0,
#  'autism': 45,
#  'FeeltheBern': 3,
#  'DanLeBatardShow': 206,
#  'ThereIsNoBottom': 82,
#  'Full_news': 37,
#  'AmericanFascism2020': 732,
#  'thisiswhyweprotest': 0,
#  'EndMassIncarceration': 2,
#  'Flagblack': 70,
#  'boston': 9,
#  'union': 755,
#  'PBWorld': 24,
#  'BoicoteANestle': 1,
#  'CorporateMisconduct': 6,
#  'GoldandBlack': 365,
#  'NewMexicoPolitics': 31,
#  'fullstalinism': 17,
#  'missouri': 28,
#  'StLouis': 55,
#  'thesystemisrigged': 105,
#  'NewOrleans': 81,
#  'FansHansenvsPredator': 1,
#  'SouthJersey': 4,
#  'Qult_Headquarters': 303,
#  'Aoxxt2': 259,
#  'maryland': 49,
#  'behindthebastards': 53,
#  'LatinoRA': 1,
#  'okc': 1,
#  'shitamericanspayfor': 163,
#  'cnn': 118,
#  'WoodyGuthriesGuitar': 10,
#  'RacistRegret': 1,
#  'PoliceBrutality2020': 55,
#  'LasCruces': 1,
#  'SLCUnedited': 51,
#  'NotDyingForWallStreet': 14,
#  'TravisCoResistance': 11,
#  'daverubin': 223,
#  'Police_v_Video': 76,
#  'BlackWomens': 2,
#  'Knoxville_liberty': 1,
#  'FirstAgainstTheWall': 21,
#  'Pennsylvania': 23,
#  'police': 196,
#  'Chiraqology': 25,
#  'weed': 290,
#  'mmmforensics': 0,
#  'BadBoyz0fNYC': 0,
#  'ServeAndProtect': 17,
#  'ActualPublicFreakouts': 2282,
#  'TheGreatestMovement': 5,
#  'ProtectAndServe': 118,
#  'Costco': 15,
#  'CAguns': 17,
#  'shittyredditfrontpage': 0,
#  'LateStageImperialism': 634,
#  'portugueses': 36,
#  'LimitlessDiscussions': 0,
#  'Iamactuallyverybadass': 515,
#  'mildlyinfuriating': 2801,
#  'newsly': 24,
#  'ColoradoSprings': 4,
#  'TrumpCivilWar': 31,
#  'Idiotswithguns': 85,
#  'LeftvsRightDebate': 10,
#  'army': 18,
#  'HelpMeFind': 30,
#  'Military': 271,
#  'HillaryMeltdown': 22,
#  'uwaterloo': 14,
#  'WallStreetTrader': 2,
#  'MarshallBrain': 171,
#  'downliftingnews': 1,
#  'Otters': 9,
#  'BAME_UK': 87,
#  'Sneakers': 4,
#  'CrimesAgainstAsianity': 46,
#  'BrasildoB': 47,
#  'stimuluscheck': 24,
#  'washingtondc': 34,
#  'gammasecretkings': 18,
#  'QanonKaren': 188,
#  'NotoQanon': 143,
#  'PersonOfInterest': 1,
#  'OhNoAnyway': 0,
#  'nestledidnothingwrong': 13,
#  'IWW': 478,
#  'CorporateMalfeasance': 44,
#  'technews': 297,
#  'PivotPodcast': 1,
#  'FuckTheZuck': 0,
#  'CoronavirusCirclejerk': 354,
#  'ChurchOfCOVID': 50,
#  'iminfected': 0,
#  'CoronaFreude': 0,
#  'Philippines': 185,
#  'TheWorkersCouncil': 72,
#  'Vastlystupid': 59,
#  'CoronavirusUS': 555,
#  'democracy': 248,
#  'AlexeiNavalny': 6,
#  'Mildlyinterestingas': 5,
#  'CoronavirusFL': 30,
#  'CoronavirusGA': 25,
#  'LibertarianPartyUSA': 5,
#  'EnoughLibertarianSpam': 75,
#  'FreeSpeech': 117,
#  'CivilRights': 5,
#  'ternionallpowerful': 0,
#  'ViralTexas': 83,
#  'conspiracyUK': 9,
#  'Dailyslant': 62,
#  'WHHR4': 34,
#  'uncensorstiny': 6,
#  'Winnipeg': 30,
#  'Mujico': 297,
#  'Arkansas': 14,
#  'mcgill': 0,
#  'GeoVideos': 112,
#  'Edmonton': 3,
#  'WallStreetbetsELITE': 157,
#  'NEWSfun': 84,
#  'latinos': 36,
#  'KnowledgeFight': 22,
#  'InternetCommentEtiq': 92,
#  'Digital_Manipulation': 108,
#  'ALEXJ0NES': 0,
#  'freetalklive': 20,
#  'TheSwampDrain': 3,
#  'ABCDesis': 22,
#  'wisp': 0,
#  'SpaceXLounge': 43,
#  'Piracy': 20,
#  'Comcast': 0,
#  'LincolnProject': 233,
#  'SmallDeliMeats': 1,
#  '8bitbookclub': 0,
#  'LoveForScalpers': 1,
#  'APieceAjit': 0,
#  'codyko': 32,
#  'h3h3productions': 448,
#  'Honkyandthebadger': 301,
#  'AXELNetwork': 4,
#  'TechDystopia': 29,
#  'Qfiles': 1,
#  'BadGOP_NoDoughnuts': 38,
#  'MichaelFlynn': 1,
#  'ArcanaPost': 63,
#  'samharris': 110,
#  'DarkFuturology': 145,
#  'NewPatriotism': 213,
#  'WhereUFckdUpAt': 0,
#  'Ternion': 2,
#  'Belgium_kingdomOf': 80,
#  'Healthcare_costs': 84,
#  'democraticparty': 159,
#  'demsocialists': 421,
#  'PeoplesPartyUSA': 134,
#  'jimmydore': 623,
#  'MedicareForAll': 85,
#  'nova': 33,
#  'rva': 17,
#  'Virginia': 105,
#  'diabetes_t1': 14,
#  'healthcare': 20,
#  'HoldMyCovid': 3,
#  'refusedMask': 52,
#  'clearlake': 1,
#  'IASIP': 565,
#  'TheDollop': 67,
#  'Trumpvirus': 918,
#  'arizona': 5,
#  'LeopardsAteMyFaceMask': 1,
#  'Manteca': 0,
#  'ownthelibs': 31,
#  'securityguards': 17,
#  'AbruptChaos': 7429,
#  'PussyPass': 12,
#  'Shitifind': 1,
#  'yourmomshousepodcast': 2034,
#  'rock': 4,
#  'punchableface': 23,
#  'FuckYouKaren': 1421,
#  'CallToActionWisconsin': 55,
#  'schadenfreude': 39,
#  'CoronavirusRegret': 60,
#  'covidregret': 8,
#  'SurprisingNoOne': 54,
#  'goodnesss': 0,
#  'resistentem_tyrannide': 51,
#  'technology': 3285,
#  'MagesVsMatriarchy': 4,
#  'NYvsTrump': 1,
#  'brasilivre': 453,
#  'ggetgot': 2,
#  'Covid19VaccineRats': 1,
#  'saudiarabia': 18,
#  'KingdomofSaudiArabia': 7,
#  'basicincomejapan': 18,
#  'Cascadia': 43,
#  'NormMacdonald': 148,
#  'PacificNorthwest': 3,
#  'BidenCoalition': 58,
#  'hanguk': 4,
#  'Chinatown_irl': 19,
#  'Democrats2020': 5,
#  'mostgilded': 1,
#  'derekhardin': 0,
#  'WhatHaveDemocratsDone': 10,
#  'AdamCarolla': 4,
#  'Boxing': 1,
#  'NelkFilmz': 8,
#  'ksi': 279,
#  'Good_Cop_Free_Donut': 22,
#  'Buddhism': 6,
#  'HumanResponse': 26,
#  'deescalation': 0,
#  'ABA': 25,
#  'Connecticut': 56,
#  'bostontrees': 1,
#  'SportsQuestionMark': 1,
#  'tesdcares': 14,
#  'JoeyDiaz': 4,
#  'hamiltonmemes': 0,
#  'spininelfianco': 0,
#  'conspiracyhub': 26,
#  'massachusetts': 50,
#  'Epstein': 1,
#  'TrueCrime': 7,
#  'AntiMAPmilitary': 0,
#  'Cistem': 1,
#  'Spudmode': 49,
#  'Coppassdenied': 35,
#  'Libraries': 5,
#  'armenia': 36,
#  'SecondGreatDepression': 37,
#  'WealthColdWar': 22,
#  'TenantUnion': 136,
#  'UighurResearch': 5,
#  'Egalitarianism': 10,
#  'Turkey': 114,
#  'Kazakhstan': 6,
#  'fucktheccp': 456,
#  'Turkiye': 0,
#  'infuriatingasfuck': 349,
#  'BoycottChinaRussiaUSA': 5,
#  'FauxNews': 27,
#  'NEPA': 0,
#  'byebyejob': 20,
#  'AsburyPark': 0,
#  'AmazonDSPDrivers': 642,
#  'milwaukee': 0,
#  'TruthLeaks': 12,
#  'bayarea': 82,
#  'SeattleChat': 4,
#  'antinatalism': 283,
#  'mopolitics': 26,
#  'wholesome': 590,
#  'doordash_drivers': 13,
#  'YourMoneyIsYourVote': 12,
#  'CaliforniaPost': 0,
#  'AngrySocialist': 18,
#  'stupidpol': 404,
#  'GamingLaptops': 0,
#  'applesucks': 2,
#  'RobinHoodPennyStocks': 1,
#  'ConcentrationOfWealth': 560,
#  'Nike': 0,
#  'WeAreNotAsking': 143,
#  'interesting': 201,
#  'EcoFriendly': 3,
#  'fuckamazon': 70,
#  'totallynotrobots': 477,
#  'AIandRobotics': 94,
#  'hotposts': 75,
#  'dsa': 399,
#  'UFCW': 79,
#  'AntiAmazon': 141,
#  'excitingdystopia': 41,
#  'LibertarianFreeState': 7,
#  'WHHR3': 4,
#  'AllCopsAreBastards': 2,
#  'EatTheRich2021': 0,
#  'Worldnews_ViralWorld': 0,
#  'pittsburgh': 9,
#  'stormwater': 0,
#  'fairtax': 16,
#  'FixedThatForYa': 1,
#  '2ndIntelligentSpecies': 119,
#  'philadelphia': 102,
#  'batonrouge': 30,
#  'LandlordLove': 161,
#  'EssentialEmployees': 371,
#  'QualityOfLifeLobby': 240,
#  'GME': 867,
#  'CoV2Canada': 33,
#  'politics': 7512,
#  'Vitards': 4,
#  'IWork4DavidBrock': 38,
#  'FragileMarxistReditor': 20,
#  'FragileMarxist': 20,
#  'FragileBlackReditors': 3,
#  'MuskMarsColony': 39,
#  'FragileBlackTwitter': 13,
#  'IamTheVictim': 6,
#  'The_Asylum': 0,
#  'copoverde': 1,
#  'noagenda': 47,
#  'malefashionadvice': 0,
#  'washingtonNFL': 0,
#  'avoidchineseproducts': 1,
#  'NavyBlazer': 0,
#  'SeattleWA': 41,
#  'islam': 397,
#  'accidentallycommunist': 260,
#  'FreeTheUyghurs': 61,
#  'MuslimLounge': 6,
#  'ShitLiberalsSay': 224,
#  'BoycottChina': 92,
#  'IslamOfficial': 0,
#  'republicanforreal': 12,
#  'QuiteFrankly': 45,
#  'AntiFANG': 314,
#  'CorpFree': 74,
#  'Oregon_Politics': 27,
#  'The_Dotard': 23,
#  'AntiTrumpAlliance': 160,
#  'vinyljerk': 36,
#  'COVIDDarwinAwards': 39,
#  'EpicKarma': 0,
#  'gso': 0,
#  'Moronavirus': 75,
#  'thedailyzeitgeist': 9,
#  'TexasPolitics': 29,
#  'texas': 180,
#  'IdiotsFightingThings': 1472,
#  'ToolBand': 46,
#  'CoronavirusCA': 16,
#  'chaoticgood': 157,
#  'CovIdiots': 76,
#  'Dear_Mr_Atheist': 98,
#  'GenZedong': 371,
#  'athiest': 3,
#  'ReligiouslyStupid': 5,
#  'Coronaphobia': 73,
#  'GoScienceFuckPolitics': 35,
#  'SanDiegoCovid19': 1,
#  'nonononoyes': 3168,
#  'TheLeagueOfMorons': 17,
#  'WHATYOUFUCKINGDESERVE': 58,
#  'unionizeDSP': 42,
#  'Masks4All': 22,
#  'REVOLUTIONARIE': 5,
#  'TheTexanwitHumor': 0,
#  'Anthropology': 3,
#  'infrasociology': 9,
#  'worldpolitics': 788,
#  'TheTopMinds': 0,
#  'SzechuanSauceSeekers': 71,
#  'ObsurdPolitics': 10,
#  'China_War': 13,
#  'ProtestBlizzcon': 3,
#  'pepperidgefarmskarma': 0,
#  'TaiwanNumberOne': 24,
#  'centerleftpolitics': 13,
#  'WhatWeDointheShadows': 0,
#  'AbolishTheMonarchy': 80,
#  'TheRoyalNews': 0,
#  'NoLockdownsNoMasks': 10,
#  'Spacers': 35,
#  'TechNewsToday': 299,
#  'netneutrality': 11,
#  'exmormon': 326,
#  'SsALT': 0,
#  'AfterThereforeBecause': 8,
#  'MuhFreedums': 0,
#  'MaskOnorFuckOff': 0,
#  'offbeat': 113,
#  'ToiletPaperUSA': 291,
#  'DankLeft': 423,
#  'NVGuns': 4,
#  'bluenecks': 1,
#  'redflaglawabuses': 6,
#  'lukewarmsalmon': 30,
#  'kroger': 25,
#  'octopus': 48,
#  'AnimalCollective': 0,
#  'ThomasPynchon': 0,
#  'ResidentAlienTVshow': 1,
#  'WeHaveConcerns': 16,
#  'KrollShow': 0,
#  'rickygervais': 250,
#  'thalassophobia': 1123,
#  'BrandNewSentence': 611,
#  'SorayorimoTooiBasho': 0,
#  'antarctica': 0,
#  'UnethicalCompanies': 89,
#  'iamanutterpieceofshit': 90,
#  'SexOffenderSupport': 0,
#  'sca': 2,
#  'antipornography': 0,
#  'iamapieceofshit': 141,
#  'Justus': 0,
#  'ButlerPA': 0,
#  'seculartalk': 284,
#  'TIL_Uncensored': 2,
#  'blowit': 15,
#  'trollfare': 13,
#  'Seattle': 256,
#  'test': 1,
#  'Foxingnews': 0,
#  'GeorgeFloydRevolution': 146,
#  'LettuceGang': 0,
#  'britishcolumbia': 22,
#  'TheTrumpZone': 34,
#  'ronpaul': 34,
#  'Seenthatcoming': 74,
#  'Snorkblot': 158,
#  'Mercerinfo': 37,
#  'PKA': 60,
#  'Lolitary': 2,
#  'CrimeJunkiePodcast': 0,
#  'thoseconspiracyguys': 0,
#  'Birthstrike': 31,
#  'MorbidRealty': 0,
#  'lastpodcastontheleft': 49,
#  'HillaryForPrison': 17,
#  'WomensNews': 0,
#  'NIVEJ': 2,
#  'conservative_CJ': 4,
#  'Sacramento': 14,
#  'JustUnsubbed': 366,
#  'theydidthemath': 249,
#  'ProgressiveChat': 71,
#  'MediaSynthesis': 3,
#  'SlanderousLiberalNews': 13,
#  'YKWD': 0,
#  'traitorperpwalk': 1,
#  'ChinaSucks': 14,
#  'tankiejerk': 28,
#  'NoMoreBigChina': 1,
#  'Bad_Cop_No_Doughnut': 17,
#  'Alabama': 23,
#  'trees': 542,
#  'timetolegalize': 2,
#  'hempflowers': 5,
#  'Veteranpolitics': 2,
#  'disabledrights': 4,
#  'BlackMentalHealth': 1,
#  'BabyBumps': 78,
#  'popularpost': 26,
#  '2ALiberals': 77,
#  'Firearms': 237,
#  'Bellingham': 17,
#  'BlackFellasAfterDark': 0,
#  'jakeandamir': 81,
#  'theydidthemonstermath': 0,
#  'mingebuttcheek': 0,
#  'Yatirim': 1,
#  'IThinkYouShouldLeave': 46,
#  'TopPostsofEachSub': 0,
#  'TopofAllTime': 0,
#  'blackmen': 13,
#  'CasualMIAMI': 0,
#  'okbuddyhasan': 1,
#  'hamberders': 0,
#  'publichealth': 26,
#  'AmericanPandemics': 1,
#  'BlueMafia': 4,
#  'KillFacebook': 30,
#  'oculus': 46,
#  'lovefromabrownplanet': 17,
#  'AngryTaxPayer': 6,
#  'shitthatdoesntmatter': 6,
#  'popheadscirclejerk': 9,
#  'clowngirls': 0,
#  ...}

# %%
#clustering
Clu = dict(nx.clustering(G))
ranks = [(k, v) for k, v in sorted(Clu.items(), key=lambda item: -item[1])]
ranks[0:]
# Out:
# [('EnvironmentProtectors', 1.0),
#  ('Alternative_Energy', 1.0),
#  ('DailyNewsPosts', 1.0),
#  ('WuhanVirus', 1.0),
#  ('TheyTrustMe', 1.0),
#  ('PlanPlantPlanet', 1.0),
#  ('Nio', 1.0),
#  ('westlinn', 1.0),
#  ('Charlottesville', 1.0),
#  ('bearpuppers', 1.0),
#  ('iamatotoalpieceofshit', 1.0),
#  ('WatchTrumpettesCry', 1.0),
#  ('totalfuckingbullshit', 1.0),
#  ('thathurts', 1.0),
#  ('Buttholeass', 1.0),
#  ('HKRising', 1.0),
#  ('mamasaidknockyouout', 1.0),
#  ('elevatorgore', 1.0),
#  ('SomeGoodNews', 1.0),
#  ('LiveIsBetter', 1.0),
#  ('coldshowers', 1.0),
#  ('messingwiththenewguy', 1.0),
#  ('coronafreakouts', 1.0),
#  ('PumpiMemes', 1.0),
#  ('winstupidprices', 1.0),
#  ('SouthDakota', 1.0),
#  ('CasualTazing', 1.0),
#  ('WholesomeFreakouts', 1.0),
#  ('ProperPublicFreakout', 1.0),
#  ('blackmirrorirl', 1.0),
#  ('KarenFreakouts', 1.0),
#  ('HighTrash', 1.0),
#  ('DunningKruger', 1.0),
#  ('projectzomboid', 1.0),
#  ('TrueJusticeServed', 1.0),
#  ('KTF', 1.0),
#  ('genuinePublicFreakout', 1.0),
#  ('DeathByMillennial', 1.0),
#  ('LostUpvoters', 1.0),
#  ('tibukandtoker', 1.0),
#  ('TheHOA', 1.0),
#  ('SlightlyDelayedKarma', 1.0),
#  ('WhyEverythingSucksNow', 1.0),
#  ('CurrentGeek', 1.0),
#  ('RealAmazonFC', 1.0),
#  ('WorkOrDie', 1.0),
#  ('CanadiansforBernie', 1.0),
#  ('Wuhan_Virus', 1.0),
#  ('WuhanNews', 1.0),
#  ('eastasianculture', 1.0),
#  ('Taipei', 1.0),
#  ('austriahungary', 1.0),
#  ('2visegrad4you', 1.0),
#  ('blackmirror_irl', 1.0),
#  ('highwayengineering', 1.0),
#  ('FULLBLOWNSOCIALISM', 1.0),
#  ('USAggression', 1.0),
#  ('TechnologyNewsToday', 1.0),
#  ('solarpanels', 1.0),
#  ('FartFarm', 1.0),
#  ('intentionalcommunity', 1.0),
#  ('miniatures', 1.0),
#  ('Angory_Tom', 1.0),
#  ('GeniusIdeas', 1.0),
#  ('speciesbeingbros', 1.0),
#  ('wood', 1.0),
#  ('Beastars', 1.0),
#  ('foundfelix', 1.0),
#  ('mundanefuckinglevel', 1.0),
#  ('heroeswithoutcapes', 1.0),
#  ('malamute', 1.0),
#  ('Corsair', 1.0),
#  ('geeky_things', 1.0),
#  ('wintercycling', 1.0),
#  ('kites', 1.0),
#  ('commencal', 1.0),
#  ('lowlevelaware', 1.0),
#  ('Britain', 1.0),
#  ('pitbullhate', 1.0),
#  ('Ceramics', 1.0),
#  ('thingsmadeofchocolate', 1.0),
#  ('didyoureddit', 1.0),
#  ('apollo', 1.0),
#  ('dailydoseofgood', 1.0),
#  ('perfectgovernance', 1.0),
#  ('TheCaretaker', 1.0),
#  ('UNCCharlotte', 1.0),
#  ('realassesofreddit', 1.0),
#  ('GifDIY', 1.0),
#  ('Jugaad', 1.0),
#  ('DevinTownsend', 1.0),
#  ('HelpingWildAnimals', 1.0),
#  ('starsector', 1.0),
#  ('Toriko', 1.0),
#  ('LoveDeathAndRobots', 1.0),
#  ('GermanShepherd', 1.0),
#  ('RedHotChiliPeppers', 1.0),
#  ('fourthworldproblems', 1.0),
#  ('Timotainment', 1.0),
#  ('BelongsInAMuseum', 1.0),
#  ('wholesomepics', 1.0),
#  ('FinalFantasyVII', 1.0),
#  ('FlintstoneTactics', 1.0),
#  ('Koi', 1.0),
#  ('Twinnovation', 1.0),
#  ('Incense', 1.0),
#  ('Gemology', 1.0),
#  ('soldering', 1.0),
#  ('DesignHomeGame', 1.0),
#  ('CITAB', 1.0),
#  ('transitiongoals', 1.0),
#  ('globeskepticism', 1.0),
#  ('HiraethVibes', 1.0),
#  ('WolvesAreBigYo', 1.0),
#  ('rccrawler', 1.0),
#  ('civ5', 1.0),
#  ('MuseOnThis', 1.0),
#  ('BaskingDogs', 1.0),
#  ('telescope', 1.0),
#  ('BloodhoundMains', 1.0),
#  ('AccidentalGhibli', 1.0),
#  ('phonewallpapers', 1.0),
#  ('TheMentalist', 1.0),
#  ('ArtTimelapse', 1.0),
#  ('crafting', 1.0),
#  ('ThroughSpaceAndTime', 1.0),
#  ('PetsFirstSnow', 1.0),
#  ('BlueChecksAreAssholes', 1.0),
#  ('MOAPES', 1.0),
#  ('LowkarmaGME', 1.0),
#  ('AMCmanipulation', 1.0),
#  ('StonkTraders', 1.0),
#  ('SUPER_DD', 1.0),
#  ('GMEplanB', 1.0),
#  ('gme_manipulation', 1.0),
#  ('truthGamesstop', 1.0),
#  ('Rensole', 1.0),
#  ('apemarket', 1.0),
#  ('OccupyStonkStreet', 1.0),
#  ('GamestopShortSqueeze', 1.0),
#  ('SecondsBeforeDisaster', 1.0),
#  ('publicdeath', 1.0),
#  ('calmboygetspet', 1.0),
#  ('OnlyHappyThings', 1.0),
#  ('fixedeyebleach', 1.0),
#  ('flyfishing', 1.0),
#  ('predator', 1.0),
#  ('antipoaching', 1.0),
#  ('kpoop', 1.0),
#  ('rule', 1.0),
#  ('HansGetAFlammenwerfer', 1.0),
#  ('meanboyfriendfnf', 1.0),
#  ('FriedOrcas', 1.0),
#  ('petercynical', 1.0),
#  ('Hot_Information7267', 1.0),
#  ('HornyJailGuards', 1.0),
#  ('fortnitefartporn', 1.0),
#  ('Newgrounds', 1.0),
#  ('TheHumanistReport', 1.0),
#  ('TheKavernacle', 1.0),
#  ('suddenlyeltonjohn', 1.0),
#  ('Whistleblowers', 1.0),
#  ('TakeOutTheTrash', 1.0),
#  ('SageAndPapita', 1.0),
#  ('consistentchaos', 1.0),
#  ('Cameraforsale', 1.0),
#  ('T_I_T', 1.0),
#  ('whatcouldgowronger', 1.0),
#  ('SuddenlyIsrael', 1.0),
#  ('midbarf', 1.0),
#  ('CustomPlayerCutscene', 1.0),
#  ('bundeswehr', 1.0),
#  ('fuckyourprotest', 1.0),
#  ('FreakoutUncensored', 1.0),
#  ('Troy', 1.0),
#  ('labradoodles', 1.0),
#  ('helddersteine', 1.0),
#  ('lorde', 1.0),
#  ('ProtestArt', 1.0),
#  ('Notaphotoshop', 1.0),
#  ('Quadrants', 1.0),
#  ('archeologyworld', 1.0),
#  ('iJerkedOffToThis', 1.0),
#  ('darkestdungeon', 1.0),
#  ('CloudsAreFake', 1.0),
#  ('vfxReference', 1.0),
#  ('SwordOfOrion', 1.0),
#  ('jacobinmagazine', 1.0),
#  ('ReddingCA', 1.0),
#  ('trustthescience', 1.0),
#  ('AlternativeHealth', 1.0),
#  ('Conspiracy_UK', 1.0),
#  ('UkConspiracy', 1.0),
#  ('satisfyinggrass', 1.0),
#  ('windsurfing', 1.0),
#  ('phoebebridgers', 1.0),
#  ('AubreyMaturinSeries', 1.0),
#  ('SwahiliTech', 1.0),
#  ('tested', 1.0),
#  ('ArtDeco', 1.0),
#  ('natureisfuckinbacklit', 1.0),
#  ('nextlevelskill', 1.0),
#  ('Acid', 1.0),
#  ('chocolate', 1.0),
#  ('WoTshow', 1.0),
#  ('SculpturePorn', 1.0),
#  ('wheelchairs', 1.0),
#  ('HildaTheSeries', 1.0),
#  ('mademesaywow', 1.0),
#  ('Dumplings', 1.0),
#  ('MountainJuice', 1.0),
#  ('LSA', 1.0),
#  ('handtools', 1.0),
#  ('Joinery', 1.0),
#  ('ericprydz', 1.0),
#  ('Anamorphicporn', 1.0),
#  ('PunjabiCulture', 1.0),
#  ('notmynormal', 1.0),
#  ('TubbyTuxes', 1.0),
#  ('thepromisedneverland', 1.0),
#  ('snowleopards', 1.0),
#  ('bernesemountaindogs', 1.0),
#  ('bleps', 1.0),
#  ('WhiskerFireworks', 1.0),
#  ('sgparrots', 1.0),
#  ('Goose', 1.0),
#  ('BaskingCats', 1.0),
#  ('extragentledogs', 1.0),
#  ('AlaskanMalamute', 1.0),
#  ('DogsStandingUp', 1.0),
#  ('AnimalsDreaming', 1.0),
#  ('AnimalsBeingFunny', 1.0),
#  ('catsbeingbathed', 1.0),
#  ('CatGrabs', 1.0),
#  ('GlitchInRealLife', 1.0),
#  ('ValorantMemes', 1.0),
#  ('ESFP', 1.0),
#  ('CatsMurderingToddlers', 1.0),
#  ('JumpyJacks', 1.0),
#  ('Gigglyooh', 1.0),
#  ('awwwlol', 1.0),
#  ('happyhumangifs', 1.0),
#  ('drifties', 1.0),
#  ('BigLion', 1.0),
#  ('CatsCalledFood', 1.0),
#  ('chinresting', 1.0),
#  ('AnimalsBeingWeird', 1.0),
#  ('concernedanimals', 1.0),
#  ('KingdomOfSean', 1.0),
#  ('shouldercats', 1.0),
#  ('AnimalGangs', 1.0),
#  ('PussyLicker', 1.0),
#  ('for_jj', 1.0),
#  ('KittenMittens', 1.0),
#  ('PomeranianGifs', 1.0),
#  ('OrangeKittys', 1.0),
#  ('kittenswhoyell', 1.0),
#  ('oversizedkittens', 1.0),
#  ('FFVIIRemake', 1.0),
#  ('bdsmmemes', 1.0),
#  ('YourJokeButWorse', 1.0),
#  ('NopeIReadThatRight', 1.0),
#  ('crazyexgirlfriend', 1.0),
#  ('5555555', 1.0),
#  ('Pride_and_Positivity', 1.0),
#  ('grilledcheese', 1.0),
#  ('Beezling', 1.0),
#  ('HappyMeowGifs', 1.0),
#  ('xannation', 1.0),
#  ('crushered', 1.0),
#  ('Rigging', 1.0),
#  ('MechTimeLapse', 1.0),
#  ('Animalssuckatjumping', 1.0),
#  ('SplishySplashy', 1.0),
#  ('horseracing', 1.0),
#  ('PornIsMisogyny', 1.0),
#  ('Shooting', 1.0),
#  ('doodoofard', 1.0),
#  ('thalassophilia', 1.0),
#  ('ArduinoProjects', 1.0),
#  ('AskOuija', 1.0),
#  ('GATESLOL', 1.0),
#  ('discordservers', 1.0),
#  ('HKGLounge', 1.0),
#  ('Tiananmen_Square', 1.0),
#  ('AngryAndSmol', 1.0),
#  ('BubblegumNose', 1.0),
#  ('BeiLand', 1.0),
#  ('EnoughSamHarris', 1.0),
#  ('radio', 1.0),
#  ('comic', 1.0),
#  ('POLACA', 1.0),
#  ('Mexico_FactCheck', 1.0),
#  ('Criminology', 1.0),
#  ('europeanparliament', 1.0),
#  ('eulaw', 1.0),
#  ('foucault', 1.0),
#  ('pwned', 1.0),
#  ('Lepidoptera', 1.0),
#  ('biogeography', 1.0),
#  ('MikePence', 1.0),
#  ('MikePenceForPresident', 1.0),
#  ('USAConstitution', 1.0),
#  ('SocialDistributism', 1.0),
#  ('cyber_war', 1.0),
#  ('SouthernSocialists', 1.0),
#  ('Dixieprole', 1.0),
#  ('unionize2021', 1.0),
#  ('hotones', 1.0),
#  ('cypruspolitics', 1.0),
#  ('centralbanking', 1.0),
#  ('digitalcurrency', 1.0),
#  ('LosAlamos', 1.0),
#  ('OutdoorSkills', 1.0),
#  ('OffTheGrid', 1.0),
#  ('smallfarms', 1.0),
#  ('arab', 1.0),
#  ('RepublicMemes', 1.0),
#  ('TopSecretRecipes', 1.0),
#  ('bestoflegaladvice', 1.0),
#  ('CaliforniaGreenParty', 1.0),
#  ('Pickles', 1.0),
#  ('MateriaIslamica', 1.0),
#  ('Recitation', 1.0),
#  ('LGBTLibertarians', 1.0),
#  ('PressFreedom', 1.0),
#  ('BlackHistory', 1.0),
#  ('ForeignPoliticsDiscus', 1.0),
#  ('forwardsfromhitler', 1.0),
#  ('diySpace', 1.0),
#  ('SpaceInstructor', 1.0),
#  ('BlackAllianceforPeace', 1.0),
#  ('gamedesign', 1.0),
#  ('Ma3azef', 1.0),
#  ('AusNews', 1.0),
#  ('Korg', 1.0),
#  ('SilverSqueeze', 1.0),
#  ('SaturdayMorning', 1.0),
#  ('u_PPLucky77', 1.0),
#  ('u_Kirnobi', 1.0),
#  ('deadandcompany', 1.0),
#  ('grateful_dead', 1.0),
#  ('EnamelPins', 1.0),
#  ('Pinz', 1.0),
#  ('Hervisguards', 1.0),
#  ('paperclan', 1.0),
#  ('blndsundoll4mj', 1.0),
#  ('budtenders', 1.0),
#  ('macrogrowery', 1.0),
#  ('TheFourth', 1.0),
#  ('Elovalasztas', 1.0),
#  ('VirginiaDems', 1.0),
#  ('CoreCyberpunk', 1.0),
#  ('Cebu', 1.0),
#  ('AskEurope', 1.0),
#  ('MakeNudityLegal', 1.0),
#  ('HouseDecorationTip', 1.0),
#  ('2600', 1.0),
#  ('opendirectories', 1.0),
#  ('marscoin', 1.0),
#  ('nativeplants', 1.0),
#  ('OutdoorHacks', 1.0),
#  ('garden_maintenance', 1.0),
#  ('ExplorersOfReality', 1.0),
#  ('Outdoor', 1.0),
#  ('survivalism', 1.0),
#  ('ShivaBhajans', 1.0),
#  ('ChinmayaMission', 1.0),
#  ('vulkan', 1.0),
#  ('ChargedUpKaren', 0.9166666666666666),
#  ('secretsnacks', 0.9166666666666666),
#  ('guerillagardening', 0.9166666666666666),
#  ('Hugelkultur', 0.9166666666666666),
#  ('path2utopia', 0.9),
#  ('tibet', 0.8333333333333334),
#  ('JimJordan', 0.8333333333333334),
#  ('iamatotalpos', 0.8333333333333334),
#  ('karengosh', 0.8333333333333334),
#  ('RacistsGetPunched', 0.8333333333333334),
#  ('redditiliked', 0.8333333333333334),
#  ('MichaelJackson', 0.8333333333333334),
#  ('renewableenergystocks', 0.8333333333333334),
#  ('snowing', 0.8333333333333334),
#  ('woodworkingporn', 0.8333333333333334),
#  ('AdvancedIdeas', 0.8333333333333334),
#  ('JobWellDone', 0.8333333333333334),
#  ('Yahaha_IRL', 0.8333333333333334),
#  ('Clusterfish', 0.8333333333333334),
#  ('IfYouHigh', 0.8333333333333334),
#  ('automata', 0.8333333333333334),
#  ('fascinature', 0.8333333333333334),
#  ('MomentOfPeace', 0.8333333333333334),
#  ('StanleyKubrick', 0.8333333333333334),
#  ('StuffWeThoughtWasCool', 0.8333333333333334),
#  ('Rainbow', 0.8333333333333334),
#  ('gingerkitty', 0.8333333333333334),
#  ('catolicism', 0.8333333333333334),
#  ('CatsWithHobbies', 0.8333333333333334),
#  ('chinchilla', 0.8333333333333334),
#  ('Pomeranians', 0.8333333333333334),
#  ('maskandmantlecats', 0.8333333333333334),
#  ('wallpaperengine', 0.8333333333333334),
#  ('MTGuns', 0.8333333333333334),
#  ('Crowbruh', 0.8333333333333334),
#  ('bipartisan', 0.8333333333333334),
#  ('Longshoremen', 0.8333333333333334),
#  ('Agronomy', 0.8333333333333334),
#  ('Drylands', 0.8333333333333334),
#  ('OrganicFarming', 0.8333333333333334),
#  ('UnexpectedMyst', 0.8),
#  ('coolthingsformygirl', 0.8),
#  ('catsonglass', 0.8),
#  ('audiodrama', 0.8),
#  ('garden', 0.7894736842105263),
#  ('machiningporn', 0.7666666666666667),
#  ('AlleKnicklicht', 0.75),
#  ('cinematography', 0.75),
#  ('bluey', 0.75),
#  ('7238sSavings', 0.75),
#  ('theisle', 0.75),
#  ('VisualPhysics', 0.75),
#  ('BetterMarkets', 0.75),
#  ('Dachshund', 0.75),
#  ('2624', 0.75),
#  ('humantorches', 0.75),
#  ('CryptidDogs', 0.75),
#  ('SweatyPaws', 0.75),
#  ('catsinsnow', 0.75),
#  ('redletterchristians', 0.75),
#  ('ActualBrutalBeatdowns', 0.7),
#  ('Bruisedbanana', 0.7),
#  ('Renewables', 0.7),
#  ('CatsPlayingInSnow', 0.7),
#  ('HornySwat', 0.7),
#  ('Bernie_Sanders', 0.7),
#  ('AnimalRightsAdvocates', 0.7),
#  ('ApeStonks', 0.6730769230769231),
#  ('hawaiinews', 0.6666666666666666),
#  ('Permanence', 0.6666666666666666),
#  ('OrphanCrushingMachine', 0.6666666666666666),
#  ('CoronaMENA', 0.6666666666666666),
#  ('WHHR5', 0.6666666666666666),
#  ('Fakertarians', 0.6666666666666666),
#  ('AlexandriaOcasio2024', 0.6666666666666666),
#  ('AlexandriaCortez2024', 0.6666666666666666),
#  ('Cortez2024', 0.6666666666666666),
#  ('RealCOPolitics', 0.6666666666666666),
#  ('AtlantaPolitics', 0.6666666666666666),
#  ('jellybeantoes', 0.6666666666666666),
#  ('LightbringerSeries', 0.6666666666666666),
#  ('itsTooLate', 0.6666666666666666),
#  ('Cameras', 0.6666666666666666),
#  ('ac_newhorizons', 0.6666666666666666),
#  ('PlantGoths', 0.6666666666666666),
#  ('NYStateOfMind', 0.6666666666666666),
#  ('BanTheRepublicanParty', 0.6666666666666666),
#  ('RealCommunists', 0.6666666666666666),
#  ('IdiotsInBoats', 0.6666666666666666),
#  ('Karensgettingowned', 0.6666666666666666),
#  ('holdmyfuckingteeth', 0.6666666666666666),
#  ('heavyequipment', 0.6666666666666666),
#  ('amibeingdetained', 0.6666666666666666),
#  ('Paraguay', 0.6666666666666666),
#  ('malcolmx', 0.6666666666666666),
#  ('PUBGConsole', 0.6666666666666666),
#  ('juxtaposition', 0.6666666666666666),
#  ('facingtheirparenting', 0.6666666666666666),
#  ('PokemonTCG', 0.6666666666666666),
#  ('FirefighterPorn', 0.6666666666666666),
#  ('randomactsofkindness', 0.6666666666666666),
#  ('PsychotherapyLeftists', 0.6666666666666666),
#  ('Catalina', 0.6666666666666666),
#  ('UniversalBasicIncome', 0.6666666666666666),
#  ('CLIMATECHANGENOW', 0.6666666666666666),
#  ('Rural_Internet', 0.6666666666666666),
#  ('Tread_Tube', 0.6666666666666666),
#  ('AccidentalSlap', 0.6666666666666666),
#  ('ticmemes', 0.6666666666666666),
#  ('ZytlibsSaved', 0.6666666666666666),
#  ('DogsOnHardwoodFloors', 0.6666666666666666),
#  ('dogsruiningyoga', 0.6666666666666666),
#  ('MonkeysActingHuman', 0.6666666666666666),
#  ('SmolHumans', 0.6666666666666666),
#  ('evcharging', 0.6666666666666666),
#  ('Therealstuff', 0.6666666666666666),
#  ('jumprope', 0.6666666666666666),
#  ('OrganizationPorn', 0.6666666666666666),
#  ('bladerunner', 0.6666666666666666),
#  ('steampunk', 0.6666666666666666),
#  ('BigBrains', 0.6666666666666666),
#  ('laminarflow', 0.6666666666666666),
#  ('HigherPlane', 0.6666666666666666),
#  ('CerebralPalsy', 0.6666666666666666),
#  ('DanishAndOneill', 0.6666666666666666),
#  ('sips', 0.6666666666666666),
#  ('VanLife', 0.6666666666666666),
#  ('Superliminal', 0.6666666666666666),
#  ('facesinthings', 0.6666666666666666),
#  ('austincirclejerk', 0.6666666666666666),
#  ('wyzecam', 0.6666666666666666),
#  ('siberianhusky', 0.6666666666666666),
#  ('GMEmoons', 0.6666666666666666),
#  ('ISKbets', 0.6666666666666666),
#  ('GME2', 0.6666666666666666),
#  ('Wekeepyourunning', 0.6666666666666666),
#  ('WallStreetMonkey', 0.6666666666666666),
#  ('GME_VERIFIED_DD', 0.6666666666666666),
#  ('1stock', 0.6666666666666666),
#  ('GME_Mafia', 0.6666666666666666),
#  ('HereWeTrade', 0.6666666666666666),
#  ('dadvids', 0.6666666666666666),
#  ('politecats', 0.6666666666666666),
#  ('Fattypillow', 0.6666666666666666),
#  ('redpandas', 0.6666666666666666),
#  ('forgedinfireshow', 0.6666666666666666),
#  ('cutepupper', 0.6666666666666666),
#  ('finegentlemen', 0.6666666666666666),
#  ('oddcouples', 0.6666666666666666),
#  ('specialaww', 0.6666666666666666),
#  ('ShortSqueezeMyBalls', 0.6666666666666666),
#  ('AntiBonkPatrol', 0.6666666666666666),
#  ('Spyden', 0.6666666666666666),
#  ('LittleNightmares', 0.6666666666666666),
#  ('WhitePeopleAtItAgain', 0.6666666666666666),
#  ('olojammy', 0.6666666666666666),
#  ('allinspanish', 0.6666666666666666),
#  ('FibonacciAsFuck', 0.6666666666666666),
#  ('stockinspo', 0.6666666666666666),
#  ('animalsyawning', 0.6666666666666666),
#  ('satisfactory', 0.6666666666666666),
#  ('accidentalart', 0.6666666666666666),
#  ('OddlyCute', 0.6666666666666666),
#  ('seattlepronz', 0.6666666666666666),
#  ('BigCykas', 0.6666666666666666),
#  ('CutestOfThemAll', 0.6666666666666666),
#  ('TheoryofCatsInSinks', 0.6666666666666666),
#  ('Fruitbatcats', 0.6666666666666666),
#  ('CatsOnKeyboards', 0.6666666666666666),
#  ('Grishaverse', 0.6666666666666666),
#  ('catpictures', 0.6666666666666666),
#  ('RingFitAdventure', 0.6666666666666666),
#  ('ShowerPussy', 0.6666666666666666),
#  ('MRW', 0.6666666666666666),
#  ('Moomies', 0.6666666666666666),
#  ('RIGuns', 0.6666666666666666),
#  ('Tyranids', 0.6666666666666666),
#  ('DrunkRussian', 0.6666666666666666),
#  ('dogswearinghats', 0.6666666666666666),
#  ('airport', 0.6666666666666666),
#  ('Worldtrade', 0.6666666666666666),
#  ('AgroForestry', 0.6666666666666666),
#  ('EAjobs', 0.6666666666666666),
#  ('AmpedUpwithRyanKnight', 0.6666666666666666),
#  ('CountryHumansSmut', 0.6666666666666666),
#  ('u_AdrianCuba', 0.6666666666666666),
#  ('Lovebirds', 0.6666666666666666),
#  ('DDintoGME', 0.6666666666666666),
#  ('MemesESP', 0.6666666666666666),
#  ('Deltarune', 0.6666666666666666),
#  ('notill', 0.6666666666666666),
#  ('SovietUnion', 0.6666666666666666),
#  ('CarbonFootprint', 0.65),
#  ('IsaacandHannahsTTC', 0.65),
#  ('EatTheRichWallStreet', 0.65),
#  ('gmeamcstonks', 0.65),
#  ('BunnyKicks', 0.65),
#  ('catshuggingcats', 0.65),
#  ('gingerpussy', 0.65),
#  ('MiddleEastern', 0.6428571428571429),
#  ('LinuxFurries', 0.6428571428571429),
#  ('Carpentry', 0.6428571428571429),
#  ('FastWorkers', 0.6428571428571429),
#  ('PureJoy', 0.6428571428571429),
#  ('hey_criss', 0.6428571428571429),
#  ('BackToEden', 0.6428571428571429),
#  ('PoliticalRevolutionNY', 0.6333333333333333),
#  ('Catsarespies', 0.6333333333333333),
#  ('CannaPLUS', 0.6190476190476191),
#  ('mexico_politicalhumor', 0.6153846153846154),
#  ('conspiracyUK', 0.6),
#  ('LockUpTrump', 0.6),
#  ('PokemonSwordAndShield', 0.6),
#  ('GoldfishMyth', 0.6),
#  ('911FOX', 0.6),
#  ('BirdsEyeViewVideos', 0.6),
#  ('MrPuckett', 0.6),
#  ('VeganSchools', 0.6),
#  ('Steep', 0.6),
#  ('mesolucky', 0.6),
#  ('guatemala', 0.6),
#  ('IrishHistory', 0.6),
#  ('CatDeathStare', 0.6),
#  ('NMGuns', 0.6),
#  ('ThisBlewMyMind', 0.5952380952380952),
#  ('OneLessDirtbag', 0.5909090909090909),
#  ('TheGreatestMovement', 0.5833333333333334),
#  ('SaveThePostalService', 0.5833333333333334),
#  ('WeNeedAThirdParty', 0.5833333333333334),
#  ('DEGuns', 0.5833333333333334),
#  ('flippyflaps', 0.5833333333333334),
#  ('rdr2online', 0.5833333333333334),
#  ('OneInTheHand', 0.5833333333333334),
#  ('INTERNETFAMOUSFOREVER', 0.5833333333333334),
#  ('RedZoomers', 0.5833333333333334),
#  ('protestfreakout', 0.5833333333333334),
#  ('EYHOTH', 0.5833333333333334),
#  ('ThunderThots', 0.5833333333333334),
#  ('mrpresidentthebutton', 0.5833333333333334),
#  ('GermanyPics', 0.5833333333333334),
#  ('FuckJeffBezos', 0.5833333333333334),
#  ('Waterfowl', 0.5833333333333334),
#  ('UpvotedBecauseBoy', 0.5833333333333334),
#  ('SWORDS', 0.5833333333333334),
#  ('juliensolomita', 0.5833333333333334),
#  ('turtleswithjobs', 0.5833333333333334),
#  ('Catberg', 0.5833333333333334),
#  ('theBeesKneads', 0.5833333333333334),
#  ('WtWFotMJaJtRAtCaB', 0.5833333333333334),
#  ('TheWitness', 0.5833333333333334),
#  ('blop', 0.5833333333333334),
#  ('rollsomememes', 0.5833333333333334),
#  ('chicksfalling', 0.5833333333333334),
#  ('conspiro', 0.5833333333333334),
#  ('displeased_kitties', 0.5833333333333334),
#  ('gingercats', 0.5833333333333334),
#  ('longcats', 0.5833333333333334),
#  ('maybecatculations', 0.5833333333333334),
#  ('praisethegopromount', 0.5833333333333334),
#  ('Mexico_Economy', 0.5833333333333334),
#  ('HawaiiPlantMedicine', 0.5833333333333334),
#  ('RevLumpenRadio', 0.5833333333333334),
#  ('policeabuse', 0.575),
#  ('windenergy', 0.5714285714285714),
#  ('GreenNewIdeas', 0.5666666666666667),
#  ('bullybackfire', 0.5666666666666667),
#  ('MoronsInAction', 0.5666666666666667),
#  ('GrowingMarijuana', 0.5666666666666667),
#  ('UrbanAgriculture', 0.5666666666666667),
#  ('jumpywumpies', 0.5666666666666667),
#  ('Wellthatsamazing', 0.5555555555555556),
#  ('GirlFails', 0.5555555555555556),
#  ('WeDemandChange', 0.55),
#  ('SeaShepherd', 0.55),
#  ('StopResisting', 0.55),
#  ('OnlyInNY', 0.55),
#  ('expectedlyunexpected', 0.55),
#  ('WeLiveInTheFuture', 0.55),
#  ('hhhorse', 0.55),
#  ('theboys_FREAKS', 0.55),
#  ('FRC', 0.55),
#  ('MemesForMyJetPack', 0.55),
#  ('IndependentLeft', 0.55),
#  ('NoTillGrowery', 0.55),
#  ('LucyAndEye', 0.55),
#  ('Rayta', 0.55),
#  ('PracticeExpressions', 0.5476190476190477),
#  ('WatchDogsDieInside', 0.5416666666666666),
#  ('agrivoltaics', 0.5384615384615384),
#  ('FossilFuels', 0.5333333333333333),
#  ('karenkarma', 0.5333333333333333),
#  ('TheDragonPrince', 0.5333333333333333),
#  ('MOASS', 0.5333333333333333),
#  ('Rattatakage', 0.5333333333333333),
#  ('waitforit', 0.5238095238095238),
#  ('cestlarigolade', 0.5238095238095238),
#  ('WorkersRights', 0.5238095238095238),
#  ('RandomFunnyCoolShit', 0.5238095238095238),
#  ('ScrapMechanic', 0.5238095238095238),
#  ('Moonmoon', 0.5194805194805194),
#  ('2bears1cave', 0.5178571428571429),
#  ('BasedJustice', 0.5147058823529411),
#  ('jibungatari', 0.5138888888888888),
#  ('EmissionsTax', 0.5),
#  ('GetIt2Gether', 0.5),
#  ('StopFossilFuels', 0.5),
#  ('greatfilterpodcast', 0.5),
#  ('2035', 0.5),
#  ('Waste', 0.5),
#  ('norfolk', 0.5),
#  ('NoGoodCops', 0.5),
#  ('WApeoplesparty', 0.5),
#  ('sextrafficking', 0.5),
#  ('upbeatnews', 0.5),
#  ('DrainTheSwamp', 0.5),
#  ('PoliceUseOfForce', 0.5),
#  ('BoicoteANestle', 0.5),
#  ('RacistRegret', 0.5),
#  ('Knoxville_liberty', 0.5),
#  ('downliftingnews', 0.5),
#  ('PivotPodcast', 0.5),
#  ('TheSwampDrain', 0.5),
#  ('LoveForScalpers', 0.5),
#  ('Qfiles', 0.5),
#  ('clearlake', 0.5),
#  ('LeopardsAteMyFaceMask', 0.5),
#  ('NYvsTrump', 0.5),
#  ('Boxing', 0.5),
#  ('Cistem', 0.5),
#  ('BoycottChinaRussiaUSA', 0.5),
#  ('AllCopsAreBastards', 0.5),
#  ('FixedThatForYa', 0.5),
#  ('avoidchineseproducts', 0.5),
#  ('ProtestBlizzcon', 0.5),
#  ('bluenecks', 0.5),
#  ('traitorperpwalk', 0.5),
#  ('NoMoreBigChina', 0.5),
#  ('Yatirim', 0.5),
#  ('okbuddyhasan', 0.5),
#  ('BlueMafia', 0.5),
#  ('AngryTaxPayer', 0.5),
#  ('DrFauci', 0.5),
#  ('COVIDAteMyFace', 0.5),
#  ('FactoryFarming', 0.5),
#  ('MMJ', 0.5),
#  ('grubhubdrivers', 0.5),
#  ('blackgunowners', 0.5),
#  ('C4CD', 0.5),
#  ('newbrunswickcanada', 0.5),
#  ('CharlottesWeb', 0.5),
#  ('March2018', 0.5),
#  ('PapaJohnsMilitary', 0.5),
#  ('lost', 0.5),
#  ('AmericanPoverty', 0.5),
#  ('toriesdeathtoll', 0.5),
#  ('TinyViolins', 0.5),
#  ('PrisonStrike', 0.5),
#  ('Eritrea', 0.5),
#  ('xijinping', 0.5),
#  ('Gold', 0.5),
#  ('ksatv', 0.5),
#  ('ProblemSolvingMatrix', 0.5),
#  ('respiratorytherapy', 0.5),
#  ('Linky_links', 0.5),
#  ('wsu', 0.5),
#  ('MaunaKea', 0.5),
#  ('liestrumptoldus', 0.5),
#  ('FinanceShed', 0.5),
#  ('XiIsFinished', 0.5),
#  ('chinareddits', 0.5),
#  ('2020Headlines', 0.5),
#  ('internationalaffairs', 0.5),
#  ('HotterTopics', 0.5),
#  ('SocConstructOfReality', 0.5),
#  ('bonsaicommunity', 0.5),
#  ('TrackDOJ', 0.5),
#  ('UncapTheHouse', 0.5),
#  ('NortheastUS', 0.5),
#  ('BanTheGOP', 0.5),
#  ('SENATORMcConnell', 0.5),
#  ('Thebenjaminbeacon', 0.5),
#  ('ImpeachmentWatch', 0.5),
#  ('CornbreadLiberals', 0.5),
#  ('Marjorie_Taylor_Green', 0.5),
#  ('TrumpCorruption', 0.5),
#  ('BetoORourke', 0.5),
#  ('MAGAretards', 0.5),
#  ('Boycott_FOXNews', 0.5),
#  ('PaMedicalMarijuana', 0.5),
#  ('IRLProgressives', 0.5),
#  ('atlanticdiscussions', 0.5),
#  ('itcouldhappenhere', 0.5),
#  ('Protest2020', 0.5),
#  ('Rights', 0.5),
#  ('Tonedeafcelebs', 0.5),
#  ('thechristianleft', 0.5),
#  ('NewJerseyEnts', 0.5),
#  ('ShahidButtar', 0.5),
#  ('BernieBros2GreenParty', 0.5),
#  ('lacrossewi', 0.5),
#  ('Addictionlss', 0.5),
#  ('nycCoronavirus', 0.5),
#  ('2016Elections', 0.5),
#  ('2016_elections', 0.5),
#  ('confederacy', 0.5),
#  ('democratic_socialists', 0.5),
#  ('capitolhill', 0.5),
#  ('confederateflags', 0.5),
#  ('mapasdemexico', 0.5),
#  ('GayChristians', 0.5),
#  ('Americans', 0.5),
#  ('forbiddenbed', 0.5),
#  ('TheAmazingNature', 0.5),
#  ('LilliaMains', 0.5),
#  ('RaIn', 0.5),
#  ('DarkCrystal', 0.5),
#  ('videography', 0.5),
#  ('NorthernNordics', 0.5),
#  ('niceotters', 0.5),
#  ('FortniteSavetheWorld', 0.5),
#  ('ror2', 0.5),
#  ('tarantulas', 0.5),
#  ('Mildlycthulhu', 0.5),
#  ('belugasbeingbros', 0.5),
#  ('yeahbutreallyImaspeck', 0.5),
#  ('Natureisfuckingtired', 0.5),
#  ('boop', 0.5),
#  ('gravityrush', 0.5),
#  ('mtg', 0.5),
#  ('ACValhalla', 0.5),
#  ('MushroomPorn', 0.5),
#  ('DrStone', 0.5),
#  ('SwiggitySwootyGifs', 0.5),
#  ('modelbirbs', 0.5),
#  ('Thorgasm', 0.5),
#  ('ThisShouldBeAPokemon', 0.5),
#  ('spelunky', 0.5),
#  ('ArtOfRolling', 0.5),
#  ('toofers', 0.5),
#  ('fawns', 0.5),
#  ('webarebears', 0.5),
#  ('TrackMania', 0.5),
#  ('pathoftitans', 0.5),
#  ('monsteraday', 0.5),
#  ('WildlifePorn', 0.5),
#  ('JurassicWorldAlive', 0.5),
#  ('EnlightendNazis', 0.5),
#  ('warcrimes', 0.5),
#  ('streetfightradio', 0.5),
#  ('BadCopNoTimbit', 0.5),
#  ('copshaming', 0.5),
#  ('OutlandishAlcoholics', 0.5),
#  ('Keller', 0.5),
#  ('FrenchPoliceVideos', 0.5),
#  ('ParkRangers', 0.5),
#  ('Featherweightfreakout', 0.5),
#  ('Grapplerbaki', 0.5),
#  ('godblessamerica', 0.5),
#  ('rule63', 0.5),
#  ('ConservativeTears', 0.5),
#  ('riots', 0.5),
#  ('morbid_reality', 0.5),
#  ('PeoplesPolitics', 0.5),
#  ('theselivesmattertoo', 0.5),
#  ('firefighter', 0.5),
#  ('ShitPile', 0.5),
#  ('brooklynninenine', 0.5),
#  ('hauntedattractions', 0.5),
#  ('iamtotalscum', 0.5),
#  ('thatsenoughredditoday', 0.5),
#  ('TenMinutePodcast', 0.5),
#  ('northcounty', 0.5),
#  ('robberiesgonewrong', 0.5),
#  ('TheBangles', 0.5),
#  ('natesshitposthub', 0.5),
#  ('Gal_Shamen', 0.5),
#  ('Coverupmofo', 0.5),
#  ('GetOffMyPlane', 0.5),
#  ('LandRover', 0.5),
#  ('OutragedKarens', 0.5),
#  ('oblivionNPC', 0.5),
#  ('SLO', 0.5),
#  ('facemaskfreakout', 0.5),
#  ('devastatingslaps', 0.5),
#  ('BossfightUniverse', 0.5),
#  ('Methany', 0.5),
#  ('karenheit', 0.5),
#  ('snowsos', 0.5),
#  ('Ulta', 0.5),
#  ('RADAL', 0.5),
#  ('Beast3636', 0.5),
#  ('hexomer', 0.5),
#  ('StandUpComedy', 0.5),
#  ('AnimalGroupRides', 0.5),
#  ('LiveThoughtProcess', 0.5),
#  ('Mustang', 0.5),
#  ('BeLikeBros', 0.5),
#  ('SirSwag', 0.5),
#  ('KidCudi', 0.5),
#  ('RealProgressives', 0.5),
#  ('black_humor', 0.5),
#  ('bee_irl', 0.5),
#  ('crazyhumanz', 0.5),
#  ('StreetFights', 0.5),
#  ('KarmaForBrats', 0.5),
#  ('TFABAARBI', 0.5),
#  ('DrDraydleFavourite', 0.5),
#  ('TurkeyJerky', 0.5),
#  ('the1975', 0.5),
#  ('AccidentalRadiohead', 0.5),
#  ('positivefreakout', 0.5),
#  ('LesionsOnSkanks', 0.5),
#  ('idiotsonthesidewalk', 0.5),
#  ('Americans_r_stupid', 0.5),
#  ('vancouvercycling', 0.5),
#  ('iilluminaughtii', 0.5),
#  ('IntriguingDiscussions', 0.5),
#  ('GifsThatEndJustRight', 0.5),
#  ('hold_my_feeding_tube', 0.5),
#  ('surrendercobra', 0.5),
#  ('HowtoChurch', 0.5),
#  ('Imacasual', 0.5),
#  ('1_Rule', 0.5),
#  ('karensincars', 0.5),
#  ('WholesomeMetalheads', 0.5),
#  ('fuckyouimatoddler', 0.5),
#  ('literally', 0.5),
#  ('bonuspup', 0.5),
#  ('Notakeonlythrow', 0.5),
#  ('Knockout', 0.5),
#  ('politicsCA', 0.5),
#  ('TheWrongWayto', 0.5),
#  ('idiotinfluencers', 0.5),
#  ('CheapShow', 0.5),
#  ('LongmontPotionCastle', 0.5),
#  ('HoldMyMetamucil', 0.5),
#  ('plano', 0.5),
#  ('proudboys', 0.5),
#  ('noveltranslations', 0.5),
#  ('HypixelSkyblock', 0.5),
#  ('unexpecteddarksouls', 0.5),
#  ('dogswithweapons', 0.5),
#  ('megandandy', 0.5),
#  ('animaniacs', 0.5),
#  ('Turkophobia', 0.5),
#  ('OTAK', 0.5),
#  ('DaDumbWay', 0.5),
#  ('MgtowLifestyle', 0.5),
#  ('BasicallyMyBlog', 0.5),
#  ('AmericaBad', 0.5),
#  ('insanepeopletwitter', 0.5),
#  ('FoodDeliveryRobots', 0.5),
#  ('genlock', 0.5),
#  ('ItalyInformatica', 0.5),
#  ('LaCarcaza', 0.5),
#  ('ForwardThinkingJasper', 0.5),
#  ('ukcrypto', 0.5),
#  ('the_bad_place', 0.5),
#  ('cricut', 0.5),
#  ('BIDENthaPEDO', 0.5),
#  ('Dystopia_IRL', 0.5),
#  ('DooDahDooDah', 0.5),
#  ('personalfinancememes', 0.5),
#  ('SheBroughtHerKittens', 0.5),
#  ('DadsBeingDads', 0.5),
#  ('onionfactory', 0.5),
#  ('CannotWatchScottsTots', 0.5),
#  ('TexasForSanders', 0.5),
#  ('Maryland4Sanders', 0.5),
#  ('WashingtonForSanders', 0.5),
#  ('Wisconsin4Sanders', 0.5),
#  ('NewJerseyforSanders', 0.5),
#  ('IowaForSanders', 0.5),
#  ('PAForSanders', 0.5),
#  ('HawaiiForSanders', 0.5),
#  ('RhodeIsland4Sanders', 0.5),
#  ('PRForSanders', 0.5),
#  ('indianaforsanders', 0.5),
#  ('LouisianaForSanders', 0.5),
#  ('WyomingForSanders', 0.5),
#  ('Michigan4Sanders', 0.5),
#  ('NewHampshire4Sanders', 0.5),
#  ('Illinois4Sanders', 0.5),
#  ('ArizonaForSanders', 0.5),
#  ('alaskaforsanders', 0.5),
#  ('KentuckyForSanders', 0.5),
#  ('NevadaForSanders', 0.5),
#  ('Connecticut4Sanders', 0.5),
#  ('Georgia4Sanders', 0.5),
#  ('OregonForSanders', 0.5),
#  ('progressivehumor', 0.5),
#  ('leftypol', 0.5),
#  ('hurricane', 0.5),
#  ('heartbeatfetish', 0.5),
#  ('catscantdrink', 0.5),
#  ('clamswithjobs', 0.5),
#  ('spidermanmemes', 0.5),
#  ('Randomawesomeness', 0.5),
#  ('marchingband', 0.5),
#  ('enfj', 0.5),
#  ('KSU', 0.5),
#  ('HealthyGifRecipes', 0.5),
#  ('0000zxcv', 0.5),
#  ('MuffinEats', 0.5),
#  ('AntifaVegan', 0.5),
#  ('Space_Colonization', 0.5),
#  ('space_settlement', 0.5),
#  ('OKBilly', 0.5),
#  ('WorkplaceSafety', 0.5),
#  ('CulturedMeat', 0.5),
#  ('Billions', 0.5),
#  ('decriminalizenature', 0.5),
#  ('SpaceColonisation', 0.5),
#  ('MBthin', 0.5),
#  ('ProjectVoy', 0.5),
#  ('CanadaPublicServants', 0.5),
#  ('CognitiveTechnology', 0.5),
#  ('SociopatiaBrasil', 0.5),
#  ('Hardsciences', 0.5),
#  ('NortheastTechnews', 0.5),
#  ('GretaThunberg', 0.5),
#  ('pagan', 0.5),
#  ('Abolishtherepublic', 0.5),
#  ('CoronavirusCasualty', 0.5),
#  ('remnantgame', 0.5),
#  ('europics', 0.5),
#  ('Blue', 0.5),
#  ('Belgium404', 0.5),
#  ('EUROAESTHETICS', 0.5),
#  ('CraftBeer', 0.5),
#  ('OpenAccess', 0.5),
#  ...]

# %%
nx.average_clustering(G)
# Out:
# 0.1024324286592494
